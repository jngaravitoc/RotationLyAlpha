# %%
# %pylab inline
from numpy import *
from pylab import *
import numpy as np
import math
import matplotlib.pyplot as plt

data_dir = "../data/Homogeneous/"
#filename200="V3007tHOM_in.ascii"
#filenameOUT200 = 'V3007tHOM_out.ascii'


filename50 = "V50HOM5t_in.ascii"
filenameOUT50 = 'V50HOM5t_out.ascii'

filename100 = 'V1005tHOM_in.ascii'
filenameOUT100 = 'V1005tHOM_out.ascii'

#filename200 = 'V2007tHOM_in.ascii'
#filenameOUT200 = 'V2007tHOM_out.ascii'

filename300 = 'V3005tHOM_in.ascii'
filenameOUT300 = 'V3005tHOM_out.ascii'



datoslyman50 = np.loadtxt(data_dir+filename50, comments = '#')
datoslymanOUT50 = np.loadtxt(data_dir+filenameOUT50, comments = '#')

datoslyman100 = np.loadtxt(data_dir+filename100, comments = '#')
datoslymanOUT100 = np.loadtxt(data_dir+filenameOUT100, comments = '#')

#datoslyman200 = np.loadtxt(data_dir+filename200, comments = '#')
#datoslymanOUT200 = np.loadtxt(data_dir+filenameOUT200, comments = '#')

datoslyman300 = np.loadtxt(data_dir+filename300, comments = '#')
datoslymanOUT300 = np.loadtxt(data_dir+filenameOUT300, comments = '#')




initpos=datoslymanOUT50[:,0]
index_clean = where(~np.isnan(initpos))
datoslymanOUT50 = datoslymanOUT50[index_clean[0],:]
datoslyman50 = datoslyman50[index_clean[0],:]

initpos=datoslymanOUT100[:,0]
index_clean = where(~np.isnan(initpos))
datoslymanOUT100 = datoslymanOUT100[index_clean[0],:]
datoslyman100 = datoslyman100[index_clean[0],:]

#initpos=datoslymanOUT200[:,0]
#index_clean = where(~np.isnan(initpos))
#datoslymanOUT200 = datoslymanOUT200[index_clean[0],:]
#datoslyman200 = datoslyman200[index_clean[0],:]

initpos=datoslymanOUT300[:,0]
index_clean = where(~np.isnan(initpos))
datoslymanOUT300 = datoslymanOUT300[index_clean[0],:]
datoslymanOUT300 = datoslymanOUT300[index_clean[0],:]


x50 = datoslymanOUT50[:,6]
X50 = datoslyman50[:,0]
Y50 = datoslyman50[:,1]
Z50 = datoslyman50[:,2]

kx50 = datoslymanOUT50[:,3]
ky50 = datoslymanOUT50[:,4]
kz50 = datoslymanOUT50[:,5]

x100 = datoslymanOUT100[:,6]
X100 = datoslyman100[:,0]
Y100 = datoslyman100[:,1]
Z100 = datoslyman100[:,2]

kx100 = datoslymanOUT100[:,3]
ky100 = datoslymanOUT100[:,4]
kz100 = datoslymanOUT100[:,5]

"""
x200 = datoslymanOUT200[:,6]
X200 = datoslyman200[:,0]
Y200 = datoslyman200[:,1]
Z200 = datoslyman200[:,2]

kx200 = datoslymanOUT200[:,3]
ky200 = datoslymanOUT200[:,4]
kz200 = datoslymanOUT200[:,5]
"""

x300 = datoslymanOUT300[:,6]
X300 = datoslyman300[:,0]
Y300 = datoslyman300[:,1]
Z300 = datoslyman300[:,2]

kx300 = datoslymanOUT300[:,3]
ky300 = datoslymanOUT300[:,4]
kz300 = datoslymanOUT300[:,5]

norm50 = sqrt(kx50**2 + ky50**2 + kz50**2)
norm_r50 = amax(sqrt(X50**2 + Y50**2 + Z50**2))
print "norma", norm_r50
X50 = X50/norm_r50
Y50 = Y50/norm_r50
Z50 = Z50/norm_r50

norm100 = sqrt(kx100**2 + ky100**2 + kz100**2)
norm_r100 = amax(sqrt(X100**2 + Y100**2 + Z100**2))
X100 = X100/norm_r100
Y100 = Y100/norm_r100
Z100 = Z100/norm_r100
"""
weight200 = kx200*obs[0] +  ky200*obs[1] + kz200*obs[2]
weight200[weight200<0] = 0.0

norm200 = sqrt(kx200**2 + ky200**2 + kz200**2)
norm_r200 = amax(sqrt(X200**2 + Y200**2 + Z200**2))
X200 = X200/norm_r200
Y200 = Y200/norm_r200
Z200 = Z200/norm_r200
"""

norm_r300 = amax(sqrt(X300**2 + Y300**2 + Z300**2))
X300 = X300/norm_r300
Y300 = Y300/norm_r300
Z300 = Z300/norm_r300

print amax(X50), amax(Y50), amin(X50), amin(Y50)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
# norma 1.69606437621e+12
# 0.99543155536
#  0.996802375969 -0.998350666256 -0.996249920524

# %%
def offcenter_rectangular(xmin, xmax, ymin, ymax, zmin, zmax, XV, YV, ZV, xV, V, weightV):
    selected = where((XV >= xmin) &  (XV <= xmax) & 
                    (ZV >= zmin) & (ZV <=zmax) & 
                    (YV >= ymin) & (YV <= ymax))
    xV_selected = xV[selected]
    new_XV = XV[selected]
    new_YV = YV[selected]
    new_ZV = ZV[selected]
    new_wV = weightV[selected]
    new_x50 = x50[selected]
    return [xV_selected, new_XV, new_YV, new_ZV, new_wV, new_x50]
                      
x50_new_1, new_x50_1, new_y50_1, new_z50_1, new_w50_1, new1_x50 = offcenter_rec(-0.2, 0.2, 0.0, 0.3, -0.2, 0.2, X50, Y50, Z50, x50, 50, weight50)
x50_new_2, new_x50_2, new_y50_2, new_z50_2, new_w50_2, new2_x50 = offcenter_rec(-0.2, 0.2, 0.3, 0.6, -0.2, 0.2, X50, Y50, Z50, x50, 50, weight50)
x50_new_3, new_x50_3, new_y50_3, new_z50_3, new_w50_3, new3_x50 = offcenter_rec(-0.2, 0.2, 0.6, 0.9, -0.2, 0.2, X50, Y50, Z50, x50, 50, weight50)

x100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter_rec(-0.2, 0.2, 0.0, 0.3, -0.2, 0.2, X100, Y100, Z100, x100, 100, weight100)
x100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter_rec(-0.2, 0.2, 0.3, 0.6, -0.2, 0.2, X100, Y100, Z100, x100, 100, weight100)
x100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter_rec(-0.2, 0.2, 0.6, 0.9, -0.2, 0.2, X100, Y100, Z100, x100, 100, weight100)

x300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter_rec(-0.2, 0.2, 0.0, 0.3, -0.2, 0.2, X300, Y300, Z300, x300, 300, weight300)
x300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter_rec(-0.2, 0.2, 0.3, 0.6, -0.2, 0.2, X300, Y300, Z300, x300, 300, weight300)
x300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter_rec(-0.2, 0.2, 0.6, 0.9, -0.2, 0.2, X300, Y300, Z300, x300, 300, weight300)


print size(x50_new_1), size(new1_x50), size(x50)
# Out:
# 1169 1169 99968

# %%
def offcenter(XV, YV, ZV, xV, V, weightV, R, D2R):
    selected = where((XV <= np.sqrt((R**2 - YV**2 - ZV**2)) + D2R) & (YV <= np.sqrt(R**2 - (XV-D2R)**2 - ZV**2)) 
                    & (ZV <= np.sqrt(R**2 - (XV-D2R)**2 - YV**2)))
    
    xV_selected = xV[selected]
    new_XV = XV[selected]
    new_YV = YV[selected]
    new_ZV = ZV[selected]
    new_wV = weightV[selected]
    new_xV = xV[selected]
    return [xV_selected, new_XV, new_YV, new_ZV, new_wV, new_xV]
                      
x50_new_1, new_x50_1, new_y50_1, new_z50_1, new_w50_1, new1_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.2)
x50_new_2, new_x50_2, new_y50_2, new_z50_2, new_w50_2, new2_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.4)
x50_new_3, new_x50_3, new_y50_3, new_z50_3, new_w50_3, new3_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.6)
x50_new_4, new_x50_4, new_y50_4, new_z50_4, new_w50_4, new4_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.8)

x100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.2)
x100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.4)
x100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.6)
x100_new_4, new_x100_4, new_y100_4, new_z100_4, new_w100_4, new4_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.8)

x300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.2)
x300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.4)
x300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.6)
x300_new_4, new_x300_4, new_y300_4, new_z300_4, new_w300_4, new4_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.8)

# %%
def offcenter_ZZ(XV, YV, ZV, kxV, kyV, kzV, xV, V, R, D2R):
    selected = where((XV <= np.sqrt((R**2 - YV**2 - ZV**2)) + D2R) & (YV <= np.sqrt(R**2 - (XV-D2R)**2 - ZV**2)) 
                    & (ZV <= np.sqrt(R**2 - (XV-D2R)**2 - YV**2)))
    
    xV_selected = xV[selected]
    new_XV = XV[selected]
    new_YV = YV[selected]
    new_ZV = ZV[selected]
    #new_wV = weightV[selected]
    new_xV = xV[selected]
    new_kxV = kxV[selected]
    new_kyV = kyV[selected]
    new_kzV = kzV[selected]
    
    return [xV_selected, new_XV, new_YV, new_ZV, new_kxV, new_kyV, new_kzV, new_xV]
                      
x50_new_1, new_x50_1, new_y50_1, new_z50_1, new_kx50_1, new_ky50_1, new_kz50_1, new1_x50 = offcenter_ZZ(X50, Y50, Z50, kx50, ky50, kz50, x50, 50,  0.5, 0.25)
x50_new_2, new_x50_2, new_y50_2, new_z50_2, new_kx50_2, new_ky50_2, new_kz50_2, new2_x50 = offcenter_ZZ(X50, Y50, Z50, kx50, ky50, kz50, x50, 50,  0.5, 0.5)
x50_new_3, new_x50_3, new_y50_3, new_z50_3, new_kx50_3, new_ky50_3, new_kz50_3, new3_x50 = offcenter_ZZ(X50, Y50, Z50, kx50, ky50, kz50, x50, 50,  0.5, 0.33)
x50_new_4, new_x50_4, new_y50_4, new_z50_4, new_kx50_4, new_ky50_4, new_kz50_4, new4_x50 = offcenter_ZZ(X50, Y50, Z50, kx50, ky50, kz50, x50, 50,  0.5, 0.41)

"""
x100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.2)
x100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.4)
x100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.6)
x100_new_4, new_x100_4, new_y100_4, new_z100_4, new_w100_4, new4_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.8)

x300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.2)
x300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.4)
x300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.6)
x300_new_4, new_x300_4, new_y300_4, new_z300_4, new_w300_4, new4_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.8)
"""
# Out:
# '\nx100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.2)\nx100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.4)\nx100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.6)\nx100_new_4, new_x100_4, new_y100_4, new_z100_4, new_w100_4, new4_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.8)\n\nx300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.2)\nx300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.4)\nx300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.6)\nx300_new_4, new_x300_4, new_y300_4, new_z300_4, new_w300_4, ne
# ...

# %%
# ZZ implementation
def get_mu_histo(kx, ky, kz, theta):
    R = np.array([0, sin(theta), cos(theta)])
    global mu
    mu = kx*R[0] + ky*R[1] + kz*R[2]
    n_bins = 12
    delta_mu = 2.0/n_bins
    histo, bin_edges = histogram(mu, bins=n_bins)
    histo = 2.0*histo/(delta_mu*size(mu))
    return [histo, bin_edges, mu]

get_mu_histo(new_kx50_1, new_ky50_1, new_kz50_1, pi/2.0)
get_mu_histo(new_kx50_2, new_ky50_2, new_kz50_2, pi/2.0)
get_mu_histo(new_kx50_3, new_ky50_3, new_kz50_3, pi/2.0)
get_mu_histo(new_kx50_4, new_ky50_4, new_kz50_4, pi/2.0)
# Out:
# [array([ 0.97136564,  1.00440529,  0.99024544,  1.04782882,  1.03555695,
#         1.0223411 ,  0.97325362,  1.01950913,  1.01950913,  0.94776589,
#         0.97608559,  0.99213342]),
#  array([ -9.99953000e-01,  -8.33303758e-01,  -6.66654517e-01,
#         -5.00005275e-01,  -3.33356033e-01,  -1.66706792e-01,
#         -5.75500000e-05,   1.66591692e-01,   3.33240933e-01,
#          4.99890175e-01,   6.66539417e-01,   8.33188658e-01,
#          9.99837900e-01])]

# %%
def get_mu(mu, xV):
    selected = where((mu>-0.1) & (mu<0.1))
    new_xV = xV[selected]
    return new_xV

new_x50_1 = get_mu(mu, x50_new_1)
new_x50_2 = get_mu(mu, x50_new_2)
new_x50_3 = get_mu(mu, x50_new_3)
new_x50_4 = get_mu(mu, x50_new_4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-ef3ac77f10e7> in <module>()
#       5
#       6 new_x50_1 = get_mu(mu, x50_new_1)
# ----> 7 new_x50_2 = get_mu(mu, x50_new_2)
#       8 new_x50_3 = get_mu(mu, x50_new_3)
#       9 new_x50_4 = get_mu(mu, x50_new_4)
#
# <ipython-input-89-ef3ac77f10e7> in get_mu(mu, xV)
#       1 def get_mu(mu, xV):
#       2     selected = where((mu>-0.1) & (mu<0.1))
# ----> 3     new_xV = xV[selected]
#       4     return new_xV
#       5
#
# IndexError: index 12697 is out of bounds for size 12695

# %%
print len(new_x50)
histo, bin_edges = histogram(new_x50, bins=15)
plot(bin_edges[0:-1], histo)
# Out:
# 1377

# %%
histo0, bin_edges = get_mu_histo
histo1, bin_edges = get_mu_histo(new_kx50_1, new_ky50_1, new_kz50_1, pi/4.0)
histo2, bin_edges = get_mu_histo(new_kx50_1, new_ky50_1, new_kz50_1, pi/3.0)
histo3, bin_edges = get_mu_histo(new_kx50_1, new_ky50_1, new_kz50_1, pi/2.0)


plot(bin_edges[0:-1], histo0)
plot(bin_edges[0:-1], histo1)
plot(bin_edges[0:-1], histo2)
plot(bin_edges[0:-1], histo3)
print len(new_kx50_1)
# Out:
# 12711

# %%
mu_1 = weights(new_kx50_1, new_ky50_1, new_kz50_1, pi/2.0)
if mu_1 >= 0.1:
    hist1, bin_edges1 = np.histogram(new1_x50,bins = 25, density=True)
#mu_0 = weights(new_kx50_1, new_ky50_1, new_kz50_1, 0.0)
mu_4 = weights(new_kx50_4, new_ky50_4, new_kz50_4, pi/2.0)

hist1, bin_edges1 = np.histogram(new1_x50,bins = 25, density=True)


hist2, bin_edges2 = np.histogram(new1_x50,bins = 25, density=True)
hist2, bin_edges2 = np.histogram(new4_x50,bins = 25, density=True, weights=mu_4)

figure(num=None, figsize=(9.5,9))
p1, = plot(bin_edges1[1:],hist1, 'm', linewidth = 2.0)
p2, = plot(bin_edges2[1:],hist2, 'b', linewidth = 2.0)

plt.xlabel (r'$\mathrm{x}$', fontsize=35)
plt.ylabel (r'$\mathrm{Intensity}$ $\mathrm{(Arbitrary Units)}$', fontsize=35)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-da513969dcc1> in <module>()
# ----> 1 mu_1 = weights(new_kx50_1, new_ky50_1, new_kz50_1, pi/2.0)
#       2 if mu_1 >= 0.1:
#       3     hist1, bin_edges1 = np.histogram(new1_x50,bins = 25, density=True)
#       4 #mu_0 = weights(new_kx50_1, new_ky50_1, new_kz50_1, 0.0)
#       5 mu_4 = weights(new_kx50_4, new_ky50_4, new_kz50_4, pi/2.0)
#
# NameError: name 'weights' is not defined

# %%
#scatter(new_x_1, new_w_1, color='red')

figure(num=None, figsize=(9.5,9.5))

#X50, Y50 = meshgrid(X50, Y50)
#Z = X50**2 + Y50**2
#contour(X50, Y50, Z)
new_x50_1,  new_y50_1 = meshgrid(new_x50_1,  new_y50_1)
znew = new_x50_1**2 + new_y50_1**2
contour(new_x50_1,  new_y50_1,  znew)
#scatter(new_x50_2,  new_y50_2, color ='orange')
#scatter(new_x50_3,  new_y50_3, color ='m')
#scatter(new_x50_4,  new_y50_4, color ='brown')
#scatter(new_x50_5,  new_y50_5, color ='yellow')



subplot(111)
# P.arrow( x, y, dx, dy, **kwargs )
arrow( 0.25, 1.2, -0.4, 0.0, fc="m", ec="m", head_width=0.1, head_length=0.3)
arrow( 1.0, 0.0, 0.4, 0.0, fc="k", ec="k", head_width=0.1, head_length=0.3)

title('$\mathrm{Off-Center}$ $\mathrm{distribution}$', fontsize=35)
plt.ylabel('$y$', fontsize=20)
plt.xlabel('$x$', fontsize=20)
xlim([-1.7, 1.7])
ylim([-1.3, 1.3])
#savefig('Distribution1.png')

# %%
a300_1 = x300_new_1
freqbin300 = arange(amin(a300_1), amax(a300_1), 2.0)
hist300_1, bin_edges300_1 = np.histogram(new1_x300,bins = 25, density=True)

a300_2 = x300_new_2
freqbin300 = arange(amin(a300_2), amax(a300_2), 2.0)
hist300_2, bin_edges300_2 = np.histogram(new2_x300,bins = 25, density=True)

a300_3 = x300_new_3
freqbin300 = arange(amin(a300_3), amax(a300_3), 2.0)
hist300_3, bin_edges300_3 = np.histogram(new3_x300,bins = 25, density=True)

a300_4 = x300_new_4
freqbin300 = arange(amin(a300_4), amax(a300_4), 2.0)
hist300_4, bin_edges300_4 = np.histogram(new4_x300,bins = 25, density=True)

a50_1 = x50_new_1
freqbin50 = arange(amin(a50_1), amax(a50_1), 2.0)
hist50_1, bin_edges50_1 = np.histogram(new1_x50,bins = 25, density=True)

a50_4 = x50_new_4
freqbin100 = arange(amin(a50_4), amax(a50_4), 2.0)
hist50_4, bin_edges50_4 = np.histogram(new4_x50,bins = 25, density=True)
#a50_5 = x50_new_5
#freqbin50 = arange(amin(a50_5), amax(a50_5), 1.0)
#hist50_5, bin_edges50_5 = np.histogram(a50_5,bins = 25, density=True, weights=new_w50_5)

figure(num=None, figsize=(9.5,9))

#p50out, = plot(bin_edges50_1[1:],hist50_1, 'c', linewidth = 2.0)
#p51out, = plot(bin_edges50_2[1:],hist50_2, 'orange', linewidth = 2.0)
#p52out, = plot(bin_edges50_3[1:],hist50_3, 'm', linewidth = 2.0)
p300out, = plot(bin_edges50_1[1:],hist50_1, 'm', linewidth = 2.0)
p53out, = plot(bin_edges50_4[1:],hist50_4, 'brown', linewidth = 2.0)

plt.xlabel (r'$\mathrm{x}$', fontsize=25)
plt.ylabel ('$\mathrm{Intensity}$ $\mathrm{(Arbitrary}$ $\mathrm{Units)}$', fontsize=25)
plt.title(r"$\mathrm{Inhomogeneous}$, $\tau_{\mathrm{H}}= 10^{5}$",  fontsize=25)
#legend([p50out, p51out, p52out],[r'$\mathrm{Dist. 1}$', r'$\mathrm{Dist. 2}$', r'$\mathrm{Dist. 3}$'])
#xlim([-15, 22])
#savefig('InomogeneousModelt5.png')

# %%
#Paper plot of Off center distribution 
X= 0.0
Y= 0.0

x = [0.25, 0.5, 0.41, 0.32]
y = [0.0, 0.0, 0.0, 0.0]
area = np.pi * ((100)**2) 
Area = np.pi * ((200)**2 )

figure(num=None, figsize=(9.5,9))
plt.xlim([-1.5, 1.5])
plt.ylim([-1.5, 1.5])
plt.title('$\mathrm{Off-Center}$ $\mathrm{distribution}$', fontsize = 30)
plt.xlabel('$\mathrm{X}$', fontsize = 30)
plt.ylabel('$\mathrm{Y}$', fontsize = 30)
plt.scatter(X, Y, s=Area, alpha=0.7, c='yellow')
plt.scatter(x, y, s=area, alpha=0.3, c='purple')

savefig('Off_center_distributions.png')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.pa
set_connectionstyle("arc,angleA=0,armA=30,rad=10")
set_arrowstyle("Fancy,head_length=0.2")

plt.xlim([-1.2, 1.2])
plt.ylim([-1.2, 1.2])
circ = plt.Circle((0,0), radius=1.0, color='k')
ax.add_patch(circ)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-cf1835d2b44c> in <module>()
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(1, 1, 1)
# ----> 3 plt.patches.FancyArrowPatch
#       4 set_connectionstyle("arc,angleA=0,armA=30,rad=10")
#       5 set_arrowstyle("Fancy,head_length=0.2")
#
# AttributeError: 'module' object has no attribute 'patches'
