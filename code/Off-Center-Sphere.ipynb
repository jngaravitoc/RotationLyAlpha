# %% [markdown]
# # This notebook makes the data analysis in order to get Off-centred emission photons

# %%
# %pylab inline
import math
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# ### Uploading data with $N_{\gamma} = 10^5$

# %%
def definig_data(v, tau):
    #data path
    data_dir = "../data/Homogeneous/"
    filename_v_tau = "V"+v+tau+"HOM_in.ascii"
    filenameOUT_v_tau = "V"+v+tau+"HOM_out.ascii"
    
    #cleaning data
    datoslyman_v_tau = np.loadtxt(data_dir+filename_v_tau, comments = '#')
    datoslymanOUT_v_tau = np.loadtxt(data_dir+filenameOUT_v_tau, comments = '#')
    initpos=datoslymanOUT_v_tau[:,0]
    index_clean = where(~np.isnan(initpos))
    datoslymanOUT_v_tau = datoslymanOUT_v_tau[index_clean[0],:]
    datoslyman_v_tau = datoslyman_v_tau[index_clean[0],:]
    
    #Defining cuantites
    x_v_tau = datoslymanOUT_v_tau[:,6]
    X_v_tau = datoslyman_v_tau[:,0]
    Y_v_tau = datoslyman_v_tau[:,1]
    Z_v_tau = datoslyman_v_tau[:,2]
    kx_v_tau = datoslymanOUT_v_tau[:,3]
    ky_v_tau = datoslymanOUT_v_tau[:,4]
    kz_v_tau = datoslymanOUT_v_tau[:,5]
    
    norm = amax(np.sqrt(X_v_tau**2 + Y_v_tau**2 + Z_v_tau**2))
    X_v_tau = X_v_tau / norm
    Y_v_tau = Y_v_tau / norm
    Z_v_tau = Z_v_tau / norm
    
    return (x_v_tau, X_v_tau, Y_v_tau, Z_v_tau, kx_v_tau, ky_v_tau, kz_v_tau)

x_50_5t, X_50_5t, Y_50_5t, Z_50_5t, kx_50_5t, ky_50_5t, kz_50_5t = definig_data('50', '5t')

x_100_5t, X_100_5t, Y_100_5t, Z_100_5t, kx_100_5t, ky_100_5t, kz_100_5t = definig_data('100', '5t')
x_200_5t, X_200_5t, Y_200_5t, Z_200_5t, kx_200_5t, ky_200_5t, kz_200_5t = definig_data('200', '5t')
x_300_5t,X_300_5t,Y_300_5t, Z_300_5t, kx_300_5t, ky_300_5t, kz_300_5t = definig_data('300', '5t') 

x_50_6t, X_50_6t, Y_50_6t, Z_50_6t, kx_50_6t, ky_50_6t, kz_50_6t = definig_data('50', '6t')
x_100_6t, X_100_6t, Y_100_6t, Z_100_6t, kx_100_6t, ky_100_6t, kz_100_6t = definig_data('100', '6t')
x_200_6t, X_200_6t, Y_200_6t, Z_200_6t, kx_200_6t, ky_200_6t, kz_200_6t = definig_data('200', '6t')
x_300_6t, X_300_6t, Y_300_6t, Z_300_6t, kx_300_6t, ky_300_6t, kz_300_6t = definig_data('300', '6t')

x_50_7t, X_50_7t, Y_50_7t, Z_50_7t, kx_50_7t, ky_50_7t, kz_50_7t = definig_data('50', '7t')
x_100_7t, X_100_7t, Y_100_7t, Z_100_7t, kx_100_7t, ky_100_7t, kz_100_7t = definig_data('100', '7t')
x_200_7t, X_200_7t, Y_200_7t, Z_200_7t, kx_200_7t, ky_200_7t, kz_200_7t = definig_data('200', '7t')
x_300_7t, X_300_7t, Y_300_7t, Z_300_7t, kx_300_7t, ky_300_7t, kz_300_7t = definig_data('300', '7t')

# %% [markdown]
# ### Uploading data with $N_{\gamma} = 10^6$

# %%
def new_data(v, tau):
     #data path
    data_dir = "../data/Homogeneous/"
    filename_v_tau = "6RotatingV"+v+"Sphere"+ tau +"HOM_in.dat"
    filenameOUT_v_tau = "6RotatingV"+v+"Sphere"+ tau +"HOM_out.dat"
    
    #cleaning data
    datoslyman_v_tau = np.loadtxt(data_dir+filename_v_tau, comments = '#')
    datoslymanOUT_v_tau = np.loadtxt(data_dir+filenameOUT_v_tau, comments = '#')
    initpos=datoslymanOUT_v_tau[:,0]
    index_clean = where(~np.isnan(initpos))
    datoslymanOUT_v_tau = datoslymanOUT_v_tau[index_clean[0],:]
    datoslyman_v_tau = datoslyman_v_tau[index_clean[0],:]
    
    #Defining cuantites
    x_v_tau = datoslymanOUT_v_tau[:,6]
    X_v_tau = datoslyman_v_tau[:,0]
    Y_v_tau = datoslyman_v_tau[:,1]
    Z_v_tau = datoslyman_v_tau[:,2]
    kx_v_tau = datoslymanOUT_v_tau[:,3]
    ky_v_tau = datoslymanOUT_v_tau[:,4]
    kz_v_tau = datoslymanOUT_v_tau[:,5]
    
    norm = amax(np.sqrt(X_v_tau**2 + Y_v_tau**2 + Z_v_tau**2))
    X_v_tau = X_v_tau / norm
    Y_v_tau = Y_v_tau / norm
    Z_v_tau = Z_v_tau / norm
    
    return (x_v_tau, X_v_tau, Y_v_tau, Z_v_tau, kx_v_tau, ky_v_tau, kz_v_tau)

    

x_50_5t_6, X_50_5t_6, Y_50_5t_6, Z_50_5t_6, kx_50_5t_6, ky_50_5t_6, kz_50_5t_6 = new_data('50', '5t')
x_100_6t_6, X_100_6t_6, Y_100_6t_6, Z_100_6t_6, kx_100_6t_6, ky_100_6t_6, kz_100_6t_6 = new_data('100', '6t')
x_200_7t_6, X_200_7t_6, Y_200_7t_6, Z_200_7t_6, kx_200_7t_6, ky_200_7t_6, kz_200_7t_6 = new_data('200', '7t')

x_150_6t_6, X_150_6t_6, Y_150_6t_6, Z_150_6t_6, kx_150_6t_6, ky_150_6t_6, kz_150_6t_6 = new_data('150', '6t')

# %% [markdown]
# Hacer un scatter plot de la posicion inicial y la final para el off-centre

# %% [markdown]
# ### Fig.8 of the Paper

# %%
# Paper plot
x = linspace(0, 0, 12)
y = linspace(0, 12, 12)
t = linspace(0, 2*pi, 100)
t2 = linspace(pi/2.2, 0.0, 100)

font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 26,
        }

font1 = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 18,
        }
figure(num=None, figsize=(9.5,9))
plt.tick_params(axis='both', which='major', labelsize=18)

arrow(0, 0, 0, 1.1, head_width=0.05, head_length=0.05, fc='k', ec='k')
arrow(0, 0, 1.1, 0, head_width=0.05, head_length=0.05, fc='k', ec='k')
arrow(0.71, 0.71, 0.1, 0.4, head_width=0.05, head_length=0.05, fc='k', ec='k')
arrow(0.71, 0.71, 0.3, 0.0, head_width=0.05, head_length=0.05, fc='k', ec='k')

plt.text(0.77, 0.86, r'$\mathrm{\Theta}$', fontdict = font1)
plt.text(1.1, 0.05, r'$\mathrm{\hat{j}}$', fontdict = font)
plt.text(0.05, 1.1, r'$\mathrm{\hat{k}}$', fontdict = font)
plt.text(0.98, 0.75, r'$\mathrm{\hat{k_{obs}}}$', fontdict = font)
plt.text(0.86, 1.1, r'$\mathrm{\hat{k_{out}}}$', fontdict = font)

plt.plot(0.1*cos(t2)+0.72, 0.1*sin(t2)+0.72, c = 'k',linewidth = 1)
plt.plot(cos(t), sin(t), c = 'k',linewidth = 2)
plt.plot(0.5*cos(t)+0.5, 0.5*sin(t), c = 'k',linewidth = 1)
#plt.plot(0.5*cos(t)+0.25, 0.5*sin(t), c = 'k',linewidth = 1)
plt.plot(0.5*cos(t)-0.5, 0.5*sin(t), c = 'k',linewidth = 1, linestyle = '--')
#plt.plot(0.5*cos(t)-0.25, 0.5*sin(t), c = 'k',linewidth = 1, linestyle = '--')
plt.xlabel('$\mathrm{Y}$', fontsize = 35)
plt.ylabel('$\mathrm{Z}$', fontsize = 35)
#plt.title('Off-Center distribution', fontsize = 35)
plt.xlim([-1.2, 1.2])
plt.ylim([-1.2, 1.3])

savefig('OF_spheres.png')

# %% [markdown]
#                                                Fig.8

# %% [markdown]
# ### The following function select the photons locate in the off-centred distribution showed in Fig.8

# %%
def offcenter_ZZ(xV, XV, YV, ZV, kxV, kyV, kzV, V, R, D2R):
    selected = where( ((ZV <= np.sqrt(R**2 - (XV-D2R)**2 - YV**2))  & (ZV >= 0.0) ) |
                    ( (ZV >= -np.sqrt(R**2 - (XV-D2R)**2 - YV**2))  & (ZV <= 0.0)) )
    
    xV_selected = xV[selected]
    new_XV = XV[selected]
    new_YV = YV[selected]
    new_ZV = ZV[selected]
    #new_wV = weightV[selected]
    new_xV = xV[selected]
    new_kxV = kxV[selected]
    new_kyV = kyV[selected]
    new_kzV = kzV[selected]
    
    return [xV_selected, new_XV, new_YV, new_ZV, new_kxV, new_kyV, new_kzV, new_xV]

# %%
x50_new_1_5t, new_x50_1_5t, new_y50_1_5t, new_z50_1_5t, new_kx50_1_5t, new_ky50_1_5t, new_kz50_1_5t, new1_x50_5t = offcenter_ZZ(x_50_5t, X_50_5t, Y_50_5t, Z_50_5t, kx_50_5t, ky_50_5t, kz_50_5t, 50,  0.5, 0.5)
x50_new_2_5t, new_x50_2_5t, new_y50_2_5t, new_z50_2_5t, new_kx50_2_5t, new_ky50_2_5t, new_kz50_2_5t, new2_x50_5t = offcenter_ZZ(x_50_5t, X_50_5t, Y_50_5t, Z_50_5t, kx_50_5t, ky_50_5t, kz_50_5t, 50,  0.5, -0.5)
               
x100_new_1_5t, new_x100_1_5t, new_y100_1_5t, new_z100_1_5t, new_kx100_1_5t, new_ky100_1_5t, new_kz100_1_5t, new1_x100_5t = offcenter_ZZ(x_100_5t, X_100_5t, Y_100_5t, Z_100_5t, kx_100_5t, ky_100_5t, kz_100_5t, 100,  0.5, 0.5)
x100_new_2_5t, new_x100_2_5t, new_y100_2_5t, new_z100_2_5t, new_kx100_2_5t, new_ky100_2_5t, new_kz100_2_5t, new2_x100_5t = offcenter_ZZ(x_100_5t, X_100_5t, Y_100_5t, Z_100_5t, kx_100_5t, ky_100_5t, kz_100_5t, 100,  0.5, -0.5)

x200_new_1_5t, new_x200_1_5t, new_y200_1_5t, new_z200_1_5t, new_kx200_1_5t, new_ky200_1_5t, new_kz200_1_5t, new1_x200_5t = offcenter_ZZ(x_200_5t, X_200_5t, Y_200_5t, Z_200_5t, kx_200_5t, ky_200_5t, kz_200_5t, 200,  0.5, 0.5)
x200_new_2_5t, new_x200_2_5t, new_y200_2_5t, new_z200_2_5t, new_kx200_2_5t, new_ky200_2_5t, new_kz200_2_5t, new2_x200_5t = offcenter_ZZ(x_200_5t, X_200_5t, Y_200_5t, Z_200_5t, kx_200_5t, ky_200_5t, kz_200_5t, 200,  0.5, -0.5)
                   
x300_new_1_5t, new_x300_1_5t, new_y300_1_5t, new_z300_1_5t, new_kx300_1_5t, new_ky300_1_5t, new_kz300_1_5t, new1_x300_5t = offcenter_ZZ(x_300_5t, X_300_5t, Y_300_5t, Z_300_5t, kx_300_5t, ky_300_5t, kz_300_5t, 300,  0.5, 0.5)
x300_new_2_5t, new_x300_2_5t, new_y300_2_5t, new_z300_2_5t, new_kx300_2_5t, new_ky300_2_5t, new_kz300_2_5t, new2_x300_5t = offcenter_ZZ(x_300_5t, X_300_5t, Y_300_5t, Z_300_5t, kx_300_5t, ky_300_5t, kz_300_5t, 300,  0.5, -0.5)

x50_new_1_6t, new_x50_1_6t, new_y50_1_6t, new_z50_1_6t, new_kx50_1_6t, new_ky50_1_6t, new_kz50_1_6t, new1_x50_6t = offcenter_ZZ(x_50_6t, X_50_6t, Y_50_6t, Z_50_6t, kx_50_6t, ky_50_6t, kz_50_6t, 50,  0.5, 0.5)
x50_new_2_6t, new_x50_2_6t, new_y50_2_6t, new_z50_2_6t, new_kx50_2_6t, new_ky50_2_6t, new_kz50_2_6t, new2_x50_6t = offcenter_ZZ(x_50_6t, X_50_6t, Y_50_6t, Z_50_6t, kx_50_6t, ky_50_6t, kz_50_6t, 50,  0.5, -0.5)

x100_new_1_6t, new_x100_1_6t, new_y100_1_6t, new_z100_1_6t, new_kx100_1_6t, new_ky100_1_6t, new_kz100_1_6t, new1_x100_6t = offcenter_ZZ(x_100_6t, X_100_6t, Y_100_6t, Z_100_6t, kx_100_6t, ky_100_6t, kz_100_6t, 100,  0.5, 0.5)
x100_new_2_6t, new_x100_2_6t, new_y100_2_6t, new_z100_2_6t, new_kx100_2_6t, new_ky100_2_6t, new_kz100_2_6t, new2_x100_6t = offcenter_ZZ(x_100_6t, X_100_6t, Y_100_6t, Z_100_6t, kx_100_6t, ky_100_6t, kz_100_6t, 100,  0.5, -0.5)

x200_new_1_6t, new_x200_1_6t, new_y200_1_6t, new_z200_1_6t, new_kx200_1_6t, new_ky200_1_6t, new_kz200_1_6t, new1_x200_6t = offcenter_ZZ(x_200_6t, X_200_6t, Y_200_6t, Z_200_6t, kx_200_6t, ky_200_6t, kz_200_6t, 200,  0.5, 0.5)
x200_new_2_6t, new_x200_2_6t, new_y200_2_6t, new_z200_2_6t, new_kx200_2_6t, new_ky200_2_6t, new_kz200_2_6t, new2_x200_6t = offcenter_ZZ(x_200_6t, X_200_6t, Y_200_6t, Z_200_6t, kx_200_6t, ky_200_6t, kz_200_6t, 200,  0.5, -0.5)
                   

x300_new_1_6t, new_x300_1_6t, new_y300_1_6t, new_z300_1_6t, new_kx300_1_6t, new_ky300_1_6t, new_kz300_1_6t, new1_x300_6t = offcenter_ZZ(x_300_6t, X_300_6t, Y_300_6t, Z_300_6t, kx_300_6t, ky_300_6t, kz_300_6t, 300,  0.5, 0.5)
x300_new_2_6t, new_x300_2_6t, new_y300_2_6t, new_z300_2_6t, new_kx300_2_6t, new_ky300_2_6t, new_kz300_2_6t, new2_x300_6t = offcenter_ZZ(x_300_6t, X_300_6t, Y_300_6t, Z_300_6t, kx_300_6t, ky_300_6t, kz_300_6t, 300,  0.5, -0.5)

x50_new_1_7t, new_x50_1_7t, new_y50_1_7t, new_z50_1_7t, new_kx50_1_7t, new_ky50_1_7t, new_kz50_1_7t, new1_x50_7t = offcenter_ZZ(x_50_7t, X_50_7t, Y_50_7t, Z_50_7t, kx_50_7t, ky_50_7t, kz_50_7t, 50,  0.5, 0.5)
x50_new_2_7t, new_x50_2_7t, new_y50_2_7t, new_z50_2_7t, new_kx50_2_7t, new_ky50_2_7t, new_kz50_2_7t, new2_x50_7t = offcenter_ZZ(x_50_7t, X_50_7t, Y_50_7t, Z_50_7t, kx_50_7t, ky_50_7t, kz_50_7t, 50,  0.5, -0.5)

x100_new_1_7t, new_x100_1_7t, new_y100_1_7t, new_z100_1_7t, new_kx100_1_7t, new_ky100_1_7t, new_kz100_1_7t, new1_x100_7t = offcenter_ZZ(x_100_7t, X_100_7t, Y_100_7t, Z_100_7t, kx_100_7t, ky_100_7t, kz_100_7t, 100,  0.5, 0.5)
x100_new_2_7t, new_x100_2_7t, new_y100_2_7t, new_z100_2_7t, new_kx100_2_7t, new_ky100_2_7t, new_kz100_2_7t, new2_x100_7t = offcenter_ZZ(x_100_7t, X_100_7t, Y_100_7t, Z_100_7t, kx_100_7t, ky_100_7t, kz_100_7t, 100,  0.5, -0.5)

x200_new_1_7t, new_x200_1_7t, new_y200_1_7t, new_z200_1_7t, new_kx200_1_7t, new_ky200_1_7t, new_kz200_1_7t, new1_x200_7t = offcenter_ZZ(x_200_7t, X_200_7t, Y_200_7t, Z_200_7t, kx_200_7t, ky_200_7t, kz_200_7t, 200,  0.5, 0.5)
x200_new_2_7t, new_x200_2_7t, new_y200_2_7t, new_z200_2_7t, new_kx200_2_7t, new_ky200_2_7t, new_kz200_2_7t, new2_x200_7t = offcenter_ZZ(x_200_7t, X_200_7t, Y_200_7t, Z_200_7t, kx_200_7t, ky_200_7t, kz_200_7t, 200,  0.5, -0.5)
 
x300_new_1_7t, new_x300_1_7t, new_y300_1_7t, new_z300_1_7t, new_kx300_1_7t, new_ky300_1_7t, new_kz300_1_7t, new1_x300_7t = offcenter_ZZ(x_300_7t, X_300_7t, Y_300_7t, Z_300_7t, kx_300_7t, ky_300_7t, kz_300_7t, 300,  0.5, 0.5)
x300_new_2_7t, new_x300_2_7t, new_y300_2_7t, new_z300_2_7t, new_kx300_2_7t, new_ky300_2_7t, new_kz300_2_7t, new2_x300_7t = offcenter_ZZ(x_300_7t, X_300_7t, Y_300_7t, Z_300_7t, kx_300_7t, ky_300_7t, kz_300_7t, 300,  0.5, -0.5)

# New models with N_h = 10**6

x50_new_1_5t_6_5, new_x50_1_5t_6_5, new_y50_1_5t_6_5, new_z50_1_5t_6_5, new_kx50_1_5t_6_5, new_ky50_1_5t_6_5, new_kz50_1_5t_6_5, new1_x50_5t_6_5 = offcenter_ZZ(x_50_5t_6, X_50_5t_6, Y_50_5t_6, Z_50_5t_6, kx_50_5t_6, ky_50_5t_6, kz_50_5t_6, 50,  0.5, 0.5)
x50_new_2_5t_6_5, new_x50_2_5t_6_5, new_y50_2_5t_6_5, new_z50_2_5t_6_5, new_kx50_2_5t_6_5, new_ky50_2_5t_6_5, new_kz50_2_5t_6_5, new2_x50_5t_6_5 = offcenter_ZZ(x_50_5t_6, X_50_5t_6, Y_50_5t_6, Z_50_5t_6, kx_50_5t_6, ky_50_5t_6, kz_50_5t_6, 50,  0.5, -0.5)

x100_new_1_6t_6_5, new_x100_1_6t_6_5, new_y100_1_6t_6_5, new_z100_1_6t_6_5, new_kx100_1_6t_6_5, new_ky100_1_6t_6_5, new_kz100_1_6t_6_5, new1_x100_6t_6_5 = offcenter_ZZ(x_100_6t_6, X_100_6t_6, Y_100_6t_6, Z_100_6t_6, kx_100_6t_6, ky_100_6t_6, kz_100_6t_6, 100,  0.5, 0.5)
x100_new_2_6t_6_5, new_x100_2_6t_6_5, new_y100_2_6t_6_5, new_z100_2_6t_6_5, new_kx100_2_6t_6_5, new_ky100_2_6t_6_5, new_kz100_2_6t_6_5, new2_x100_6t_6_5 = offcenter_ZZ(x_100_6t_6, X_100_6t_6, Y_100_6t_6, Z_100_6t_6, kx_100_6t_6, ky_100_6t_6, kz_100_6t_6, 100,  0.5, -0.5)

x200_new_1_7t_6_5, new_x200_1_7t_6_5, new_y200_1_7t_6_5, new_z200_1_7t_6_5, new_kx200_1_7t_6_5, new_ky200_1_7t_6_5, new_kz200_1_7t_6_5, new1_x200_7t_6_5 = offcenter_ZZ(x_200_7t_6, X_200_7t_6, Y_200_7t_6, Z_200_7t_6, kx_200_7t_6, ky_200_7t_6, kz_200_7t_6, 200,  0.5, 0.5)
x200_new_2_7t_6_5, new_x200_2_7t_6_5, new_y200_2_7t_6_5, new_z200_2_7t_6_5, new_kx200_2_7t_6_5, new_ky200_2_7t_6_5, new_kz200_2_7t_6_5, new2_x200_7t_6_5 = offcenter_ZZ(x_200_7t_6, X_200_7t_6, Y_200_7t_6, Z_200_7t_6, kx_200_7t_6, ky_200_7t_6, kz_200_7t_6, 200,  0.5, -0.5)

x50_new_1_5t_6_25, new_x50_1_5t_6_25, new_y50_1_5t_6_25, new_z50_1_5t_6_25, new_kx50_1_5t_6_25, new_ky50_1_5t_6_25, new_kz50_1_5t_6_25, new1_x50_5t_6_25 = offcenter_ZZ(x_50_5t_6, X_50_5t_6, Y_50_5t_6, Z_50_5t_6, kx_50_5t_6, ky_50_5t_6, kz_50_5t_6, 50,  0.5, 0.25)
x50_new_2_5t_6_25, new_x50_2_5t_6_25, new_y50_2_5t_6_25, new_z50_2_5t_6_25, new_kx50_2_5t_6_25, new_ky50_2_5t_6_25, new_kz50_2_5t_6_25, new2_x50_5t_6_25 = offcenter_ZZ(x_50_5t_6, X_50_5t_6, Y_50_5t_6, Z_50_5t_6, kx_50_5t_6, ky_50_5t_6, kz_50_5t_6, 50,  0.5, -0.25)

x100_new_1_6t_6_25, new_x100_1_6t_6_25, new_y100_1_6t_6_25, new_z100_1_6t_6_25, new_kx100_1_6t_6_25, new_ky100_1_6t_6_25, new_kz100_1_6t_6_25, new1_x100_6t_6_25 = offcenter_ZZ(x_100_6t_6, X_100_6t_6, Y_100_6t_6, Z_100_6t_6, kx_100_6t_6, ky_100_6t_6, kz_100_6t_6, 100,  0.5, 0.25)
x100_new_2_6t_6_25, new_x100_2_6t_6_25, new_y100_2_6t_6_25, new_z100_2_6t_6_25, new_kx100_2_6t_6_25, new_ky100_2_6t_6_25, new_kz100_2_6t_6_25, new2_x100_6t_6_25 = offcenter_ZZ(x_100_6t_6, X_100_6t_6, Y_100_6t_6, Z_100_6t_6, kx_100_6t_6, ky_100_6t_6, kz_100_6t_6, 100,  0.5, -0.25)

x200_new_1_7t_6_25, new_x200_1_7t_6_25, new_y200_1_7t_6_25, new_z200_1_7t_6_25, new_kx200_1_7t_6_25, new_ky200_1_7t_6_25, new_kz200_1_7t_6_25, new1_x200_7t_6_25 = offcenter_ZZ(x_200_7t_6, X_200_7t_6, Y_200_7t_6, Z_200_7t_6, kx_200_7t_6, ky_200_7t_6, kz_200_7t_6, 200,  0.5, 0.25)
x200_new_2_7t_6_25, new_x200_2_7t_6_25, new_y200_2_7t_6_25, new_z200_2_7t_6_25, new_kx200_2_7t_6_25, new_ky200_2_7t_6_25, new_kz200_2_7t_6_25, new2_x200_7t_6_25 = offcenter_ZZ(x_200_7t_6, X_200_7t_6, Y_200_7t_6, Z_200_7t_6, kx_200_7t_6, ky_200_7t_6, kz_200_7t_6, 200,  0.5, -0.25)


# trying better 3-peaks

x100_new_1_6t_6_75, new_x100_1_6t_6_75, new_y100_1_6t_6_75, new_z100_1_6t_6_75, new_kx100_1_6t_6_75, new_ky100_1_6t_6_75, new_kz100_1_6t_6_75, new1_x100_6t_6_75 = offcenter_ZZ(x_100_6t_6, X_100_6t_6, Y_100_6t_6, Z_100_6t_6, kx_100_6t_6, ky_100_6t_6, kz_100_6t_6, 100,  0.3, 0.7)
x100_new_2_6t_6_75, new_x100_2_6t_6_75, new_y100_2_6t_6_75, new_z100_2_6t_6_75, new_kx100_2_6t_6_75, new_ky100_2_6t_6_75, new_kz100_2_6t_6_75, new2_x100_6t_6_75 = offcenter_ZZ(x_100_6t_6, X_100_6t_6, Y_100_6t_6, Z_100_6t_6, kx_100_6t_6, ky_100_6t_6, kz_100_6t_6, 100,  0.3, -0.7)

x150_new_1_6t_6_7, new_x150_1_6t_6_7, new_y150_1_6t_6_7, new_z150_1_6t_6_7, new_kx150_1_6t_6_7, new_ky150_1_6t_6_7, new_kz150_1_6t_6_7, new1_x150_6t_6_7 = offcenter_ZZ(x_150_6t_6, X_150_6t_6, Y_150_6t_6, Z_150_6t_6, kx_150_6t_6, ky_150_6t_6, kz_150_6t_6, 100,  0.3, 0.7)
x150_new_2_6t_6_7, new_x150_2_6t_6_7, new_y150_2_6t_6_7, new_z150_2_6t_6_7, new_kx150_2_6t_6_7, new_ky150_2_6t_6_7, new_kz150_2_6t_6_7, new2_x150_6t_6_7 = offcenter_ZZ(x_150_6t_6, X_150_6t_6, Y_150_6t_6, Z_150_6t_6, kx_150_6t_6, ky_150_6t_6, kz_150_6t_6, 100,  0.3, -0.7)

x150_new_1_6t_6_75, new_x150_1_6t_6_75, new_y150_1_6t_6_75, new_z150_1_6t_6_75, new_kx150_1_6t_6_75, new_ky150_1_6t_6_75, new_kz150_1_6t_6_75, new1_x150_6t_6_75 = offcenter_ZZ(x_150_6t_6, X_150_6t_6, Y_150_6t_6, Z_150_6t_6, kx_150_6t_6, ky_150_6t_6, kz_150_6t_6, 100,  0.25, 0.75)
x150_new_2_6t_6_75, new_x150_2_6t_6_75, new_y150_2_6t_6_75, new_z150_2_6t_6_75, new_kx150_2_6t_6_75, new_ky150_2_6t_6_75, new_kz150_2_6t_6_75, new2_x150_6t_6_75 = offcenter_ZZ(x_150_6t_6, X_150_6t_6, Y_150_6t_6, Z_150_6t_6, kx_150_6t_6, ky_150_6t_6, kz_150_6t_6, 100,  0.25, -0.75)

x150_new_1_6t_6_6, new_x150_1_6t_6_6, new_y150_1_6t_6_6, new_z150_1_6t_6_6, new_kx150_1_6t_6_6, new_ky150_1_6t_6_6, new_kz150_1_6t_6_6, new1_x150_6t_6_6 = offcenter_ZZ(x_150_6t_6, X_150_6t_6, Y_150_6t_6, Z_150_6t_6, kx_150_6t_6, ky_150_6t_6, kz_150_6t_6, 100,  0.4, 0.6)
x150_new_2_6t_6_6, new_x150_2_6t_6_6, new_y150_2_6t_6_6, new_z150_2_6t_6_6, new_kx150_2_6t_6_6, new_ky150_2_6t_6_6, new_kz150_2_6t_6_6, new2_x150_6t_6_6 = offcenter_ZZ(x_150_6t_6, X_150_6t_6, Y_150_6t_6, Z_150_6t_6, kx_150_6t_6, ky_150_6t_6, kz_150_6t_6, 100,  0.4, -0.6)

# %% [markdown]
# ### Now we make a Histogram of $\mu = \hat{k_{out}} \cdot \hat{k_{obs}}$

# %% [markdown]
# ### where $\hat{k_{obs}}$  represents the direction of the line of sight of the observer

# %%
# ZZ implementation
def get_mu_histo(kx, ky, kz, theta):
    R = np.array([0, sin(theta), cos(theta)])
    mu = kx*R[0] + ky*R[1] + kz*R[2]
    n_bins = 10
    delta_mu = 2.0/n_bins
    histo, bin_edges = histogram(mu, bins=n_bins)
    histo = 2.0*histo/(delta_mu*size(mu))
    return [histo, bin_edges, mu]

# %% [markdown]
# ### Plotting the $\mu$  histogram

# %%
a, b, c, = get_mu_histo(new_x100_1_6t, new_y100_1_6t, new_z100_1_6t, pi/2.0)
a1, b1, c1, = get_mu_histo(new_x100_2_6t, new_y100_2_6t, new_z100_2_6t, pi/2.0)

a2, b2, c2, = get_mu_histo(new_x200_1_6t, new_y200_1_6t, new_z200_1_6t, pi/2.0)
a3, b3, c3, = get_mu_histo(new_x200_2_6t, new_y200_2_6t, new_z200_2_6t, pi/2.0)

a4, b4, c4, = get_mu_histo(new_x300_1_5t, new_y300_1_5t, new_z300_1_5t, pi/2.0)
a5, b5, c5, = get_mu_histo(new_x300_2_5t, new_y300_2_5t, new_z300_2_5t, pi/2.0)

figure(num=None, figsize=(9.5,9.5))

#plot(b[0:-1], a, color = 'k', linewidth=2.5, linestyle = '-')
#plot(b1[0:-1], a1, color = 'r', linewidth=2.5, linestyle = '-')

plot(b2[0:-1], a2, color = 'k', linewidth=2.5, linestyle = '--')
#plot(b3[0:-1], a3, color = 'r', linewidth=2.5, linestyle='--')

plot(b4[0:-1], a4, color = 'k', linewidth=3.0, linestyle = ':')
#plot(b5[0:-1], a5, color = 'r', linewidth=3.0, linestyle = ':')
#plot(b3[0:-1], a2, color = 'r', linewidth=1.0)
#plot(b3[0:-1], a3, color = 'r', linewidth=3.0)

#plot(b4[0:-1], a4, color = 'g', linewidth=1.0)
#plot(b5[0:-1], a5, color = 'g', linewidth=3.0)

plt.title('$\mathrm{Homogeneous,}$ $\mathrm{N_\gamma = 10^6}$', fontsize=35)
plt.xlabel(r'$\mathrm{\mu}$', fontsize=35)
plt.ylabel(r'$\mathrm{F(\mu)}$', fontsize=35)
plt.tick_params(axis='both', which='major', labelsize=18)
#plt.xlim([-1.2, 1.2])
#plt.ylim([0.899, 1.09])
plt.legend(['$\mathrm{V_{max} = 50kms}$', '$\mathrm{V_{max}=100kms}$', '$\mathrm{V_{max}=200kms}$'], fontsize=20)
plt.text(-1.20, 1.078,r'$\mathrm{(Edge}$ $\mathrm{On)}$', fontsize =25)
plt.text(-0.28, 1.078,r'$\mathrm{(Face}$ $\mathrm{On)}$', fontsize =25)
savefig('mu_OC.png')

# %%
a, b, c, = get_mu_histo(new_kx50_1_5t_6, new_ky50_1_5t_6, new_kz50_1_5t_6, pi/2.0)
a1, b1, c1, = get_mu_histo(new_kx50_2_5t_6, new_ky50_2_5t_6, new_kz50_2_5t_6, pi/2.0)

a2, b2, c2, = get_mu_histo(new_kx100_1_6t_6, new_ky100_1_6t_6, new_kz100_1_6t_6, pi/2.0)
a3, b3, c3, = get_mu_histo(new_kx100_2_6t_6, new_ky100_2_6t_6, new_kz100_2_6t_6, pi/2.0)

a4, b4, c4, = get_mu_histo(new_kx200_1_7t_6, new_ky200_1_7t_6, new_kz200_1_7t_6, pi/2.0)
a5, b5, c5, = get_mu_histo(new_kx200_2_7t_6, new_ky200_2_7t_6, new_kz200_2_7t_6, pi/2.0)

figure(num=None, figsize=(9.5,9.5))

plot(b[0:-1], a, color = 'k', linewidth=2.5, linestyle = '-')
plot(b1[0:-1], a1, color = 'r', linewidth=2.5, linestyle = '-')

plot(b2[0:-1], a2, color = 'k', linewidth=2.5, linestyle = '--')
plot(b3[0:-1], a3, color = 'r', linewidth=2.5, linestyle='--')

plot(b4[0:-1], a4, color = 'k', linewidth=3.0, linestyle = ':')
plot(b5[0:-1], a5, color = 'r', linewidth=3.0, linestyle = ':')
#plot(b3[0:-1], a2, color = 'r', linewidth=1.0)
#plot(b3[0:-1], a3, color = 'r', linewidth=3.0)

#plot(b4[0:-1], a4, color = 'g', linewidth=1.0)
#plot(b5[0:-1], a5, color = 'g', linewidth=3.0)

plt.title('$\mathrm{Homogeneous,}$ $\mathrm{N_\gamma = 10^6}$', fontsize=35)
plt.xlabel(r'$\mathrm{\mu}$', fontsize=35)
plt.ylabel(r'$\mathrm{F(\mu)}$', fontsize=35)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.xlim([-1.2, 1.2])
plt.ylim([0.899, 1.09])
plt.legend(['$\mathrm{V_{max} = 50kms}$', '$\mathrm{V_{max}=100kms}$', '$\mathrm{V_{max}=200kms}$'], fontsize=20)
plt.text(-1.20, 1.078,r'$\mathrm{(Edge}$ $\mathrm{On)}$', fontsize =25)
plt.text(-0.28, 1.078,r'$\mathrm{(Face}$ $\mathrm{On)}$', fontsize =25)

# %% [markdown]
# For models witn $N\gamma = 10^6$
# we found the the mayor angular dependency is for location at $0.5R$
#
# And for higher velocities we found a greater viewing angle dependency

# %% [markdown]
# ### Now we select the photons escaping in some range of $\mu$

# %%
def get_mu(X, Y, Z, xV, a, b, theta):
    x, y, z = get_mu_histo(X, Y, Z, theta)
    selected = where((abs(z)>a) & (abs(z)<b))
    new_xV = xV[selected]
    return new_xV

# %%
new_x50_25_5t= get_mu(new_kx50_1_5t, new_ky50_1_5t, new_kz50_1_5t, x50_new_1_5t, 0.9, 1.0)
new_x50_m25_5t = get_mu(new_kx50_2_5t, new_ky50_2_5t, new_kz50_2_5t, x50_new_2_5t, 0.9, 1.0)

new_x50_25_6t= get_mu(new_kx50_1_6t, new_ky50_1_6t, new_kz50_1_6t, x50_new_1_6t, 0.9, 1.0)
new_x50_m25_6t = get_mu(new_kx50_2_6t, new_ky50_2_6t, new_kz50_2_6t, x50_new_2_6t, 0.9, 1.0)

new_x50_25_7t= get_mu(new_kx50_1_7t, new_ky50_1_7t, new_kz50_1_7t, x50_new_1_7t, 0.9, 1.0)
new_x50_m25_7t = get_mu(new_kx50_2_7t, new_ky50_2_7t, new_kz50_2_7t, x50_new_2_7t, 0.9, 1.0)



new_x100_25_5t= get_mu(new_kx100_1_5t, new_ky100_1_5t, new_kz100_1_5t, x100_new_1_5t, 0.9, 1.0)
new_x100_m25_5t = get_mu(new_kx100_2_5t, new_ky100_2_5t, new_kz100_2_5t, x100_new_2_5t, 0.9, 1.0)

new_x100_25_6t= get_mu(new_kx100_1_6t, new_ky100_1_6t, new_kz100_1_6t, x100_new_1_6t, 0.9, 1.0)
new_x100_m25_6t = get_mu(new_kx100_2_6t, new_ky100_2_6t, new_kz100_2_6t, x100_new_2_6t, 0.9, 1.0)

new_x100_25_7t = get_mu(new_kx100_1_7t, new_ky100_1_7t, new_kz100_1_7t, x100_new_1_7t, 0.9, 1.0)
new_x100_m25_7t = get_mu(new_kx100_2_7t, new_ky100_2_7t, new_kz100_2_7t, x100_new_2_7t, 0.9, 1.0)



new_x200_25_5t= get_mu(new_kx200_1_5t, new_ky200_1_5t, new_kz200_1_5t, x200_new_1_5t, 0.9, 1.0)
new_x200_m25_5t = get_mu(new_kx200_2_5t, new_ky200_2_5t, new_kz200_2_5t, x200_new_2_5t, 0.9, 1.0)

new_x200_25_6t= get_mu(new_kx200_1_6t, new_ky200_1_6t, new_kz200_1_6t, x200_new_1_6t, 0.9, 1.0)
new_x200_m25_6t = get_mu(new_kx200_2_6t, new_ky200_2_6t, new_kz200_2_6t, x200_new_2_6t, 0.9, 1.0)

new_x200_25_7t= get_mu(new_kx200_1_7t, new_ky200_1_7t, new_kz200_1_7t, x200_new_1_7t, 0.9, 1.0)
new_x200_m25_7t = get_mu(new_kx200_2_7t, new_ky200_2_7t, new_kz200_2_7t, x200_new_2_7t, 0.9, 1.0)


new_x300_25_5t= get_mu(new_kx300_1_5t, new_ky300_1_5t, new_kz300_1_5t, x300_new_1_5t, 0.9, 1.0)
new_x300_m25_5t = get_mu(new_kx300_2_5t, new_ky300_2_5t, new_kz300_2_5t, x300_new_2_5t, 0.9, 1.0)

new_x300_25_6t= get_mu(new_kx300_1_6t, new_ky300_1_6t, new_kz300_1_6t, x300_new_1_6t, 0.9, 1.0)
new_x300_m25_6t = get_mu(new_kx300_2_6t, new_ky300_2_6t, new_kz300_2_6t, x300_new_2_6t, 0.9, 1.0)

new_x300_25_7t= get_mu(new_kx300_1_7t, new_ky300_1_7t, new_kz300_1_7t, x300_new_1_7t, 0.9, 1.0)
new_x300_m25_7t = get_mu(new_kx300_2_7t, new_ky300_2_7t, new_kz300_2_7t, x300_new_2_7t, 0.9, 1.0)

# %% [raw]
# Models with N_h = 10**6 and \pm0.25 Off-center

# %%
"""
new_x50_25_5t_6= get_mu(new_kx50_1_5t_6_25, new_ky50_1_5t_6_25, new_kz50_1_5t_6_25, x50_new_1_5t_6_25, 0.9, 1.0)
new_x50_m25_5t_6 = get_mu(new_kx50_2_5t_6_25, new_ky50_2_5t_6_25, new_kz50_2_5t_6_25, x50_new_2_5t_6_25, 0.9, 1.0)

new_x100_25_6t_6= get_mu(new_kx100_1_6t_6_25, new_ky100_1_6t_6_25, new_kz100_1_6t_6_25, x100_new_1_6t_6_25, 0.9, 1.0)
new_x100_m25_6t_6 = get_mu(new_kx100_2_6t_6_25, new_ky100_2_6t_6_25, new_kz100_2_6t_6_25, x100_new_2_6t_6_25, 0.9, 1.0)
"""
new_x150_75_6t_6= get_mu(new_kx150_1_6t_6_75, new_ky150_1_6t_6_75, new_kz150_1_6t_6_75, x150_new_1_6t_6_75, 0.9, 1.0, 2*pi/3.0)
new_x150_m75_6t_6 = get_mu(new_kx150_2_6t_6_75, new_ky150_2_6t_6_75, new_kz150_2_6t_6_75, x150_new_2_6t_6_75, 0.9, 1.0, 2*pi/3.0)

new_x150_7_6t_6= get_mu(new_kx150_1_6t_6_7, new_ky150_1_6t_6_7, new_kz150_1_6t_6_7, x150_new_1_6t_6_7, 0.9, 1.0, 2*pi/3.0)
new_x150_m7_6t_6 = get_mu(new_kx150_2_6t_6_7, new_ky150_2_6t_6_7, new_kz150_2_6t_6_7, x150_new_2_6t_6_7, 0.9, 1.0, 2*pi/3.0)

new_x150_6_6t_6= get_mu(new_kx150_1_6t_6_6, new_ky150_1_6t_6_6, new_kz150_1_6t_6_6, x150_new_1_6t_6_6, 0.9, 1.0, 2*pi/3.0)
new_x150_m6_6t_6 = get_mu(new_kx150_2_6t_6_6, new_ky150_2_6t_6_6, new_kz150_2_6t_6_6, x150_new_2_6t_6_6, 0.9, 1.0, 2*pi/3.0)

"""
new_x200_25_7t_6= get_mu(new_kx200_1_7t_6_25, new_ky200_1_7t_6_25, new_kz200_1_7t_6_25, x200_new_1_7t_6_25, 0.9, 1.0)
new_x200_m25_7t_6 = get_mu(new_kx200_2_7t_6_25, new_ky200_2_7t_6_25, new_kz200_2_7t_6_25, x200_new_2_7t_6_25, 0.9, 1.0)
"""
# Out:
# '\nnew_x200_25_7t_6= get_mu(new_kx200_1_7t_6_25, new_ky200_1_7t_6_25, new_kz200_1_7t_6_25, x200_new_1_7t_6_25, 0.9, 1.0)\nnew_x200_m25_7t_6 = get_mu(new_kx200_2_7t_6_25, new_ky200_2_7t_6_25, new_kz200_2_7t_6_25, x200_new_2_7t_6_25, 0.9, 1.0)\n'

# %% [raw]
# lModels with N_h = 10**6 and \pm0.5 Off-center

# %%
new_x50_5_5t_6= get_mu(new_kx50_1_5t_6_5, new_ky50_1_5t_6_5, new_kz50_1_5t_6_5, x50_new_1_5t_6_5, 0.9, 1.0, 0.0)
new_x50_m5_5t_6 = get_mu(new_kx50_2_5t_6_5, new_ky50_2_5t_6_5, new_kz50_2_5t_6_5, x50_new_2_5t_6_5, 0.9, 1.0, 0.0)

new_x100_5_6t_6= get_mu(new_kx100_1_6t_6_5, new_ky100_1_6t_6_5, new_kz100_1_6t_6_5, x100_new_1_6t_6_5, 0.9, 1.0, 0.0)
new_x100_m5_6t_6 = get_mu(new_kx100_2_6t_6_5, new_ky100_2_6t_6_5, new_kz100_2_6t_6_5, x100_new_2_6t_6_5, 0.9, 1.0, 0.0)

new_x200_5_7t_6= get_mu(new_kx200_1_7t_6_5, new_ky200_1_7t_6_5, new_kz200_1_7t_6_5, x200_new_1_7t_6_5, 0.9, 1.0, pi/4.0)
new_x200_m5_7t_6 = get_mu(new_kx200_2_7t_6_5, new_ky200_2_7t_6_5, new_kz200_2_7t_6_5, x200_new_2_7t_6_5, 0.9, 1.0, pi/4.0)

# %% [raw]
# Models with N_h = 10**6 and \pm0.75 Off-center

# %%
new_x100_75_6t_6= get_mu(new_kx100_1_6t_6_75, new_ky100_1_6t_6_75, new_kz100_1_6t_6_75, x100_new_1_6t_6_75, 0.9, 1.0, pi/3.0)
new_x100_m75_6t_6 = get_mu(new_kx100_2_6t_6_75, new_ky100_2_6t_6_75, new_kz100_2_6t_6_75, x100_new_2_6t_6_75, 0.9, 1.0, pi/3.0)
print len(new_x100_75_6t_6)
# Out:
# 2090

# %% [markdown]
# ### Trying to find three-peaks

# %%
histo6, bin_edges6 = histogram(new_x150_6_6t_6, bins=20, density = True)
histo7, bin_edges7 = histogram(new_x150_7_6t_6, bins=20, density = True)
histo75, bin_edges75 = histogram(new_x150_75_6t_6, bins=20, density = True)
histom6, bin_edgesm6 = histogram(new_x150_m6_6t_6, bins=20, density = True)
histom7, bin_edgesm7 = histogram(new_x150_m7_6t_6, bins=20, density = True)
histom75, bin_edgesm75 = histogram(new_x150_m75_6t_6, bins=20, density = True)


figure(num=None, figsize=(9.5,9.5))
plt.tick_params(axis='both', which='major', labelsize=18)
plot(bin_edges6[0:-1], histo6, color = 'b', linewidth=2.0, linestyle = '-')
plot(bin_edges7[0:-1], histo7, color = 'r', linewidth=2.0, linestyle = '-')
plot(bin_edges75[0:-1], histo75, color = 'k', linewidth=2.0, linestyle = '-')
plot(bin_edgesm6[0:-1], histom6, color = 'b', linewidth=2.0, linestyle = '--')
plot(bin_edgesm7[0:-1], histom7, color = 'r', linewidth=2.0, linestyle = '--')
plot(bin_edgesm75[0:-1], histom75, color = 'k', linewidth=2.0, linestyle = '--')

#plot(bin_edges75m[0:-1], histo75m, color = 'k', linewidth=2.0, linestyle = '--')
plt.text(-25, 0.05, r'$\mathrm{\tau_H}=10^6$' , fontsize=20)
plt.text(-25, 0.047, r'$\mathrm{\tau_\gamma}=10^6$' , fontsize=20)
plt.text(-25, 0.043, r'$V_{max}=150$' , fontsize=20)
plt.text(-25, 0.039, r'$\mathrm{\theta}=2\pi/3.0$' , fontsize=20)
plt.legend([r'$\mathrm{+0.6}$', r'$\mathrm{+0.7}$', r'$\mathrm{+0.75}$', r'$\mathrm{-0.6}$', r'$\mathrm{-0.7}$', r'$\mathrm{-0.75}$'], fontsize=18)
plt.savefig('finding3peaks14.png')

# %% [raw]
# Comments:
#
# 3 peaks are apparently more noterious for spheres which are more far from the centre
#
# also is an equilibrium betweem V_max and T_h
#
# the angle theta (L.O.S) also is inportant.
#
#     what does it means the asymetry in the wings, appereantly is related with the L.O.S check with theta pi/3 and 2pi/3

# %% [markdown]
# ### Resulting Line Profiles

# %%
histo1, bin_edges1 = histogram(new_x50_25_5t, bins=15, density = True)
histo2, bin_edges2 = histogram(new_x50_m25_5t, bins=15, density = True)

histo3, bin_edges3 = histogram(new_x50_25_6t, bins=15, density= True)
histo4, bin_edges4 = histogram(new_x50_m25_6t, bins=15, density= True)

histo5, bin_edges5 = histogram(new_x50_25_7t, bins=15, density = True)
histo6, bin_edges6 = histogram(new_x50_m25_7t, bins=15, density= True)



histo7, bin_edges7 = histogram(new_x100_25_5t, bins=15, density = True)
histo8, bin_edges8 = histogram(new_x100_m25_5t, bins=15, density = True)

histo9, bin_edges9 = histogram(new_x100_25_6t, bins=15, density= True)
histo10, bin_edges10 = histogram(new_x100_m25_6t, bins=15, density= True)

histo11, bin_edges11 = histogram(new_x100_25_7t, bins=15, density = True)
histo12, bin_edges12 = histogram(new_x100_m25_7t, bins=15, density= True)



histo13, bin_edges13 = histogram(new_x200_25_5t, bins=15, density = True)
histo14, bin_edges14 = histogram(new_x200_m25_5t, bins=15, density = True)

histo15, bin_edges15 = histogram(new_x200_25_6t, bins=15, density= True)
histo16, bin_edges16 = histogram(new_x200_m25_6t, bins=15, density= True)

histo17, bin_edges17 = histogram(new_x200_25_7t, bins=15, density = True)
histo18, bin_edges18 = histogram(new_x200_m25_7t, bins=15, density= True)



histo19, bin_edges19 = histogram(new_x300_25_5t, bins=15, density = True)
histo20, bin_edges20 = histogram(new_x300_m25_5t, bins=15, density = True)

histo21, bin_edges21 = histogram(new_x300_25_6t, bins=15, density= True)
histo22, bin_edges22 = histogram(new_x300_m25_6t, bins=15, density= True)

histo23, bin_edges23 = histogram(new_x300_25_7t, bins=15, density = True)
histo24, bin_edges24 = histogram(new_x300_m25_7t, bins=15, density= True)

# New models with N_h = 10**6

histo25, bin_edges25 = histogram(new_x50_25_5t_6, bins=16, density = True)
histo26, bin_edges26 = histogram(new_x50_m25_5t_6, bins=16, density = True)

histo27, bin_edges27 = histogram(new_x100_25_6t_6, bins=16, density= True)
histo28, bin_edges28 = histogram(new_x100_m25_6t_6, bins=16, density= True)

histo29, bin_edges29 = histogram(new_x200_25_7t_6, bins=16, density = True)
histo30, bin_edges30 = histogram(new_x200_m25_7t_6, bins=16, density= True)

# %%
def example_plot(ax):
    new_tick_locations_1 = np.array([1/14.0, 3/14.0, 5/14.0, 7/14.0, 9/14.0, 11/14.0, 13/14.0])
    new_tick_locations_2 = np.array([0.0, 0.25, 0.5, 0.75, 1.0])
    new_tick_locations_3 = np.array([1/10.0, 3/10.0, 5/10.0, 0.7, 0.9])
        
    ax1.plot(bin_edges1[0:-1], histo1, color = 'green', linewidth=1.0, linestyle = '--')
    ax1.plot(bin_edges2[0:-1], histo2, color = 'm', linewidth=1.0)
    ax1.set_ylim([0, 0.085])
    ax1.set_xlim([-35, 35])
    ax1.tick_params(axis='both', which='major', labelsize=18)

    
    ax2.plot(bin_edges3[0:-1], histo3, color = 'green', linewidth=1.0, linestyle = '--')
    ax2.plot(bin_edges4[0:-1], histo4, color = 'm', linewidth=1.0)
    ax2.set_ylim([0, 0.065])
    ax2.set_xlim([-35, 35])
    ax2.tick_params(axis='both', which='major', labelsize=18)
    
    ax3.plot(bin_edges5[0:-1], histo5, color = 'green', linewidth=1.0, linestyle = '--')
    ax3.plot(bin_edges6[0:-1], histo6, color = 'm', linewidth=1.0)
    ax3.set_ylim([0, 0.045])
    ax3.set_xlim([-35, 35])
    ax3.tick_params(axis='both', which='major', labelsize=18)
    
    ax4.plot(bin_edges7[0:-1], histo7, color = 'green', linewidth=1.0, linestyle = '--')
    ax4.plot(bin_edges8[0:-1], histo8, color = 'm', linewidth=1.0)
    ax4.set_ylim([0, 0.08])
    ax4.set_xlim([-35, 35])
    ax4.tick_params(axis='both', which='major', labelsize=18)
    
    ax5.plot(bin_edges9[0:-1], histo9, color = 'green', linewidth=1.0, linestyle = '--')
    ax5.plot(bin_edges10[0:-1], histo10, color = 'm', linewidth=1.0)
    ax5.set_ylim([0, 0.050])
    ax5.set_xlim([-35, 35])
    ax5.tick_params(axis='both', which='major', labelsize=18)
        
    ax6.plot(bin_edges11[0:-1], histo11, color = 'green', linewidth=1.0, linestyle = '--')
    ax6.plot(bin_edges12[0:-1], histo12, color = 'm', linewidth=1.0)
    ax6.set_ylim([0, 0.035])
    ax6.set_xlim([-35, 35])
    ax6.tick_params(axis='both', which='major', labelsize=18)
    
    ax7.plot(bin_edges13[0:-1], histo13, color = 'green', linewidth=1.0, linestyle = '--')
    ax7.plot(bin_edges14[0:-1], histo14, color = 'm', linewidth=1.0)
    ax7.set_ylim([0, 0.055])
    ax7.set_xlim([-40, 40])
    ax7.tick_params(axis='both', which='major', labelsize=18)
    
    ax8.plot(bin_edges15[0:-1], histo15, color = 'green', linewidth=1.0, linestyle = '--')
    ax8.plot(bin_edges16[0:-1], histo16, color = 'm', linewidth=1.0)
    ax8.set_ylim([0, 0.04])
    ax8.set_xlim([-40, 40])
    ax8.tick_params(axis='both', which='major', labelsize=18)
    
    ax9.plot(bin_edges17[0:-1], histo17, color = 'green', linewidth=1.0, linestyle = '--')
    ax9.plot(bin_edges18[0:-1], histo18, color = 'm', linewidth=1.0)
    ax9.set_ylim([0, 0.025])
    ax9.set_xlim([-40, 40])
    ax9.tick_params(axis='both', which='major', labelsize=18)
    
    ax10.plot(bin_edges19[0:-1], histo19, color = 'green', linewidth=1.0, linestyle = '--')
    ax10.plot(bin_edges20[0:-1], histo20, color = 'm', linewidth=1.0)
    ax10.set_ylim([0, 0.04])
    ax10.set_xlim([-50, 50])
    ax10.tick_params(axis='both', which='major', labelsize=18)
    
    ax11.plot(bin_edges21[0:-1], histo21, color = 'green', linewidth=1.0, linestyle = '--')
    ax11.plot(bin_edges22[0:-1], histo22, color = 'm', linewidth=1.0)
    ax11.set_ylim([0, 0.035])
    ax11.set_xlim([-50, 50])
    ax11.tick_params(axis='both', which='major', labelsize=18)
    
    ax12.plot(bin_edges23[0:-1], histo23, color = 'green', linewidth=1.0, linestyle = '--')
    ax12.plot(bin_edges24[0:-1], histo24, color = 'm', linewidth=1.0)
    ax12.set_ylim([0, 0.025])
    ax12.set_xlim([-50, 50])
    ax12.tick_params(axis='both', which='major', labelsize=18)
    
    ax22 = ax1.twiny()
    ax23 = ax2.twiny()
    ax24 = ax3.twiny()
    ax25 = ax4.twiny()
    ax26 = ax5.twiny()
    ax27 = ax6.twiny()
    ax28 = ax7.twiny()
    ax29 = ax8.twiny()
    ax30 = ax9.twiny()
    ax31 = ax10.twiny()
    ax32 = ax11.twiny()
    ax33 = ax12.twiny()
    
    ax22.set_xticks(new_tick_locations_1)
    ax22.tick_params()
    ax22.set_xticklabels(['385.5',' ','128.5', '0', '-128.5', ' ', '-368.5'])
    ax22.tick_params(axis='both', which='major', labelsize=18)
    
    ax23.set_xticks(new_tick_locations_1)
    ax23.tick_params()
    ax23.set_xticklabels(['385.5',' ','128.5', '0', '-128.5', ' ', '-368.5'])
    ax23.tick_params(axis='both', which='major', labelsize=18)
    
    ax24.set_xticks(new_tick_locations_1)
    ax24.tick_params()
    ax24.set_xticklabels(['385.5',' ','128.5', '0', '-128.5',  ' ', '-368.5'])
    ax24.tick_params(axis='both', which='major', labelsize=18)
    
    ax25.set_xticks(new_tick_locations_1)
    ax25.tick_params()
    ax25.set_xticklabels(['385.5',' ','128.5', '0', '-128.5', ' ', '-368.5'])
    ax25.tick_params(axis='both', which='major', labelsize=18)
        
    ax26.set_xticks(new_tick_locations_1)
    ax26.tick_params()
    ax26.set_xticklabels(['385.5',' ','128.5', '0', '-128.5', ' ', '-368.5'])
    ax26.tick_params(axis='both', which='major', labelsize=18)
    
    ax27.set_xticks(new_tick_locations_1)
    ax27.tick_params()
    ax27.set_xticklabels(['385.5',' ','128.5', '0', '-128.5', ' ', '-368.5'])
    ax27.tick_params(axis='both', which='major', labelsize=18)
    
    ax28.set_xticks(new_tick_locations_2)
    ax28.tick_params()
    ax28.set_xticklabels(['514', '257', '0', '-257', '-514'])
    ax28.tick_params(axis='both', which='major', labelsize=18)
    
    ax29.set_xticks(new_tick_locations_2)
    ax29.tick_params()
    ax29.set_xticklabels(['514', '257', '0', '-257', '-514'])
    ax29.tick_params(axis='both', which='major', labelsize=18)
        
    ax30.set_xticks(new_tick_locations_2)
    ax30.tick_params()
    ax30.set_xticklabels(['514', '257', '0', '-257', '-514'])
    ax30.tick_params(axis='both', which='major', labelsize=18)
    
    ax31.set_xticks(new_tick_locations_3)
    ax31.tick_params()
    ax31.set_xticklabels(['514', '257', '0', '-257', '-514'])
    ax31.tick_params(axis='both', which='major', labelsize=18)
    
    ax32.set_xticks(new_tick_locations_3)
    ax32.tick_params()
    ax32.set_xticklabels(['514', '257', '0', '-257', '-514'])
    ax32.tick_params(axis='both', which='major', labelsize=18)
    
    ax33.set_xticks(new_tick_locations_3)
    ax33.tick_params()
    ax33.set_xticklabels(['514', '257', '0', '-257', '-514'])
    ax33.tick_params(axis='both', which='major', labelsize=18)
    

fig = plt.figure()
fig = figure(figsize=(20, 20))
fig.text(0.5, -0.02,r'$\mathrm{X}$', fontsize =25)
fig.text(0.5, 1,r'$\mathrm{Velocity}$ $\mathrm{(Km}$$\mathrm{s^{-1})}$', fontsize =25)
fig.text(-0.02, 0.6,r'$\mathrm{Intensity}$ $\mathrm{(Arbitrary}$ $\mathrm{Units)}$', fontsize =25, rotation=90.)

#                                           figures labels                                 #
#               first raw
fig.text(0.05, 0.93,r'$\mathrm{\tau=10^5}$', fontsize =25)
fig.text(0.05, 0.96,r'$\mathrm{V_{max}=50}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

fig.text(0.30, 0.93,r'$\mathrm{\tau=10^5}$', fontsize =25)
fig.text(0.30, 0.96,r'$\mathrm{V_{max}=100}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

fig.text(0.55, 0.93,r'$\mathrm{\tau=10^5}$', fontsize =25)
fig.text(0.55, 0.96,r'$\mathrm{V_{max}=200}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

fig.text(0.80, 0.93,r'$\mathrm{\tau=10^5}$', fontsize =25)
fig.text(0.80, 0.96,r'$\mathrm{V_{max}=300}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

#               second raw
fig.text(0.05, 0.60,r'$\mathrm{\tau=10^6}$', fontsize =25)
fig.text(0.05, 0.63,r'$\mathrm{V_{max}=50}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

fig.text(0.30, 0.60,r'$\mathrm{\tau=10^6}$', fontsize =25)
fig.text(0.30, 0.63,r'$\mathrm{V_{max}=100}$ $\mathrm{km} \mathrm{s^{-1}}$', fontsize =25)

fig.text(0.55, 0.60,r'$\mathrm{\tau=10^6}$', fontsize =25)
fig.text(0.55, 0.63,r'$\mathrm{V_{max}=200}$ $\mathrm{km} \mathrm{s^{-1}}$', fontsize =25)

fig.text(0.80, 0.60,r'$\mathrm{\tau=10^6}$', fontsize =25)
fig.text(0.80, 0.63,r'$\mathrm{V_{max}=300}$ $\mathrm{km} \mathrm{s^{-1}}$', fontsize =25)

#               third raw
fig.text(0.05, 0.27,r'$\mathrm{\tau=10^7}$', fontsize =25)
fig.text(0.05, 0.30,r'$\mathrm{V_{max}=50}$ $\mathrm{km} \mathrm{s^{-1}}$', fontsize =25)

fig.text(0.30, 0.27,r'$\mathrm{\tau=10^7}$', fontsize =25)
fig.text(0.30, 0.30,r'$\mathrm{V_{max}=100}$ $\mathrm{km} \mathrm{s^{-1}}$', fontsize =25)

fig.text(0.55, 0.27,r'$\mathrm{\tau=10^7}$', fontsize =25)
fig.text(0.55, 0.30,r'$\mathrm{V_{max}=200}$ $\mathrm{km} \mathrm{s^{-1}}$', fontsize =25)

fig.text(0.80, 0.27,r'$\mathrm{\tau=10^7}$', fontsize =25)
fig.text(0.80, 0.30,r'$\mathrm{V_{max}=300}$ $\mathrm{km} \mathrm{s^{-1}}$', fontsize =25)


ax1 = plt.subplot2grid((3, 4), (0, 0))
ax2 = plt.subplot2grid((3, 4), (1, 0))
ax3 = plt.subplot2grid((3, 4), (2, 0))
ax4 = plt.subplot2grid((3, 4), (0, 1))#, rowspan=2)
ax5 = plt.subplot2grid((3, 4), (1, 1))#, rowspan=2)
ax6 = plt.subplot2grid((3, 4), (2, 1))#, rowspan=2)
ax7 = plt.subplot2grid((3, 4), (0, 2))#, rowspan=2)
ax8 = plt.subplot2grid((3, 4), (1, 2))#, rowspan=2)
ax9 = plt.subplot2grid((3, 4), (2, 2))#, rowspan=2)
ax10 = plt.subplot2grid((3, 4), (0, 3))#, rowspan=2)
ax11 = plt.subplot2grid((3, 4), (1, 3))#, rowspan=2)
ax12 = plt.subplot2grid((3, 4), (2, 3))


example_plot(ax1)
example_plot(ax2)
example_plot(ax3)
example_plot(ax4)
example_plot(ax5)
example_plot(ax6)
example_plot(ax7)
example_plot(ax8)
example_plot(ax9)
example_plot(ax10)
example_plot(ax11)
example_plot(ax12)

plt.tight_layout()

plt.savefig('OC_profiles.png', bbox_inches='tight', pad_inches=0.5)
plt.show()

"""
12.85

new_tick_locations = np.array([192.7, 128.5, 64.25, 0, -64.25, -128.5, -192.7]) # (15, 10, 5, 0)
new_tick_locations = np.array([-514, -385.5, -257, 0]) # (40, 30, 20, 0)
"""
# Out:
# '\n12.85\n\nnew_tick_locations = np.array([192.7, 128.5, 64.25, 0, -64.25, -128.5, -192.7]) # (15, 10, 5, 0)\nnew_tick_locations = np.array([-514, -385.5, -257, 0]) # (40, 30, 20, 0)\n'

# %%
#figure(num=None, figsize=(9.5,9))
#plt.tick_params(axis='both', which='major', labelsize=18)

#fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)

def example_plot(ax):
    new_tick_locations = np.array([0.0, 0.25, 0.5, 0.75, 0.99])
    
    ax1.plot(bin_edges25[0:-1], histo25, color = 'green', linewidth=2.0)
    ax1.plot(bin_edges26[0:-1], histo26, color = 'red', linewidth=2.0)
    ax1.tick_params(axis='both', which='major', labelsize=18)
    ax1.set_ylim([0, 0.08])
    
    ax2.plot(bin_edges27[0:-1], histo27, color = 'green', linewidth=2.0)
    ax2.plot(bin_edges28[0:-1], histo28, color = 'red', linewidth=2.0)
    ax2.tick_params(axis='both', which='major', labelsize=18)
    ax2.set_ylim([0, 0.05])
    
    ax3.plot(bin_edges29[0:-1], histo29, color = 'green', linewidth=2.0)
    ax3.plot(bin_edges30[0:-1], histo30, color = 'red', linewidth=2.0)
    ax3.tick_params(axis='both', which='major', labelsize=18)
    ax3.set_ylim([0, 0.025])
    
    ax22 = ax1.twiny()
    ax23 = ax2.twiny()
    ax24 = ax3.twiny()
    
    ax22.set_xticks(new_tick_locations)
    ax22.tick_params()
    ax22.set_xticklabels(['192.7', '96.4', '0', '-96.4',  '-192.7'])
    ax22.tick_params(axis='both', which='major', labelsize=18)
    
    ax23.set_xticks(new_tick_locations)
    ax23.tick_params()
    ax23.set_xticklabels(['257','128.5', '0', '-128.5', '-257'])
    ax23.tick_params(axis='both', which='major', labelsize=18)
    
    ax24.set_xticks(new_tick_locations)
    ax24.tick_params()
    ax24.set_xticklabels(['514','257', '0', '-257',  '-514'])
    ax24.tick_params(axis='both', which='major', labelsize=18)
    
fig = plt.figure()
fig = figure(figsize=(22.5, 9.5))
fig.text(0.5, 0.04,r'$\mathrm{X}$', fontsize =25)
fig.text(0.5, 0.94,r'$\mathrm{Velocity}$ $\mathrm{(Km}$$\mathrm{s^{-1})}$', fontsize =25)
fig.text(0.08, 0.6,r'$\mathrm{Intensity}$ $\mathrm{(Arbitrary}$ $\mathrm{Units)}$', fontsize =25, rotation=90.)    

fig.text(0.15, 0.80,r'$\mathrm{\tau_{H}=10^5}$', fontsize =25)
fig.text(0.15, 0.84,r'$\mathrm{V_{max}=50}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

fig.text(0.42, 0.80,r'$\mathrm{\tau_{H}=10^6}$', fontsize =25)
fig.text(0.42, 0.84,r'$\mathrm{V_{max}=100}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

fig.text(0.70, 0.80,r'$\mathrm{\tau_{H}=10^7}$', fontsize =25)
fig.text(0.70, 0.84,r'$\mathrm{V_{max}=200}$ $\mathrm{km}\mathrm{s^{-1}}$', fontsize =25)

ax1 = plt.subplot2grid((1, 3), (0, 0))
ax2 = plt.subplot2grid((1, 3), (0, 1))
ax3 = plt.subplot2grid((1, 3), (0, 2))

example_plot(ax1)
example_plot(ax2)
example_plot(ax3)
#ax1.axvline(x=0.0,linewidth=2,color='k', linestyle='--')

#plt.xlim([-18.0, 18.0])
#plt.xlabel (r'$\mathrm{x}$', fontsize=35)
#plt.ylabel ('$\mathrm{Intensity}$ $\mathrm{(Arbitrary Units)}$', fontsize=35)
#plt.title (r'$\mu = (-0.1, 0.1), \theta = 0.0,\tau=10^5$, $\mathrm{v=100}$', fontsize=35)
#plt.legend([0.25, -0.25])
savefig('NewPanel_N6_atpm5.png')
