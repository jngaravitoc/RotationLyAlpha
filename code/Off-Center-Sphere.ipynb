# %%
# %pylab inline
from numpy import *
from pylab import *
import numpy as np
import math
import matplotlib.pyplot as plt

data_dir = "../data/Homogeneous/"
#filename200="V3007tHOM_in.ascii"
#filenameOUT200 = 'V3007tHOM_out.ascii'


filename50 = "V50HOM5t_in.ascii"
filenameOUT50 = 'V50HOM5t_out.ascii'

filename100 = 'V1005tHOM_in.ascii'
filenameOUT100 = 'V1005tHOM_out.ascii'

filename200 = 'V2007tHOM_in.ascii'
filenameOUT200 = 'V2007tHOM_out.ascii'

filename300 = 'V3005tHOM_in.ascii'
filenameOUT300 = 'V3005tHOM_out.ascii'



datoslyman50 = np.loadtxt(data_dir+filename50, comments = '#')
datoslymanOUT50 = np.loadtxt(data_dir+filenameOUT50, comments = '#')

datoslyman100 = np.loadtxt(data_dir+filename100, comments = '#')
datoslymanOUT100 = np.loadtxt(data_dir+filenameOUT100, comments = '#')

datoslyman200 = np.loadtxt(data_dir+filename200, comments = '#')
datoslymanOUT200 = np.loadtxt(data_dir+filenameOUT200, comments = '#')

datoslyman300 = np.loadtxt(data_dir+filename300, comments = '#')
datoslymanOUT300 = np.loadtxt(data_dir+filenameOUT300, comments = '#')




initpos=datoslymanOUT50[:,0]
index_clean = where(~np.isnan(initpos))
datoslymanOUT50 = datoslymanOUT50[index_clean[0],:]
datoslyman50 = datoslyman50[index_clean[0],:]

initpos=datoslymanOUT100[:,0]
index_clean = where(~np.isnan(initpos))
datoslymanOUT100 = datoslymanOUT100[index_clean[0],:]
datoslyman100 = datoslyman100[index_clean[0],:]

initpos=datoslymanOUT200[:,0]
index_clean = where(~np.isnan(initpos))
datoslymanOUT200 = datoslymanOUT200[index_clean[0],:]
datoslyman200 = datoslyman200[index_clean[0],:]

initpos=datoslymanOUT300[:,0]
index_clean = where(~np.isnan(initpos))
datoslymanOUT300 = datoslymanOUT300[index_clean[0],:]
datoslymanOUT300 = datoslymanOUT300[index_clean[0],:]


x50 = datoslymanOUT50[:,6]
X50 = datoslyman50[:,0]
Y50 = datoslyman50[:,1]
Z50 = datoslyman50[:,2]

kx50 = datoslymanOUT50[:,3]
ky50 = datoslymanOUT50[:,4]
kz50 = datoslymanOUT50[:,5]

x100 = datoslymanOUT100[:,6]
X100 = datoslyman100[:,0]
Y100 = datoslyman100[:,1]
Z100 = datoslyman100[:,2]

kx100 = datoslymanOUT100[:,3]
ky100 = datoslymanOUT100[:,4]
kz100 = datoslymanOUT100[:,5]

x200 = datoslymanOUT200[:,6]
X200 = datoslyman200[:,0]
Y200 = datoslyman200[:,1]
Z200 = datoslyman200[:,2]

kx200 = datoslymanOUT200[:,3]
ky200 = datoslymanOUT200[:,4]
kz200 = datoslymanOUT200[:,5]

x300 = datoslymanOUT300[:,6]
X300 = datoslyman300[:,0]
Y300 = datoslyman300[:,1]
Z300 = datoslyman300[:,2]

kx300 = datoslymanOUT300[:,3]
ky300 = datoslymanOUT300[:,4]
kz300 = datoslymanOUT300[:,5]

norm50 = sqrt(kx50**2 + ky50**2 + kz50**2)
norm_r50 = amax(sqrt(X50**2 + Y50**2 + Z50**2))
print "norma", norm_r50
X50 = X50/norm_r50
Y50 = Y50/norm_r50
Z50 = Z50/norm_r50

norm100 = sqrt(kx100**2 + ky100**2 + kz100**2)
norm_r100 = amax(sqrt(X100**2 + Y100**2 + Z100**2))
X100 = X100/norm_r100
Y100 = Y100/norm_r100
Z100 = Z100/norm_r100


norm200 = sqrt(kx200**2 + ky200**2 + kz200**2)
norm_r200 = amax(sqrt(X200**2 + Y200**2 + Z200**2))
X200 = X200/norm_r200
Y200 = Y200/norm_r200
Z200 = Z200/norm_r200

norm_r300 = amax(sqrt(X300**2 + Y300**2 + Z300**2))
X300 = X300/norm_r300
Y300 = Y300/norm_r300
Z300 = Z300/norm_r300

print amax(X50), amax(Y50), amin(X50), amin(Y50)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.
# norma 1.69606437621e+12
# 0.99543155536 0.996802375969 -0.998350666256 -0.996249920524

# %%
def offcenter_rectangular(xmin, xmax, ymin, ymax, zmin, zmax, XV, YV, ZV, xV, V, weightV):
    selected = where((XV >= xmin) &  (XV <= xmax) & 
                    (ZV >= zmin) & (ZV <=zmax) & 
                    (YV >= ymin) & (YV <= ymax))
    xV_selected = xV[selected]
    new_XV = XV[selected]
    new_YV = YV[selected]
    new_ZV = ZV[selected]
    new_wV = weightV[selected]
    new_x50 = x50[selected]
    return [xV_selected, new_XV, new_YV, new_ZV, new_wV, new_x50]
                      
x50_new_1, new_x50_1, new_y50_1, new_z50_1, new_w50_1, new1_x50 = offcenter_rec(-0.2, 0.2, 0.0, 0.3, -0.2, 0.2, X50, Y50, Z50, x50, 50, weight50)
x50_new_2, new_x50_2, new_y50_2, new_z50_2, new_w50_2, new2_x50 = offcenter_rec(-0.2, 0.2, 0.3, 0.6, -0.2, 0.2, X50, Y50, Z50, x50, 50, weight50)
x50_new_3, new_x50_3, new_y50_3, new_z50_3, new_w50_3, new3_x50 = offcenter_rec(-0.2, 0.2, 0.6, 0.9, -0.2, 0.2, X50, Y50, Z50, x50, 50, weight50)

x100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter_rec(-0.2, 0.2, 0.0, 0.3, -0.2, 0.2, X100, Y100, Z100, x100, 100, weight100)
x100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter_rec(-0.2, 0.2, 0.3, 0.6, -0.2, 0.2, X100, Y100, Z100, x100, 100, weight100)
x100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter_rec(-0.2, 0.2, 0.6, 0.9, -0.2, 0.2, X100, Y100, Z100, x100, 100, weight100)

x300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter_rec(-0.2, 0.2, 0.0, 0.3, -0.2, 0.2, X300, Y300, Z300, x300, 300, weight300)
x300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter_rec(-0.2, 0.2, 0.3, 0.6, -0.2, 0.2, X300, Y300, Z300, x300, 300, weight300)
x300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter_rec(-0.2, 0.2, 0.6, 0.9, -0.2, 0.2, X300, Y300, Z300, x300, 300, weight300)


print size(x50_new_1), size(new1_x50), size(x50)
# Out:
# 1169 1169 99968

# %%
def offcenter(XV, YV, ZV, xV, V, weightV, R, D2R):
    selected = where((XV <= np.sqrt((R**2 - YV**2 - ZV**2)) + D2R) & (YV <= np.sqrt(R**2 - (XV-D2R)**2 - ZV**2)) 
                    & (ZV <= np.sqrt(R**2 - (XV-D2R)**2 - YV**2)))
    
    xV_selected = xV[selected]
    new_XV = XV[selected]
    new_YV = YV[selected]
    new_ZV = ZV[selected]
    new_wV = weightV[selected]
    new_xV = xV[selected]
    return [xV_selected, new_XV, new_YV, new_ZV, new_wV, new_xV]
                      
x50_new_1, new_x50_1, new_y50_1, new_z50_1, new_w50_1, new1_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.2)
x50_new_2, new_x50_2, new_y50_2, new_z50_2, new_w50_2, new2_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.4)
x50_new_3, new_x50_3, new_y50_3, new_z50_3, new_w50_3, new3_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.6)
x50_new_4, new_x50_4, new_y50_4, new_z50_4, new_w50_4, new4_x50 = offcenter(X50, Y50, Z50, x50, 50, weight50, 0.2, 0.8)

x100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.2)
x100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.4)
x100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.6)
x100_new_4, new_x100_4, new_y100_4, new_z100_4, new_w100_4, new4_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.8)

x300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.2)
x300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.4)
x300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.6)
x300_new_4, new_x300_4, new_y300_4, new_z300_4, new_w300_4, new4_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.8)

# %%
def offcenter_ZZ(XV, YV, ZV, kxV, kyV, kzV, xV, V, R, D2R):
    selected = where((XV <= np.sqrt((R**2 - YV**2 - ZV**2)) + D2R) & (YV <= np.sqrt(R**2 - (XV-D2R)**2 - ZV**2)) 
                    & (ZV <= np.sqrt(R**2 - (XV-D2R)**2 - YV**2)))
    
    xV_selected = xV[selected]
    new_XV = XV[selected]
    new_YV = YV[selected]
    new_ZV = ZV[selected]
    #new_wV = weightV[selected]
    new_xV = xV[selected]
    new_kxV = kxV[selected]
    new_kyV = kyV[selected]
    new_kzV = kzV[selected]
    
    return [xV_selected, new_XV, new_YV, new_ZV, new_kxV, new_kyV, new_kzV, new_xV]
                      
x50_new_1, new_x50_1, new_y50_1, new_z50_1, new_kx50_1, new_ky50_1, new_kz50_1, new1_x50 = offcenter_ZZ(X50, Y50, Z50, kx50, ky50, kz50, x50, 50,  0.5, 0.25)
x50_new_3, new_x50_3, new_y50_3, new_z50_3, new_kx50_3, new_ky50_3, new_kz50_3, new3_x50 = offcenter_ZZ(X50, Y50, Z50, kx50, ky50, kz50, x50, 50,  0.5, -0.25)
x50_new_4, new_x50_4, new_y50_4, new_z50_4, new_kx50_4, new_ky50_4, new_kz50_4, new4_x50 = offcenter_ZZ(X50, Y50, Z50, kx50, ky50, kz50, x50, 50,  0.5, 0.5)

x100_new_1, new_x100_1, new_y100_1, new_z100_1, new_kx100_1, new_ky100_1, new_kz100_1, new1_x100 = offcenter_ZZ(X100, Y100, Z100, kx100, ky100, kz100, x100, 100,  0.5, 0.25)
x100_new_3, new_x100_3, new_y100_3, new_z100_3, new_kx100_3, new_ky100_3, new_kz100_3, new3_x100 = offcenter_ZZ(X100, Y100, Z100, kx100, ky100, kz100, x100, 100,  0.5, -0.25)

x200_new_1, new_x200_1, new_y200_1, new_z200_1, new_kx200_1, new_ky200_1, new_kz200_1, new1_x200 = offcenter_ZZ(X200, Y200, Z200, kx200, ky200, kz200, x200, 200,  0.5, 0.25)
x200_new_3, new_x200_3, new_y200_3, new_z200_3, new_kx200_3, new_ky200_3, new_kz200_3, new3_x200 = offcenter_ZZ(X200, Y200, Z200, kx200, ky200, kz200, x200, 200,  0.5, -0.25)
                                          
x300_new_1, new_x300_1, new_y300_1, new_z300_1, new_kx300_1, new_ky300_1, new_kz300_1, new1_x300 = offcenter_ZZ(X300, Y300, Z300, kx300, ky300, kz300, x300, 300,  0.5, 0.25)
x300_new_3, new_x300_3, new_y300_3, new_z300_3, new_kx300_3, new_ky300_3, new_kz300_3, new3_x300 = offcenter_ZZ(X300, Y300, Z300, kx300, ky300, kz300, x300, 300,  0.5, -0.25)



"""
x100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.2)
x100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.4)
x100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.6)
x100_new_4, new_x100_4, new_y100_4, new_z100_4, new_w100_4, new4_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.8)

x300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.2)
x300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.4)
x300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.6)
x300_new_4, new_x300_4, new_y300_4, new_z300_4, new_w300_4, new4_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.8)
"""
# Out:
# '\nx100_new_1, new_x100_1, new_y100_1, new_z100_1, new_w100_1, new1_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.2)\nx100_new_2, new_x100_2, new_y100_2, new_z100_2, new_w100_2, new2_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.4)\nx100_new_3, new_x100_3, new_y100_3, new_z100_3, new_w100_3, new3_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.6)\nx100_new_4, new_x100_4, new_y100_4, new_z100_4, new_w100_4, new4_x100 = offcenter(X100, Y100, Z100, x100, 100, weight100, 0.2, 0.8)\n\nx300_new_1, new_x300_1, new_y300_1, new_z300_1, new_w300_1, new1_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.2)\nx300_new_2, new_x300_2, new_y300_2, new_z300_2, new_w300_2, new2_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.4)\nx300_new_3, new_x300_3, new_y300_3, new_z300_3, new_w300_3, new3_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.6)\nx300_new_4, new_x300_4, new_y300_4, new_z300_4, new_w300_4, new4_x300 = offcenter(X300, Y300, Z300, x300, 300, weight300, 0.2, 0.8)\n'

# %%
plt.scatter(X50, Z50)
plt.scatter(new_x50_1, new_z50_1, color = 'r')

# %%
plt.scatter(Y50, Z50)
plt.scatter(new_y50_1, new_z50_1, color = 'r')

# %%
plt.scatter(X50, Y50)
plt.scatter(new_x50_1, new_y50_1, color = 'r')

# %%
# ZZ implementation
def get_mu_histo(kx, ky, kz, theta):
    R = np.array([0, sin(theta), cos(theta)])
    mu = kx*R[0] + ky*R[1] + kz*R[2]
    n_bins = 12
    delta_mu = 2.0/n_bins
    histo, bin_edges = histogram(mu, bins=n_bins)
    histo = 2.0*histo/(delta_mu*size(mu))
    return [histo, bin_edges, mu]

a, b, c, = get_mu_histo(new_kx50_1, new_ky50_1, new_kz50_1, 0.0)
a1, b1, c1, = get_mu_histo(new_kx50_4, new_ky50_4, new_kz50_4, 0.0)

figure(num=None, figsize=(9.5,9.5))

plot(b[0:-1], a, color = 'k', linewidth=1.0)
plot(b1[0:-1], a1, color = 'k', linewidth=3.0)

plt.title('$\mathrm{Homogeneous}$', fontsize=35)
plt.xlabel(r'$\mathrm{\mu}$', fontsize=35)
plt.ylabel(r'$\mathrm{F(\mu)}$', fontsize=35)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.ylim([0.92, 1.098])
plt.legend(['$\mathrm{R=0.25}$', '$\mathrm{R=0.5}$'], fontsize=20)

savefig('mu_OC.png')

# %%
def get_mu(X, Y, Z, xV, a, b):
    x, y, z = get_mu_histo(X, Y, Z, 0.0)
    selected = where((z>a) & (z<b))
    new_xV = xV[selected]
    return new_xV

new_x50_25_1_07 = get_mu(new_kx50_1, new_ky50_1, new_kz50_1, x50_new_1, 0.7, 1.0)
new_x50_m25_1_07 = get_mu(new_kx50_3, new_ky50_3, new_kz50_3, x50_new_3, 0.7, 1.0)
new_x50_25_07_05 = get_mu(new_kx50_1, new_ky50_1, new_kz50_1, x50_new_1, -0.1, 0.1)
new_x50_m25_07_05 = get_mu(new_kx50_3, new_ky50_3, new_kz50_3, x50_new_3, -0.1, 0.1)
new_x50_25_01_m01 = get_mu(new_kx50_1, new_ky50_1, new_kz50_1, x50_new_1, -0.1, 0.1)
new_x50_m25_01_m01 = get_mu(new_kx50_3, new_ky50_3, new_kz50_3, x50_new_3, -0.1, 0.1)
new_x50_25_10_m07 = get_mu(new_kx50_1, new_ky50_1, new_kz50_1, x50_new_1, -1.0, -0.7)
new_x50_m25_10_m07 = get_mu(new_kx50_3, new_ky50_3, new_kz50_3, x50_new_3, -1.0, -0.7)

new_x100_25_01_m01 = get_mu(new_kx100_1, new_ky100_1, new_kz100_1, x100_new_1, -0.1, 0.1)
new_x100_m25_01_m01 = get_mu(new_kx100_3, new_ky100_3, new_kz100_3, x100_new_3, -0.1, 0.1)

new_x200_25_01_m01 = get_mu(new_kx200_1, new_ky200_1, new_kz200_1, x200_new_1, -0.1, 0.1)
new_x200_m25_01_m01 = get_mu(new_kx200_3, new_ky200_3, new_kz200_3, x200_new_3, -0.1, 0.1)

new_x300_25_01_m01 = get_mu(new_kx300_1, new_ky300_1, new_kz300_1, x300_new_1, -1.0, -0.7)
new_x300_m25_01_m01 = get_mu(new_kx300_3, new_ky300_3, new_kz300_3, x300_new_3, -1.0, -0.7)

# %%
print len(new_x50_2)
figure(num=None, figsize=(9.5,9))

histo1, bin_edges1 = histogram(new_x50_25_1_07, bins=15)
histo2, bin_edges2 = histogram(new_x50_m25_1_07, bins=15)
histo3, bin_edges3 = histogram(new_x50_25_01_m01, bins=15, density = True)
histo4, bin_edges4 = histogram(new_x50_m25_01_m01, bins=15, density = True)
histo5, bin_edges5 = histogram(new_x50_25_10_m07, bins=15)
histo6, bin_edges6 = histogram(new_x50_m25_10_m07, bins=15)

histo7, bin_edges7 = histogram(new_x100_25_01_m01, bins=15, density=True)
histo8, bin_edges8 = histogram(new_x100_m25_01_m01, bins=15, density=True)

histo200, bin_edges200 = histogram(new_x200_25_01_m01, bins=12, density=True)
histo201, bin_edges201 = histogram(new_x200_m25_01_m01, bins=12, density=True)

histo9, bin_edges9 = histogram(new_x300_25_01_m01, bins=15, density=True)
histo10, bin_edges10 = histogram(new_x300_m25_01_m01, bins=15, density=True)

plt.tick_params(axis='both', which='major', labelsize=18)

#plot(bin_edges1[0:-1], histo1, color = 'b',linewidth=3.0)
#plot(bin_edges2[0:-1], histo2, color = 'green',linewidth=3.0)
#plot(bin_edges3[0:-1], histo3, color = 'green', linewidth=1.0)
#plot(bin_edges4[0:-1], histo4, color = 'red', linewidth=1.0)

plot(bin_edges7[0:-1], histo8, color = 'green', linewidth=2.0)
plot(bin_edges8[0:-1], histo7, color = 'red', linewidth=2.0)

#plot(bin_edges9[0:-1], histo9, color = 'green', linewidth=3.0)
#plot(bin_edges10[0:-1], histo10, color = 'red', linewidth=3.0)
#plot(bin_edges5[0:-1], histo5, color = 'k', linewidth=3.0)
#plot(bin_edges6[0:-1], histo6, color = 'purple', linewidth=3.0)


axvline(x=0.0,linewidth=2,color='k', linestyle='--')
plt.xlim([-18.0, 18.0])
plt.xlabel (r'$\mathrm{x}$', fontsize=35)
plt.ylabel ('$\mathrm{Intensity}$ $\mathrm{(Arbitrary Units)}$', fontsize=35)
plt.title (r'$\mu = (-0.1, 0.1), \theta = 0.0,\tau=10^5$, $\mathrm{v=100}$', fontsize=35)
plt.legend([-0.25, 0.25])
savefig('OC_5t_vel100.jpg')
# Out:
# 12695

# %%
x = linspace(0, 0, 12)
y = linspace(0, 12, 12)
t = linspace(0, 2*pi, 100)
t2 = linspace(0, pi/4, 100)

font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 26,
        }

font1 = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 18,
        }
figure(num=None, figsize=(9.5,9))
plt.tick_params(axis='both', which='major', labelsize=18)

arrow(0, 0, 0, 1.1, head_width=0.05, head_length=0.05, fc='k', ec='k')
arrow(0, 0, 1.1, 0, head_width=0.05, head_length=0.05, fc='k', ec='k')
arrow(0, 0, 1.0, 1.0, head_width=0.05, head_length=0.05, fc='k', ec='k')

plt.text(0.1, 0.05, r'$\mathrm{\theta}$', fontdict = font1)
plt.text(1.1, 0.05, r'$\mathrm{\hat{x}}$', fontdict = font)
plt.text(0.05, 1.1, r'$\mathrm{\hat{z}}$', fontdict = font)
plt.text(1.0, 1.05, r'$\mathrm{\hat{k}}$', fontdict = font)

plt.plot(0.1*cos(t2), 0.1*sin(t2), c = 'k',linewidth = 1)
plt.plot(cos(t), sin(t), c = 'k',linewidth = 2)
plt.plot(0.4*cos(t)+0.4, 0.4*sin(t), c = 'k',linewidth = 1)
plt.plot(0.4*cos(t)+0.6, 0.4*sin(t), c = 'k',linewidth = 1)
plt.plot(0.4*cos(t)-0.4, 0.4*sin(t), c = 'k',linewidth = 1, linestyle = '--')
plt.plot(0.4*cos(t)-0.6, 0.4*sin(t), c = 'k',linewidth = 1, linestyle = '--')
plt.xlabel('$\mathrm{X}$', fontsize = 35)
plt.ylabel('$\mathrm{Z}$', fontsize = 35)
#plt.title('Off-Center distribution', fontsize = 35)
plt.xlim([-1.2, 1.2])
plt.ylim([-1.2, 1.3])

savefig('OF_spheres.png')

# %%
arrow?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-c19cf09eb407> in <module>()
# ----> 1 FancyArrow
#
# NameError: name 'FancyArrow' is not defined
