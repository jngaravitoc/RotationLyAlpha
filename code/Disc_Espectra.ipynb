# %%
# %pylab inline
font = {'size':20, 'family':'serif'}
matplotlib.rc('font', **font)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# #Reading Data

# %%
datav0_in = loadtxt("../data/Homogeneous/RotatingV0Sphere5tHOM_in.ascii")
datav0_out = loadtxt("../data/Homogeneous/RotatingV0Sphere5tHOM_out.ascii")
datav300_in = loadtxt("../data/Homogeneous/RotatingV300Sphere5tHOM_in.ascii")
datav300_out = loadtxt("../data/Homogeneous/RotatingV300Sphere5tHOM_out.ascii")

# %% [markdown]
# #Defining Quantities

# %%
x0_in = datav0_in[:,0]
y0_in = datav0_in[:,1]
z0_in = datav0_in[:,2]
X0_in = datav0_in[:,6]

x0_out = datav0_in[:,0]
y0_out = datav0_in[:,1]
z0_out = datav0_in[:,2]
X0_out = datav0_out[:,6]

x300_in = datav300_in[:,0]
y300_in = datav300_in[:,1]
z300_in = datav300_in[:,2]
X300_in = datav300_in[:,6]

x300_out = datav300_in[:,0]
y300_out = datav300_in[:,1]
z300_out = datav300_in[:,2]
X300_out = datav300_out[:,6]

# %%
fig = figure(figsize=(15, 5))
fig.subplots_adjust(hspace=0.00, wspace=0.23, top=0.98, right=0.95, bottom=0.05)

ax = fig.add_subplot(131)
ax1 = fig.add_subplot(132)
ax2 = fig.add_subplot(133)

ax.scatter(x0_in, y0_in)
ax1.scatter(x0_in, z0_in)
ax2.scatter(y0_in, z0_in)

# %%
fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.00, wspace=0.23, top=0.98, right=0.95, bottom=0.05)

ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)
ax.hist(X0_in, bins=30)
ax1.hist(X0_out, bins=30)
ax.set_title("Inupt Spctra")
ax1.set_title("Output Spectra")

# %% [markdown]
# # definiendo la escala del disco, lo hice tomando como referencia la MW

# %%
diameter = amax(z0_in) - amin(z0_in)
print diameter
thickness = 2*(diameter/100.0)
print thickness
# Out:
# 3.375061e+12
# 67501220000.0

# %% [markdown]
# #Seleccionando el disco

# %%
index = where(abs(z0_in) < thickness)

x0_in_disc = x0_in[index]
y0_in_disc = y0_in[index]
z0_in_disc = z0_in[index]
X0_out_disc = X0_out[index]

x300_in_disc = x300_in[index]
y300_in_disc = y300_in[index]
z300_in_disc = z300_in[index]
X300_out_disc = X300_out[index]

# %%
fig = figure(figsize=(15, 5))
fig.subplots_adjust(hspace=0.00, wspace=0.23, top=0.98, right=0.95, bottom=0.05)

ax = fig.add_subplot(131)
ax1 = fig.add_subplot(132)
ax2 = fig.add_subplot(133)

ax.scatter(x0_in_disc, y0_in_disc)
ax1.scatter(x0_in_disc, z0_in_disc)
ax2.scatter(y0_in_disc, z0_in_disc)

# %%
print "Numero de fotones dentro del disco: ", len(z0_in_disc), "Número de fotones en la esfera: ", len(z0_in)
# Out:
# Numero de fotones dentro del disco:  6125 Número de fotones en la esfera:  99936

# %% [markdown]
# # Espectro de la esfera vs Disco

# %%
fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.00, wspace=0.23, top=0.98, right=0.95, bottom=0.05)

ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)
ax.hist(X300_out, bins=30, normed=True)
ax1.hist(X300_out_disc, bins=30, normed=True)
ax.set_title("$Sphere\ Spctra, v=300 km\ s^{-1}$")
ax1.set_title("$Disc\ Spectra, v=300 km\ s^{-1}$")
