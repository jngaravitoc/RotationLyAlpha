# %%
from pylab import *
import numpy


data_path = "/home/Nicolas-Garavito/"
data_dir="Dropbox/github/RotationLyAlpha/data/raw_data/new_data/RUN_02/"
filename="V3005tHOM_out.ascii"

datoslyman = np.loadtxt(data_path+data_dir+filename, comments = '#')

x = datoslyman[:,6]
scatt = datoslyman[:,8]

plt.autoscale_on=True

plt.ylim([0,16])

fig = plt.figure
plt.subplot(121)
hist,xedges,yedges = numpy.histogram2d(x,log(scatt),bins=20,range=[[-15,0],[0,16]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1] ]
imshow(hist.T,extent=extent,interpolation='nearest',origin='lower')
#colorbar()
#savefig ('2dHistogram50t5HOM.png')
plt.subplot(122)
hist,xedges,yedges = numpy.histogram2d(x,log(scatt),bins=20,range=[[0,15],[0,16]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1] ]
imshow(hist.T,extent=extent,interpolation='nearest',origin='lower')
cax = fig.addcolorbar()
show()

# %%
data_path = "/home/Nicolas-Garavito/"
data_dir="Dropbox/github/RotationLyAlpha/data/raw_data/new_data/RUN_02/"
filename="V1005tHOM_out.ascii"

datoslyman = np.loadtxt(data_path+data_dir+filename, comments = '#')

x = datoslyman[:,6]
scatt = datoslyman[:,8]

plt.autoscale_on=True

#plt.ylim([0,16])

figure(num=None, figsize=(9.5,9))

hist,xedges,yedges = numpy.histogram2d(x,log(scatt),bins=35,range=[[-15,15],[0,16]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1] ]
imshow(hist.T,extent=[-20,20,0,40],interpolation='nearest',origin='lower')
colorbar()
#savefig ('2dHistogram50t5HOM.png')
show()

# %%
#this is a test

#data dir
data_path = "/home/Nicolas-Garavito/"
data_dir="Dropbox/github/RotationLyAlpha/data/raw_data/new_data/RUN_02/"
filename="V505tHOM_out.ascii"
filename2='V3005tHOM_out.ascii'

datoslyman = np.loadtxt(data_path+data_dir+filename, comments = '#')
datoslyman2 = np.loadtxt(data_path+data_dir+filename2, comments = '#')

# Definig data

x = datoslyman[:,6]
x2 = datoslyman2[:,6]

scatt = datoslyman[:,8]
scatt2 = datoslyman2[:,8]


figure(num=None, figsize=(9,9))

#plot 50Km/s


#plt.xlim([-20, 20])
hist,xedges,yedges = numpy.histogram2d(x,log(scatt),bins=35,range=[[-15,15],[0,16]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1] ]
xlabel(r'$X_{m}$')
ylabel(r'$N_{scatt}$')
imshow(hist.T,extent=extent,interpolation='nearest',origin='lower')
colorbar()
savefig('test.png')
show()
figure(num=None, figsize=(9.5,9))

#plot 300km/s

hist,xedges,yedges = numpy.histogram2d(x2,log(scatt2),bins=25,range=[[-20,20],[0,18]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1] ]
pcolor(hist.T)
colorbar()

savefig('test2.png')

show()

# %%
fig = plt.figure()
#fig(num=None, figsize=(9.5,9))
fig.subplots_adjust(wspace=0,hspace=0)

# subplot number 1
ax1 = fig.add_subplot(1,2,1,aspect='equal',xlim=[-25,25],ylim=[0,20])
plt.title(r"$50$",fontsize="18")
plt.xlabel(r"$X_{m}$",fontsize="15")
plt.ylabel(r"$<N_{scatt}>$",rotation='horizontal',fontsize="15")
plt.xlim([-20,20])
hist,xedges,yedges = numpy.histogram2d(x,log(scatt),bins=45,range=[[-25,25],[0,20]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1] ]
plt.xticks([-20, -15, -10, -5, 0, 5, 10, 15, 20])
plt.imshow(hist.T,extent=[-20, 20, 0, 20],interpolation='nearest',origin='lower')
#plt.axhline(y=0,linewidth=2,color='k',linestyle="--")
plt.axvline(x=0,linewidth=2,color='k',linestyle="--")
#e1 = patches.Ellipse((0,0),2,2,color='white')
#ax1.add_patch(e1)

# subplot number 2
ax2 = fig.add_subplot(1,2,2,sharey=ax1,xlim=[-25,25],ylim=[0,20])
plt.title("$300$",fontsize="18")
plt.xlabel(r"$X_{m}$",fontsize="15")
#ax2.yaxis.set_major_formatter( NullFormatter() )
#plt.axhline(y=0,linewidth=2,color='k',linestyle="--")
plt.axvline(x=0,linewidth=2,color='k',linestyle="--")
hist,xedges,yedges = numpy.histogram2d(x2,log(scatt2),bins=45,range=[[-25,25],[0,20]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1] ]
plt.imshow(hist.T,extent=[-20,20,0,20],interpolation='nearest',origin='lower')


# subplot for colorbar
ax3 = fig.add_subplot(1,1,1)
ax3.axis('off')
cbar = plt.colorbar(ax=ax2)

plt.show()
