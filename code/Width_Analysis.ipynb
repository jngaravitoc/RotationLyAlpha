# %%
from numpy import * 
from pylab import *
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
#Central and Homogeneous, vs Rotational vrlocity
t7 = (12.13,15, 21.24, 27.73)                 # 90
t6 = (5.99, 9.397, 13.99, 15.1756)
t5 = (3.21, 6.311, 7.462, 9.00)

t7hom = (13.51, 15.63308, 21.4569, 23.6824)                 # 90
t6hom = (5.42, 9.68307, 12.074, 14.0267)
t5hom = (3.92, 6.425, 7.929, 9.889)

v = (0, 100, 200, 300)

figure(num=None, figsize=(9.5,9))

p1, = plot(v,t7, '--ro', linewidth = 3.5)
p2, = plot(v,t6, '--b*', linewidth = 3.5)
p3, = plot(v,t5, '--gp', linewidth = 3.5)

p1hom, = plot(v,t7hom, '-ro',linewidth = 3.5)
p2hom, = plot(v,t6hom, '-b*', linewidth = 3.5)
p3hom, = plot(v,t5hom, '-gp', linewidth = 3.5)

legend([p1, p2, p3], [r'$\tau=10^{7}$',r'$\tau=10^{6}$', r'$\tau=10^{5}$'], loc ='upper center', ncol=3, fontsize=20)
xlabel (r'$\mathrm{V_{max}}$ ($\mathrm{km}$ $\mathrm{s^{-1}}$)', fontsize=35)
ylabel ( r'$\mathrm{W_{1/2}} \mathrm{(\AA)}$', fontsize=35)
#plt.title ('Central', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.xlim([-25,350])
plt.ylim([0,32])

savefig("WidthvsVmax.png")

# %%
# Width Analysis in Velocitis units

t7 = np.array([12.13, 15, 21.24, 27.73])                 # 90 theta
t6 = np.array([5.99, 9.397, 13.99, 15.1756])
t5 = np.array([3.21, 6.311, 7.462, 9.00])

t7hom = np.array([13.51, 15.63308, 21.4569, 23.6824])                 # 90 theta 
t6hom = np.array([5.42, 9.68307, 12.074, 14.0267])
t5hom = np.array([3.92, 6.425, 7.929, 9.889])

#New widths in V terms

Wt7 = t7*12.85
Wt6 = t6*12.85
Wt5 = t5*12.85

Wt7hom = t7hom*12.85
Wt6hom = t6hom*12.85
Wt5hom = t5hom*12.85

v = (0, 100, 200, 300)

figure(num=None, figsize=(9.5,9))

p1, = plot(v,Wt7, '--ro', linewidth = 3.5)
p2, = plot(v,Wt6, '--b*', linewidth = 3.5)
p3, = plot(v,Wt5, '--gp', linewidth = 3.5)

p1hom, = plot(v,Wt7hom, '-ro',linewidth = 3.5)
p2hom, = plot(v,Wt6hom, '-b*', linewidth = 3.5)
p3hom, = plot(v,Wt5hom, '-gp', linewidth = 3.5)

legend([p1, p2, p3], [r'$\tau=10^{7}$',r'$\tau=10^{6}$', r'$\tau=10^{5}$'], loc ='upper center', ncol=3, fontsize=20)
xlabel (r'$\mathrm{V_{max}}$ ($\mathrm{km}$ $\mathrm{s^{-1}}$)', fontsize=35)
ylabel ( r'$\mathrm{W_{1/2}} \mathrm{(kms^{-1})}$', fontsize=35)
#plt.title ('Central', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.xlim([-20, 320])
plt.ylim([0, 400])
savefig("WidthVvsVmax.png")
plt.show()

# %%
x = (12.13,12.93, 15, 21.24, 27.73)                 # 90
y = (12.13,12.72, 14.48, 18.51, 25.79)              # 45
z = (12.13,12.62 , 14.07, 16.9, 24.69)              # 0

v = (0,50, 100, 200, 300)


p1, = plot(v,z, 'ro')
p2, = plot(v,y, 'o')
p3, = plot(v,x, 'go')


legend([p1, p2, p3], ["0 Deg","45 Deg", "90 Deg"], loc = 'upper left')
plt.xlabel (r'Rotational Velocity ($\frac{Km}{s}$)', fontsize=18)
plt.ylabel ( 'Width ($\AA$)', fontsize=18)
plt.title (r'Central, $Log_{10}\tau=7$', fontsize=18)
plt.xlim([-25,350])
plt.ylim([10,29])

savefig('Width7Central.png')

plt.show()

# %%
x = (13.51, 13.701385, 15.63308, 21.4569, 23.6824)                 # 90
y = (13.51, 13.70195, 15.1733, 20.24, 22.99)              # 45
z = (13.51, 13.4325 , 14.7607, 18.869, 22.3030)              # 0

v = (0,50, 100, 200, 300)


p1, = plot(v,z, 'ro')
p2, = plot(v,y, 'o')
p3, = plot(v,x, 'go')


legend([p1, p2, p3], ["0 Deg","45 Deg", "90 Deg"], loc = 'upper left')
plt.xlabel (r'Rotational Velocity ($\frac{Km}{s}$)', fontsize=18)
plt.ylabel ( 'Width ($\AA$)', fontsize=18)
plt.title (r'Homogeneous, $Log_{10}\tau=7$', fontsize=18)
plt.xlim([-25,350])

savefig('Width7Homogeneous.png')

plt.show()

# %%
x = (5.99,6.6633, 9.397, 13.99, 15.1756)            # 90
y = (5.99,6.612, 8.43, 13.026, 14.348)              # 45
z = (5.99,6.517 , 7.748, 12.38, 13.796)             # 0

v = (0,50, 100, 200, 300)


p1, = plot(v,z, 'ro')
p2, = plot(v,y, 'o')
p3, = plot(v,x, 'go')


legend([p1, p2, p3], ["0 Deg","45 Deg", "90 Deg"], loc = 'upper left')
plt.xlabel (r'Rotational Velocity ($\frac{Km}{s}$)', fontsize=18)
plt.ylabel ( 'Width ($\AA$)', fontsize=18)
plt.title (r'Central, $Log_{10}\tau=6$', fontsize=18)
plt.xlim([-25,350])

savefig('Width6.png')

plt.show()

# %%
x = (5.42,6.735, 9.68307, 12.074, 14.0267)            # 90
y = (5.42,6.779, 10.0248, 12.6921, 14.1416)           # 45
z = (5.42,6.435 , 9.68, 12.0024, 13.9117)             # 0

v = (0, 50, 100, 200, 300)


p1, = plot(v,z, 'ro')
p2, = plot(v,y, 'o')
p3, = plot(v,x, 'go')


legend([p1, p2, p3], ["0 Deg","45 Deg", "90 Deg"], loc = 'upper left')
plt.xlabel (r'Rotational Velocity ($\frac{Km}{s}$)', fontsize=18)
plt.ylabel ( 'Width ($\AA$)', fontsize=18)
plt.title (r'Homogeneous, $Log_{10}\tau=6$', fontsize=18)
plt.xlim([-25,350])

savefig('Width6HOM.png')

plt.show()

# %%
x = (3.92,5.64, 6.425, 7.929, 9.889)             # 90
y = (3.92,5.468, 6.516, 8.294, 10.223)           # 45
z = (3.92,5.34, 6.38, 7.929, 10.233)             # 0

v = (0,50, 100, 200, 300)


p1, = plot(v,z, 'ro')
p2, = plot(v,y, 'o')
p3, = plot(v,x, 'go')


legend([p1, p2, p3], ["0 Deg","45 Deg", "90 Deg"], loc = 'upper left')
plt.xlabel (r'Rotational Velocity ($\frac{Km}{s}$)', fontsize=18)
plt.ylabel ( 'Width ($\AA$)', fontsize=18)
plt.title (r'Homogeneous, $Log_{10}\tau=5$', fontsize=18)
plt.xlim([-25,350])

savefig('Width5HOM.png')

plt.show()
# este comportamiento diferente al de las otras grafica es debido a que le medicion no es tan precisa ya que las diferencias son muy pequñas y deberia estar dentro de los errores.

# %%
x = (3.21,4.15, 6.311, 7.462, 9.00)             # 90
y = (3.21,4.107, 6.111, 7, 7.839)                # 45
z = (3.21,3.907 , 5.621, 6.607, 7.2)             # 0

v = (0, 50, 100, 200, 300)


p1, = plot(v,z, 'ro')
p2, = plot(v,y, 'o')
p3, = plot(v,x, 'go')


legend([p1, p2, p3], ["0 Deg","45 Deg", "90 Deg"], loc = 'upper left')
plt.xlabel (r'Rotational Velocity ($\frac{Km}{s}$)', fontsize=18)
plt.ylabel ( 'Width ($\AA$)', fontsize=18)
plt.title (r'Central, $Log_{10}\tau=5$', fontsize=18)
plt.xlim([-25,350])
plt.ylim([2,10])

savefig('Width5.png')

plt.show()

# %%
# ALL THIS IS FOR THE CENTRAL DISTRIBUTION
# grafica de ancho vs cos theta Rotating50Sphere7t

ancho50=[13.035,13.035,12.93,12.93,12.8283,12.8283,12.82,12.62]

# grafica de ancho vs cos theta Rotating100Sphere7t

ancho100=[14.89,14.69,14.79,14.48,13.55,14.17,14.17,14.069]


# grafica de ancho vs cos theta  Rotating200Sphere7t
ancho200=[21.84,20.69,19.54,18.6,17.82,17.35,17.24,16.89]
costheta = [cos(pi/2), cos(2*pi/5), cos(pi/3), cos(pi/4), cos(pi/6), cos(pi/9), cos(pi/18), cos(0)]

# 90, 72, 60, 45, 30, 20 , 10, 0.
# grafica de ancho vs cos theta  Rotating300Sphere7t

ancho300=[27.82, 27.17,26.5,25.66,25.10,25.52,25.52,24.7]
costheta = [cos(pi/2), cos(2*pi/5), cos(pi/3), cos(pi/4), cos(pi/6), cos(pi/9), cos(pi/18), cos(0)]

plt.xlabel (r'$\cos(\theta)$', fontsize=18)
plt.ylabel ( 'Width $\AA$', fontsize=15)
plt.title ('Central distribution', fontsize = 15)
plt.xlim([-0.1,1.1])
plt.ylim([12,32])
#print cos


p1, = plot(costheta,ancho300 ,'ro')
p2, = plot(costheta, ancho200, 'go')
p3, = plot(costheta, ancho100, 'bo')
p4, = plot(costheta, ancho50, 'yo')

legend([p1, p2, p3,p4], ["300km/s","200km/s", "100km/s", "50Km/s"], loc = 'center left', bbox_to_anchor=(0.2, 0.9),
          ncol=2, fancybox=True,shadow=True)
savefig('WidthvsThetaDifSpeeds.png')

# %%
# ALL THIS IS FOR THE HOMOGENEOUS DISTRIBUTION
# grafica de ancho vs cos theta Rotating50Sphere7t

ancho50=[13.68195,13.51799,13.51799,13.6,13.51799,13.51799,13.42609,13.42609]

# grafica de ancho vs cos theta Rotating100Sphere7t

ancho100=[15.54112,15.35716,15.1733,14.89733,14.89744,14.62153,14.62153,14.62153]


# grafica de ancho vs cos theta  Rotating200Sphere7t
ancho200=[21.4869,21.4869,21.1765,20.7627,19.3143,19.1074,19.1074,19.10]
costheta = [cos(pi/2), cos(2*pi/5), cos(pi/3), cos(pi/4), cos(pi/6), cos(pi/9), cos(pi/18), cos(0)]

# 90, 72, 60, 45, 30, 20 , 10, 0.
# grafica de ancho vs cos theta  Rotating300Sphere7t

ancho300=[23.6824, 23.6824,23.3375,23.1076,22.7628,22.418,22.3030,22.3030]
costheta = [cos(pi/2), cos(2*pi/5), cos(pi/3), cos(pi/4), cos(pi/6), cos(pi/9), cos(pi/18), cos(0)]

plt.xlabel (r'$\cos(\theta)$', fontsize =18)
plt.ylabel ( 'Width $\AA$', fontsize=15)
plt.title ('Homogeneous distribution', fontsize = 15)
plt.xlim([-0.1,1.1])
plt.ylim([12,29])
#print cos


p1, = plot(costheta,ancho300 ,'ro')
p2, = plot(costheta, ancho200, 'go')
p3, = plot(costheta, ancho100, 'bo')
p4, = plot(costheta, ancho50, 'yo')

legend([p1, p2, p3,p4], ["300km/s","200km/s", "100km/s", "50Km/s"], loc = 'upper left', bbox_to_anchor=(0.2, 1.0),
          ncol=2, fancybox=True,shadow=True)
savefig('WidthvsThetaDifSpeedsHOM.png')

# %%
# ALL THIS IS FOR THE CENTRAL DISTRIBUTION
# grafica de ancho vs cos theta para una velocidad fija (200) y diferentes optical depths 

ancho200t5=[7.40503,7.23418,7.12028,6.94943,6.77858,6.72162,6.72162,6.72162]

ancho200t6=[14.0721,13.83,13.4284,12.9456,12.6237,12.4628,12.3823,12.38923]

ancho200t7=[21.84,20.69,19.54,18.6,17.82,17.35,17.24,16.89]

costheta = [cos(pi/2), cos(2*pi/5), cos(pi/3), cos(pi/4), cos(pi/6), cos(pi/9), cos(pi/18), cos(0)]

plt.xlabel (r'$\cos(\theta)$', fontsize =18)
plt.ylabel ( 'Width $\AA$', fontsize=15)
plt.title ('Central distribution', fontsize = 15)

plt.xlim([-0.1,1.1])
plt.ylim([6,27])

p1, = plot(costheta,ancho200t5 ,'ro')
p2, = plot(costheta, ancho200t6, 'go')
p3, = plot(costheta, ancho200t7, 'bo')

legend([p1, p2, p3], [r"$Log_{10} \tau=5$", r"$Log_{10} \tau=6$",r"$Log_{10} \tau=7$"], loc = 'upper left', bbox_to_anchor=(0.2, 1.0),
          ncol=2, fancybox=True,shadow=True)
savefig('WidthvsThetaDifOD.png')

# %%
# ALL THIS IS FOR THE HOMOGENEOUS DISTRIBUTION
# grafica de ancho vs cos theta Rotating200Sphere5t

ancho200t5hom=[7.92984, 7.92984, 8.11208, 8.29432, 8.20320, 8.29432,8.29432, 8.20320]

# grafica de ancho vs cos theta Rotating200Sphere6t
#espectros raros 
ancho200t6hom=[11.5886, 11.7955, 12.0714, 12.0714, 12.0024, 11.9334, 11.9334, 11.7955]


# grafica de ancho vs cos theta  Rotating200Sphere7t
ancho200t7hom=[21.4869,21.4869,21.1765,20.7627,19.3143,19.1074,19.1074,19.10]
costheta = [cos(pi/2), cos(2*pi/5), cos(pi/3), cos(pi/4), cos(pi/6), cos(pi/9), cos(pi/18), cos(0)]

pol = np.polyfit(ancho200t7hom, costheta, 3)


plt.xlabel (r'$\cos(\theta)$', fontsize =18)
plt.ylabel ( 'Width $\AA$', fontsize=15)
plt.title ('Homogeneous distribution', fontsize = 15)
plt.xlim([-0.1,1.1])
plt.ylim([6,28])
#print cos
#box = ax.get_position()
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

p1, = plot(costheta, ancho200t5hom ,'ro')
p2, = plot(costheta, ancho200t6hom, 'go')
p3, = plot(costheta, ancho200t7hom, 'bo')

legend([p1, p2, p3], [r"$Log_{10} \tau=5$", r"$Log_{10} \tau=6$",r"$Log_{10} \tau=7$"], loc = 'upper left', bbox_to_anchor=(0.2, 1.0),
          ncol=2, fancybox=True,shadow=True)
#savefig('WidthvsThetaDifODHOM.png')

print pol
# Out:
# [ -2.40749968e-01   1.45150824e+01  -2.91684196e+02   1.95441497e+03]

# %%
#polynomial regression in order to compare with Verhamme et al (I change the costheta order) Homogeneous

ancho200t5hom=[7.92984, 7.92984, 8.11208, 8.29432, 8.20320, 8.29432,8.29432, 8.20320]
ancho200t6hom=[11.5886, 11.7955, 12.0714, 12.0714, 12.0024, 11.9334, 11.9334, 11.7955]
ancho200t7hom=[21.4869,21.4869,21.1765,20.7627,19.3143,19.1074,19.1074,19.10]
costheta = [cos(0), cos(pi/18,),cos(pi/9), cos(pi/6), cos(pi/4), cos(pi/3), cos(2*pi/5), cos(pi/2)]


pol5 = np.polyfit(ancho200t5hom, costheta, 4)
pol6 = np.polyfit(ancho200t6hom, costheta, 4)
pol7 = np.polyfit(ancho200t7hom, costheta, 4)

print pol7
# Out:
# [ -2.82114586e-01   2.32970823e+01  -7.21047000e+02   9.91280773e+03
#   -5.10746879e+04]
# /home/Nicolas-Garavito/Documents/yt-i686/lib/python2.7/site-packages/numpy/lib/polynomial.py:560: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
#polynomial regression in order to compare with Verhamme et al (I change the costheta order) Central

ancho200t5=[7.40503,7.23418,7.12028,6.94943,6.77858,6.72162,6.72162,6.72162]

ancho200t6=[14.0721,13.83,13.4284,12.9456,12.6237,12.4628,12.3823,12.38923]

ancho200t7=[21.84,20.69,19.54,18.6,17.82,17.35,17.24,16.89]
costheta = [cos(0), cos(pi/18,),cos(pi/9), cos(pi/6), cos(pi/4), cos(pi/3), cos(2*pi/5), cos(pi/2)]

pol5 = np.polyfit(ancho200t5, costheta, 4)
pol6 = np.polyfit(ancho200t6, costheta, 4)
pol7 = np.polyfit(ancho200t7, costheta, 4)

print pol5
# Out:
# [ -5.90750904e+01   1.67780490e+03  -1.78640298e+04   8.45097010e+04
#   -1.49877348e+05]

# %%
#Homogenous, vs Rotational velocity
t7hom = (13.51, 15.63308, 21.4569, 23.6824)                 # 90
t6hom = (5.42, 9.68307, 12.074, 14.0267)
t5hom = (3.92, 6.425, 7.929, 9.889)

v = (0, 100, 200, 300)


p1hom, = plot(v,t7hom, '-ro')
p2hom, = plot(v,t6hom, '-*')
p3hom, = plot(v,t5hom, '-gp')



legend([p1, p2, p3], [r'$\tau=10^{7}$',r'$\tau=10^{6}$', r'$\tau=10^{5}$'], loc ='upper left', ncol=3)
plt.xlabel (r'$V_{max}$ ($Kms^{-1}$)', fontsize=20)
plt.ylabel ( r'$W_{1/2} (\AA)$', fontsize=20)
plt.title ('Homogeneous', fontsize=20)
plt.xlim([-25,350])
plt.ylim([0,32])

savefig("WidthHomogeneous.png")
plt.show()

# %%
# ALL THIS IS FOR THE HOMOGENEOUS DISTRIBUTION
# grafica de ancho vs cos theta Rotating200Sphere5t
#metodo 1 es el normal midiendo el ancho a la altura media
#metodo 2 es cuando a la mitad de la altura la linea ya esta unida entonces se mide desde elcero hasta el ancho

ancho50t5hom = [5.673, 5.638, 5.604, 5.536, 5.468, 5.40]#estos se miden con el metodo 2
ancho100t5hom = [6.288, 6.379, 6.425, 6.425, 6.51, 6.425]#metodo2
ancho200t5hom = [7.838, 7.92, 8.02, 8.20, 8.29, 8.29]#metodo 2
ancho300t5hom = [9.77, 9.77, 9.77, 9.77, 9.88, 10.34]#metodo 2

# grafica de ancho vs cos theta Rotating200Sphere6t

ancho50t6hom = [7.06, 7.11, 7.06, 6.9, 6.77, 6.53]#metodo1
ancho100t6hom = [10.46, 10.34, 10.2894, 10.13, 9.91, 9.68]#metodo2
ancho200t6hom = [11.72, 11.72, 11.86, 12.2, 12.07, 11.79]#metodo2
ancho300t6hom = [13.68, 14.02, 14.02, 14.2566, 14.0267, 13.79]#metodo2

# grafica de ancho vs cos theta  Rotating200Sphere7t
ancho50t7hom = [13.609, 13.609, 13.51, 13.6, 13.61, 13.32 ]#metodo1
ancho100t7hom = [15.54, 15.4502, 15.26, 15.17, 14.897, 14.62]#metodo1
ancho200t7hom = [21.4869, 21.3834, 21.28, 21.07, 19.52, 19.10]#metodo2
ancho300t7hom = [23.68, 23.68, 23.33, 22.64, 22.64, 22.18]#metodo2

costheta = [cos(pi/2), cos(pi/2.294), cos(pi/2.71), cos(pi/3.3879), cos(pi/4.882), cos(0)]


plt.xlabel (r'$\cos(\theta)$', fontsize =20)
plt.ylabel ( r'$W_{1/2} (\AA)$', fontsize=20)
plt.title ('Homogeneous', fontsize = 20)
#plt.xlim([-0.1,1.1])
plt.ylim([0,30])


p1, = plot(costheta, ancho50t5hom ,'-r^', linewidth=1.5)
#p2, = plot(costheta, ancho100t5hom, '-go',linewidth=2.5)
#p3, = plot(costheta, ancho200t5hom, '-bx',linewidth=3.5)
p4, = plot(costheta, ancho300t5hom ,'-r*', linewidth=1.5)
p5, = plot(costheta, ancho50t6hom, ':b^', linewidth=3.0)
#p6, = plot(costheta, ancho100t6hom, ':bo', linewidth=2.5)
#p7, = plot(costheta, ancho200t6hom ,':rx',linewidth=3.5)
p8, = plot(costheta, ancho300t6hom, ':b*',linewidth=3.0)
p9, = plot(costheta, ancho50t7hom, '-.g^',linewidth=4.5)
#p10, = plot(costheta,ancho100t7hom ,'-.bo', linewidth=2.5)
#p11, = plot(costheta, ancho200t7hom, '-.bx', linewidth=3.5)
p12, = plot(costheta, ancho300t7hom, '-.g*', linewidth=4.5)

legend([p1, p5, p9], [r"$Log_{10} \tau=5$", r"$Log_{10} \tau=6$",r"$Log_{10} \tau=7$"], loc = 'upper left', ncol=3, fancybox=True,shadow=True)
          #ncol=2, fancybox=True,shadow=True)
savefig('WidthvsTheta.png')

#cos, 90, 78.46,66.42,53.13,36.87,0

# %%
# ALL THIS ISl
# All this is FOR THE CENTRAL DISTRIBUTION
# grafica de ancho vs cos theta Rotating200Sphere5t
#metodo 1 es el normal midiendo el ancho a la altura media
#metodo 2 es cuando a la mitad de la altura la linea ya esta unida entonces se mide desde elcero hasta el ancho

ancho50t5 = [3.89, 4.02, 4.13, 4.205, 4.32, 4.4]#metodo1
ancho100t5 = [5.58, 6.06, 6.13, 6.214, 6.281, 6.32]#metodo1
ancho200t5 = [6.7, 6.86, 6.96, 7.1825, 7.34, 7.71]#metodo 2
ancho300t5 = [7.43, 7.58, 8.03, 8.48, 8.74, 8.89]#metodo 2

# grafica de ancho vs cos theta Rotating200Sphere6t

ancho50t6 = [6.318, 6.454, 6.492, 6.58846, 6.58846, 6.54993 ]#metodo1
ancho100t6 = [7.660, 8.1443, 8.512, 8.94731, 9.07573, 9.20416]#metodo1
ancho200t6 = [12.42, 12.68, 13.1882, 13.5282, 13.8299, 13.8903]#metodo2
ancho300t6 = [13.9, 14.23, 14.55, 14.8299, 14.8299, 15.1748]#metodo2

# grafica de ancho vs cos theta  Rotating200Sphere7t
ancho50t7 = [12.56, 12.72, 12.802, 12.879, 12.72, 12.80]#metodo1
ancho100t7 = [14.19, 14.43, 14.6644, 14.6644, 14.81, 14.81]#metodo1
ancho200t7 = [16.98, 18.01, 18.70766, 19.65604, 20.86, 21.293]#metodo1
ancho300t7 = [24.62, 25.55, 26.176, 26.90, 27.41, 27.72]#metodo2

costheta = [cos(pi/2), cos(pi/2.294), cos(pi/2.71), cos(pi/3.3879), cos(pi/4.882), cos(0)]


plt.xlabel (r'$\cos(\theta)$', fontsize =20)
plt.ylabel (  r'$W_{1/2} (\AA)$', fontsize=20)
plt.title ('Central', fontsize = 20)
#plt.xlim([-0.1,1.1])
plt.ylim([0,35])


p1, = plot(costheta, ancho50t5 ,'-r^',linewidth=1.5)
#p2, = plot(costheta, ancho100t5, '-go',linewidth=2.5)
#p3, = plot(costheta, ancho200t5, '-bx',linewidth=3.5)
p4, = plot(costheta, ancho300t5 ,'-r*', linewidth=1.5)
p5, = plot(costheta, ancho50t6, ':b^', linewidth=3.0)
#p6, = plot(costheta, ancho100t6, ':bo', linewidth=2.5)
#p7, = plot(costheta, ancho200t6 ,':rx',linewidth=3.5)
p8, = plot(costheta, ancho300t6, ':b*',linewidth=3.0)
p9, = plot(costheta, ancho50t7, '-.g^',linewidth=4.5)
#p10, = plot(costheta,ancho100t7 ,'-.bo', linewidth=2.5)
#p11, = plot(costheta, ancho200t7, '-.bx', linewidth=3.5)
p12, = plot(costheta, ancho300t7, '-.g*', linewidth=4.5)

legend([p1, p5, p9], [r"$Log_{10} \tau=5$", r"$Log_{10} \tau=6$",r"$Log_{10} \tau=7$"], loc = 'upper left', ncol=3, fancybox=True,shadow=True)
savefig('WidthvsThetaCentral.png')

#cos, 90, 78.46,66.42,53.13,36.87,0

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0075866f904b> in <module>()
#       4     print point_x * scale, point_y * scale
#       5
# ----> 6 project_to_distance(2, 7, 4)
#
# <ipython-input-8-0075866f904b> in project_to_distance(point_x, point_y, distance)
#       1 def project_to_distance(point_x, point_y, distance):
# ----> 2     dist_to_origin = math.sqr(point_x ** 2 + point_y ** 2)
#       3     scale == distance / dist_to_origin
#       4     print point_x * scale, point_y * scale
#       5
#
# AttributeError: 'module' object has no attribute 'sqr'
