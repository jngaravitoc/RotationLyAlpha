# %%
#This notebook corresponds to section 4.  , Rotation effects...

from numpy import *
from pylab import *
import numpy as np
import math
import matplotlib.pyplot as plt

#1. Load the Data

data_path = "/home/Nicolas-Garavito/Dropbox/github/RotationLyAlpha/data/Homogeneous/"

filename0 = "V05tHOMDust_out.ascii"
filename = "Rotating100Sphere5tHOMDust.ascii"
filename2 = "Rotating200Sphere5tHOMDust.ascii"
filename3 = "Rotating300Sphere5tHOMDust.ascii"

filename60 = "V06tHOMDust_out.ascii" #check name
filename61 = "Rotating100Sphere6tHOMDust.ascii" 
filename62 = "Rotating200Sphere6tHOMDust.ascii"
filename63 = "Rotating300Sphere6tHOMDust.ascii"

filename70 = "V07tHOMDust_out.ascii" #check name
filename71 = "Rotating100Sphere7tHOMDust.ascii"
filename72 = "Rotating200Sphere7tHOMDust.ascii"
filename73 = "Rotating300Sphere7tHOMDust.ascii"


data0 = np.loadtxt(data_path + filename0, comments = '#')
data = np.loadtxt(data_path + filename, comments = '#')
data2 = np.loadtxt(data_path + filename2, comments = '#')
data3 = np.loadtxt(data_path + filename3, comments = '#')

data60 = np.loadtxt(data_path + filename60, comments = '#')
data61 = np.loadtxt(data_path + filename61, comments = '#')
data62 = np.loadtxt(data_path + filename62, comments = '#')
data63 = np.loadtxt(data_path + filename63, comments = '#')

data70 = np.loadtxt(data_path + filename70, comments = '#')
data71 = np.loadtxt(data_path + filename71, comments = '#')
data72 = np.loadtxt(data_path + filename72, comments = '#')
data73 = np.loadtxt(data_path + filename73, comments = '#')

#Clean nan values---------------------------------------------------------------

#5t----------

initpos0 = data0[:,0]
index_clean0 = where(~np.isnan(initpos0))
data0 = data0[index_clean0[0],:]

initpos = data[:,0]
index_clean = where(~np.isnan(initpos))
data = data[index_clean[0],:]

initpos2 = data2[:,0]
index_clean2 = where(~np.isnan(initpos2))
data2 = data2[index_clean2[0],:]

initpos3 = data3[:,0]
index_clean3 = where(~np.isnan(initpos3))
data3 = data3[index_clean3[0],:]

#6t----------

initpos60 = data60[:,0]
index_clean60 = where(~np.isnan(initpos60))
data60 = data60[index_clean60[0],:]

initpos61 = data61[:,0]
index_clean61 = where(~np.isnan(initpos61))
data61 = data61[index_clean61[0],:]

initpos62 = data62[:,0]
index_clean62 = where(~np.isnan(initpos62))
data62 = data62[index_clean62[0],:]

initpos63 = data63[:,0]
index_clean63 = where(~np.isnan(initpos63))
data63 = data63[index_clean63[0],:]

#7t----------

initpos70 = data70[:,0]
index_clean70 = where(~np.isnan(initpos70))
data70 = data70[index_clean70[0],:]

initpos71 = data71[:,0]
index_clean71 = where(~np.isnan(initpos71))
data71 = data71[index_clean71[0],:]

initpos72 = data72[:,0]
index_clean72 = where(~np.isnan(initpos72))
data72 = data72[index_clean72[0],:]

initpos73 = data73[:,0]
index_clean73 = where(~np.isnan(initpos73))
data73 = data73[index_clean73[0],:]

# Define the values of the X_{m}

x0 = data0[:,6]
x = data[:,6]
x2 = data2[:,6]
x3 = data3[:,6]

x60 = data60[:,6]
x61 = data61[:,6]
x62 = data62[:,6]
x63 = data63[:,6]

x70 = data70[:,6]
x71 = data71[:,6]
x72 = data72[:,6]
x73 = data73[:,6]

#print amin([x]), amax(x)

# %%
# Put our results in wavelenght units (Amstrongs)

xe0 = x0 + 1216.15
xe = x + 1216.15
xe2 = x2 + 1216.15
xe3 = x3 +1216.5

xe60 = x60 + 1216.15
xe61 = x61 + 1216.15
xe62 = x62 + 1216.15
xe63 = x63 +1216.5

xe70 = x70 + 1216.15
xe71 = x71 + 1216.15
xe72 = x72 + 1216.15
xe73 = x73 +1216.5


#Put results at observed redshift
z=2.3

xo0 = (1 + z)*xe0
xo = (1 + z)*xe
xo2 = (1 + z)*xe2
xo3 = (1 + z)*xe3

xo60 = (1 + z)*xe60
xo61 = (1 + z)*xe61
xo62 = (1 + z)*xe62
xo63 = (1 + z)*xe63

xo70 = (1 + z)*xe70
xo71 = (1 + z)*xe71
xo72 = (1 + z)*xe72
xo73 = (1 + z)*xe73

# %%
#Plot comparison of different redshifts, STILL MISSING THE ANGLES WEIGHTS!!!!!

#t5
kx0 = data0[:,3]
ky0 = data0[:,4]
kz0 = data0[:,5]

kx = data[:,3]
ky = data[:,4]
kz = data[:,5]

kx2 = data2[:,3]
ky2 = data2[:,4]
kz2 = data2[:,5]

kx3 = data3[:,3]
ky3 = data3[:,4]
kz3 = data3[:,5]

#t6

kx60 = data60[:,3]
ky60 = data60[:,4]
kz60 = data60[:,5]

kx61 = data61[:,3]
ky61 = data61[:,4]
kz61 = data61[:,5]

kx62 = data62[:,3]
ky62 = data62[:,4]
kz62 = data62[:,5]

kx63 = data63[:,3]
ky63 = data63[:,4]
kz63 = data63[:,5]

#t7

kx70 = data70[:,3]
ky70 = data70[:,4]
kz70 = data70[:,5]

kx71 = data71[:,3]
ky71 = data71[:,4]
kz71 = data71[:,5]

kx72 = data72[:,3]
ky72 = data72[:,4]
kz72 = data72[:,5]

kx73 = data73[:,3]
ky73 = data73[:,4]
kz73 = data73[:,5]

#Define Norm of K

#5t
norm0 = sqrt(kx0**2 + ky0**2 + kz0**2)
norm = sqrt(kx**2 + ky**2 + kz**2)
norm2 = sqrt(kx2**2 + ky2**2 + kz2**2)
norm3 = sqrt(kx3**2 + ky3**2 + kz3**2)

#6t
norm60 = sqrt(kx60**2 + ky60**2 + kz60**2)
norm61 = sqrt(kx61**2 + ky61**2 + kz61**2)
norm62 = sqrt(kx62**2 + ky62**2 + kz62**2)
norm63 = sqrt(kx63**2 + ky63**2 + kz63**2)

#7t
norm70 = sqrt(kx70**2 + ky70**2 + kz70**2)
norm71 = sqrt(kx71**2 + ky71**2 + kz71**2)
norm72 = sqrt(kx72**2 + ky72**2 + kz72**2)
norm73 = sqrt(kx73**2 + ky73**2 + kz73**2)

# %%
#Define histo

#------------------------t5---------------------------------------
#Observed Histo with v=0km/s
freqbinObs0 = arange(amin(xo0), amax(xo0), 1.0)
histObs0, bin_edgesObs0 = np.histogram(xo0,bins = freqbinObs0)


#Histo in rest frame with v=100km/s
freqbin = arange(amin(xe), amax(xe), 1.0)
hist, bin_edges = np.histogram(xe,bins = freqbin)

# Observed Histo with v=100km/s
freqbinObs = arange(amin(xo), amax(xo), 1.0)
histObs, bin_edgesObs = np.histogram(xo,bins = freqbinObs)

# Observed Histo with v=200km/s

freqbinObs2 = arange(amin(xo2), amax(xo2), 1.0)
histObs2, bin_edgesObs2 = np.histogram(xo2,bins = freqbinObs2)

# Observed Hosto with v=300km/s
freqbinObs3 = arange(amin(xo3), amax(xo3), 1.0)
histObs3, bin_edgesObs3 = np.histogram(xo3,bins = freqbinObs3)

#--------------------t6---------------------------
#Observed Histo with v=0km/s
freqbinObs60 = arange(amin(xo60), amax(xo60), 1.0)
histObs60, bin_edgesObs60 = np.histogram(xo60,bins = freqbinObs60)


#Histo in rest frame with v=100km/s
freqbin61 = arange(amin(xe61), amax(xe61), 1.0)
hist61, bin_edges61 = np.histogram(xe61,bins = freqbin61)

# Observed Histo with v=100km/s
freqbinObs61 = arange(amin(xo61), amax(xo61), 1.0)
histObs61, bin_edgesObs61 = np.histogram(xo61,bins = freqbinObs61)

# Observed Histo with v=200km/s

freqbinObs62 = arange(amin(xo62), amax(xo62), 1.0)
histObs62, bin_edgesObs62 = np.histogram(xo62,bins = freqbinObs62)

# Observed Hosto with v=300km/s
freqbinObs63 = arange(amin(xo63), amax(xo63), 1.0)
histObs63, bin_edgesObs63 = np.histogram(xo63,bins = freqbinObs63)

#--------------------t7---------------------------
#Observed Histo with v=0km/s
freqbinObs70 = arange(amin(xo70), amax(xo70), 1.0)
histObs70, bin_edgesObs70 = np.histogram(xo70,bins = freqbinObs70)


#Histo in rest frame with v=100km/s
freqbin71 = arange(amin(xe71), amax(xe71), 1.0)
hist71, bin_edges71 = np.histogram(xe71,bins = freqbin71)

# Observed Histo with v=100km/s
freqbinObs71 = arange(amin(xo71), amax(xo71), 1.0)
histObs71, bin_edgesObs71 = np.histogram(xo71,bins = freqbinObs71)

# Observed Histo with v=200km/s

freqbinObs72 = arange(amin(xo72), amax(xo72), 1.0)
histObs72, bin_edgesObs72 = np.histogram(xo72,bins = freqbinObs72)

# Observed Hosto with v=300km/s
freqbinObs73 = arange(amin(xo73), amax(xo73), 1.0)
histObs73, bin_edgesObs73 = np.histogram(xo73,bins = freqbinObs73)

#Some test plots

plt.title('Ly alpha at different Z')

#t5
#p, = plot(bin_edges[1:],hist)
pObs, = plot(bin_edgesObs[1:],histObs)

#t6
#p6, = plot(bin_edges61[1:],hist61)
pObs6, = plot(bin_edgesObs61[1:],histObs61)

#t7
#p7, = plot(bin_edges71[1:],hist71)
pObs7, = plot(bin_edgesObs71[1:],histObs71)

plt.show()

#plot of observed spectra
pObs, = plot(bin_edgesObs[1:],histObs)

plt.show()

# %%
#Narrow band filter.

#Steidel et al. (2010) Filters

SSA22 = 19.6
HS1549 = 23.4
HS1700 = 27.3

#Center of the band filters (make a function that detects the x position corresponding to the flux maxima)!!


#Narrow band filters plots---------------------------------------

#SSA22
plt.axvline(x=4015,linewidth=2,color='k',linestyle="--")
plt.axvline(x=4024.8,linewidth=2,color='k')
plt.axvline(x=4005.2,linewidth=2,color='k')

#HS1549
plt.axvline(x=4026.7,linewidth=2,color='r')
plt.axvline(x=4003.3,linewidth=2,color='r')

#HS1700
plt.axvline(x=4028.65,linewidth=2,color='g')
plt.axvline(x=4001.35,linewidth=2,color='g')


#Spectra plots --------------------------------------------------

#------------t5
pObs0, = plot(bin_edgesObs0[1:],histObs0) #check binedges 64 vs histObs 128
pObs, = plot(bin_edgesObs[1:],histObs)  
pObs2, = plot(bin_edgesObs2[1:],histObs2)
pObs3, = plot(bin_edgesObs3[1:],histObs3)


#Labels---------------------------------------------------------

plt.title (r'Narrow band filter, $\tau = 10^5$, Homogenoeus models', fontsize=18)
plt.xlabel(r"$\lambda$", fontsize=20)

# %%
#Narrow band filters plots---------------------------------------

#SSA22
plt.axvline(x=4015,linewidth=2,color='k',linestyle="--")
plt.axvline(x=4024.8,linewidth=2,color='k')
plt.axvline(x=4005.2,linewidth=2,color='k')

#HS1549
plt.axvline(x=4026.7,linewidth=2,color='r')
plt.axvline(x=4003.3,linewidth=2,color='r')

#HS1700
plt.axvline(x=4028.65,linewidth=2,color='g')
plt.axvline(x=4001.35,linewidth=2,color='g')

#------------t6
pObs60, = plot(bin_edgesObs60[1:],histObs60) 
pObs61, = plot(bin_edgesObs61[1:],histObs61)  
pObs62, = plot(bin_edgesObs62[1:],histObs62)
pObs63, = plot(bin_edgesObs63[1:],histObs63)

# %%
#Narrow band filters plots---------------------------------------

#SSA22
plt.axvline(x=4015,linewidth=2,color='k',linestyle="--")
plt.axvline(x=4024.8,linewidth=2,color='k')
plt.axvline(x=4005.2,linewidth=2,color='k')

#HS1549
plt.axvline(x=4026.7,linewidth=2,color='r')
plt.axvline(x=4003.3,linewidth=2,color='r')

#HS1700
plt.axvline(x=4028.65,linewidth=2,color='g')
plt.axvline(x=4001.35,linewidth=2,color='g')

#------------t7
pObs70, = plot(bin_edgesObs70[1:],histObs70) #check binedges 64 vs histObs 128
pObs71, = plot(bin_edgesObs71[1:],histObs71)  
pObs72, = plot(bin_edgesObs72[1:],histObs72)
pObs73, = plot(bin_edgesObs73[1:],histObs73)

# %%
#Numer of photons (Flux) inside the narrow band filter
#this is  test for HS1700

j=0
j2=0
j3=0

# For v=100km/s

for i in range(len(xo)):
    if xo[i] <=4028.65 and xo[i] >=4001.35:
        j += 1

print 'Number of phtons inside HS1700 filter, v=100km/s = ',j

# For V=200km/s

for i in range(len(xo2)):
    if xo2[i] <=4028.65 and xo2[i] >=4001.35:
        j2 += 1

print 'Number of phtons inside HS1700 filter, v=200km/s = ',j2

# For V=300km/s

for i in range(len(xo3)):
    if xo3[i] <=4028.65 and xo3[i] >=4001.35:
        j3 += 1

print 'Number of phtons inside HS1700 filter, v=300km/s = ', j3
# Out:
# Number of phtons inside HS1700 filter, v=100km/s =  65752
# Number of phtons inside HS1700 filter, v=200km/s =
#  43540
# Number of phtons inside HS1700 filter, v=300km/s =
#  32108
