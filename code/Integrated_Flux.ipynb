# %%
#This notebook corresponds to section 4.4  , Rotation effects on the lyman alpha line morphology in distant galaxies
#check plots, think about how to get FLux from the observer dependecy, must be similar to EF
# To improve:
# Put all the data in ../data/Homogeneous/


from numpy import *
from pylab import *
import numpy as np
import math
import matplotlib.pyplot as plt

#1. Load the Data

data_path = "../data/Homogeneous/"

#Load data with Dust++++++++++++++++++++++++++++++++++
#5t
filename0 = "V0hom5t.ascii"
filename = "V1005tHOM_out.ascii"
filename2 = "V2005tHOM_out.ascii"
filename3 = "V3005tHOM_out.ascii"

#6t
filename60 = "V0hom6t.ascii" #check name
filename61 = "V1006tHOM_out.ascii" 
filename62 = "V2005tHOM_out.ascii"
filename63 = "V3005tHOM_out.ascii"

#7t
filename70 = "V0hom7t.ascii" #check name
filename71 = "V1007tHOM_out.ascii"
filename72 = "V2007tHOM_out.ascii"
filename73 = "Rotating300Sphere7tHOM.ascii" #THis is not working carefull

#5t
data0 = np.loadtxt(data_path + filename0, comments = '#')
data = np.loadtxt(data_path + filename, comments = '#')
data2 = np.loadtxt(data_path + filename2, comments = '#')
data3 = np.loadtxt(data_path + filename3, comments = '#')

#6t
data60 = np.loadtxt(data_path + filename60, comments = '#')
data61 = np.loadtxt(data_path + filename61, comments = '#')
data62 = np.loadtxt(data_path + filename62, comments = '#')
data63 = np.loadtxt(data_path + filename63, comments = '#')

#7t
data70 = np.loadtxt(data_path + filename70, comments = '#')
data71 = np.loadtxt(data_path + filename71, comments = '#')
data72 = np.loadtxt(data_path + filename72, comments = '#')
data73 = np.loadtxt(data_path + filename73, comments = '#')

#Clean nan values---------------------------------------------------------------

#5t----------

initpos0 = data0[:,0]
index_clean0 = where(~np.isnan(initpos0))
data0 = data0[index_clean0[0],:]

initpos = data[:,0]
index_clean = where(~np.isnan(initpos))
data = data[index_clean[0],:]

initpos2 = data2[:,0]
index_clean2 = where(~np.isnan(initpos2))
data2 = data2[index_clean2[0],:]

initpos3 = data3[:,0]
index_clean3 = where(~np.isnan(initpos3))
data3 = data3[index_clean3[0],:]

#6t----------

initpos60 = data60[:,0]
index_clean60 = where(~np.isnan(initpos60))
data60 = data60[index_clean60[0],:]

initpos61 = data61[:,0]
index_clean61 = where(~np.isnan(initpos61))
data61 = data61[index_clean61[0],:]

initpos62 = data62[:,0]
index_clean62 = where(~np.isnan(initpos62))
data62 = data62[index_clean62[0],:]

initpos63 = data63[:,0]
index_clean63 = where(~np.isnan(initpos63))
data63 = data63[index_clean63[0],:]

#7t----------

initpos70 = data70[:,0]
index_clean70 = where(~np.isnan(initpos70))
data70 = data70[index_clean70[0],:]

initpos71 = data71[:,0]
index_clean71 = where(~np.isnan(initpos71))
data71 = data71[index_clean71[0],:]

initpos72 = data72[:,0]
index_clean72 = where(~np.isnan(initpos72))
data72 = data72[index_clean72[0],:]

initpos73 = data73[:,0]
index_clean73 = where(~np.isnan(initpos73))
data73 = data73[index_clean73[0],:]

# Define the values of the X_{m}

#5t
x0 = data0[:,6]
x = data[:,6]
x2 = data2[:,6]
x3 = data3[:,6]

#6t
x60 = data60[:,6]
x61 = data61[:,6]
x62 = data62[:,6]
x63 = data63[:,6]

#7t
x70 = data70[:,6]
x71 = data71[:,6]
x72 = data72[:,6]
x73 = data73[:,6]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-941d9bbf442b> in <module>()
#      37 data0 = np.loadtxt(data_path + filename0, comments = '#')
#      38 data = np.loadtxt(data_path + filename, comments = '#')
# ---> 39 data2 = np.loadtxt(data_path + filename2, comments = '#')
#      40 data3 = np.loadtxt(data_path + filename3, comments = '#')
#      41
#
# /usr/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     713                 fh = iter(bz2.BZ2File(fname))
#     714             else:
# --> 715                 fh = iter(open(fname, 'U'))
#     716         else:
#     717             fh = iter(fname)
#
# IOError: [Errno 2] No such file or directory: '../data/Homogeneous/V2005tHOM_out.ascii'

# %%
# Put our results in wavelenght units (Angstrom)

#t5
xe0 = x0 + 1216.15
xe = x + 1216.15
xe2 = x2 + 1216.15
xe3 = x3 +1216.5

#t6
xe60 = x60 + 1216.15
xe61 = x61 + 1216.15
xe62 = x62 + 1216.15
xe63 = x63 +1216.5

#t7
xe70 = x70 + 1216.15
xe71 = x71 + 1216.15
xe72 = x72 + 1216.15
xe73 = x73 +1216.5


#Put results at observed redshift
z=3.09

xo0 = (1 + z)*xe0
xo = (1 + z)*xe
xo2 = (1 + z)*xe2
xo3 = (1 + z)*xe3

xo60 = (1 + z)*xe60
xo61 = (1 + z)*xe61
xo62 = (1 + z)*xe62
xo63 = (1 + z)*xe63

xo70 = (1 + z)*xe70
xo71 = (1 + z)*xe71
xo72 = (1 + z)*xe72
xo73 = (1 + z)*xe73

# %%
#Plot comparison of different redshifts, STILL MISSING THE ANGLES WEIGHTS!!!!!

#t5
kx0 = data0[:,3]
ky0 = data0[:,4]
kz0 = data0[:,5]

kx = data[:,3]
ky = data[:,4]
kz = data[:,5]

kx2 = data2[:,3]
ky2 = data2[:,4]
kz2 = data2[:,5]

kx3 = data3[:,3]
ky3 = data3[:,4]
kz3 = data3[:,5]

#t6

kx60 = data60[:,3]
ky60 = data60[:,4]
kz60 = data60[:,5]

kx61 = data61[:,3]
ky61 = data61[:,4]
kz61 = data61[:,5]

kx62 = data62[:,3]
ky62 = data62[:,4]
kz62 = data62[:,5]

kx63 = data63[:,3]
ky63 = data63[:,4]
kz63 = data63[:,5]

#t7

kx70 = data70[:,3]
ky70 = data70[:,4]
kz70 = data70[:,5]

kx71 = data71[:,3]
ky71 = data71[:,4]
kz71 = data71[:,5]

kx72 = data72[:,3]
ky72 = data72[:,4]
kz72 = data72[:,5]

kx73 = data73[:,3]
ky73 = data73[:,4]
kz73 = data73[:,5]

#Define Norm of K

#5t
norm0 = sqrt(kx0**2 + ky0**2 + kz0**2)
norm = sqrt(kx**2 + ky**2 + kz**2)
norm2 = sqrt(kx2**2 + ky2**2 + kz2**2)
norm3 = sqrt(kx3**2 + ky3**2 + kz3**2)

#6t
norm60 = sqrt(kx60**2 + ky60**2 + kz60**2)
norm61 = sqrt(kx61**2 + ky61**2 + kz61**2)
norm62 = sqrt(kx62**2 + ky62**2 + kz62**2)
norm63 = sqrt(kx63**2 + ky63**2 + kz63**2)

#7t
norm70 = sqrt(kx70**2 + ky70**2 + kz70**2)
norm71 = sqrt(kx71**2 + ky71**2 + kz71**2)
norm72 = sqrt(kx72**2 + ky72**2 + kz72**2)
norm73 = sqrt(kx73**2 + ky73**2 + kz73**2)

# %%
# Define Obs dependence..

#Define angles

theta = pi/2.0
o90 = array([0, sin(theta), cos(theta)])
theta = pi/4.0
o45 = array([0, sin(theta), cos(theta)])
theta = 0.0
o0 = array([0, sin(theta), cos(theta)])

#Dot product between angle and lya photon direction

#--------------t5

s090t5 = abs(kx0[:]*o90[0]+ky0[:]*o90[1]+kz0[:]*o90[2])
s045t5 = abs(kx0[:]*o45[0]+ky0[:]*o45[1]+kz0[:]*o45[2])
s00t5 = abs(kx0[:]*o0[0]+ky0[:]*o0[1]+kz0[:]*o0[2])

s190t5 = abs(kx[:]*o90[0]+ky[:]*o90[1]+kz[:]*o90[2])
s145t5 = abs(kx[:]*o45[0]+ky[:]*o45[1]+kz[:]*o45[2])
s10t5 = abs(kx[:]*o0[0]+ky[:]*o0[1]+kz[:]*o0[2])

s290t5 = abs(kx2[:]*o90[0]+ky2[:]*o90[1]+kz2[:]*o90[2])
s245t5 = abs(kx2[:]*o45[0]+ky2[:]*o45[1]+kz2[:]*o45[2])
s20t5 = abs(kx2[:]*o0[0]+ky2[:]*o0[1]+kz2[:]*o0[2])

s390t5 = abs(kx3[:]*o90[0]+ky3[:]*o90[1]+kz3[:]*o90[2])
s345t5 = abs(kx3[:]*o45[0]+ky3[:]*o45[1]+kz3[:]*o45[2])
s30t5 = abs(kx3[:]*o0[0]+ky3[:]*o0[1]+kz3[:]*o0[2])

#--------------t6

s090t60 = abs(kx60[:]*o90[0]+ky60[:]*o90[1]+kz60[:]*o90[2])
s045t60 = abs(kx60[:]*o45[0]+ky60[:]*o45[1]+kz60[:]*o45[2])
s00t60 = abs(kx60[:]*o0[0]+ky60[:]*o0[1]+kz60[:]*o0[2])

s190t61 = abs(kx61[:]*o90[0]+ky61[:]*o90[1]+kz61[:]*o90[2])
s145t61 = abs(kx61[:]*o45[0]+ky61[:]*o45[1]+kz61[:]*o45[2])
s10t61 = abs(kx61[:]*o0[0]+ky61[:]*o0[1]+kz61[:]*o0[2])

s290t62 = abs(kx62[:]*o90[0]+ky62[:]*o90[1]+kz62[:]*o90[2])
s245t62= abs(kx62[:]*o45[0]+ky62[:]*o45[1]+kz62[:]*o45[2])
s20t62 = abs(kx62[:]*o0[0]+ky62[:]*o0[1]+kz62[:]*o0[2])

s390t63 = abs(kx63[:]*o90[0]+ky63[:]*o90[1]+kz63[:]*o90[2])
s345t63 = abs(kx63[:]*o45[0]+ky63[:]*o45[1]+kz63[:]*o45[2])
s30t63 = abs(kx63[:]*o0[0]+ky63[:]*o0[1]+kz63[:]*o0[2])

#--------------t7

s090t70 = abs(kx70[:]*o90[0]+ky70[:]*o90[1]+kz70[:]*o90[2])
s045t70 = abs(kx70[:]*o45[0]+ky70[:]*o45[1]+kz70[:]*o45[2])
s00t70 = abs(kx70[:]*o0[0]+ky70[:]*o0[1]+kz70[:]*o0[2])

s190t71 = abs(kx71[:]*o90[0]+ky71[:]*o90[1]+kz71[:]*o90[2])
s145t71 = abs(kx71[:]*o45[0]+ky71[:]*o45[1]+kz71[:]*o45[2])
s10t71 = abs(kx71[:]*o0[0]+ky71[:]*o0[1]+kz71[:]*o0[2])

s290t72 = abs(kx72[:]*o90[0]+ky72[:]*o90[1]+kz72[:]*o90[2])
s245t72= abs(kx72[:]*o45[0]+ky72[:]*o45[1]+kz72[:]*o45[2])
s20t72 = abs(kx72[:]*o0[0]+ky72[:]*o0[1]+kz72[:]*o0[2])

s390t73 = abs(kx73[:]*o90[0]+ky73[:]*o90[1]+kz73[:]*o90[2])
s345t73 = abs(kx73[:]*o45[0]+ky73[:]*o45[1]+kz73[:]*o45[2])
s30t73 = abs(kx73[:]*o0[0]+ky73[:]*o0[1]+kz73[:]*o0[2])

# %%
#Define histo

#------------------------t5---------------------------------------
#Observed Histo with v=0km/s
freqbinObs0 = arange(amin(xo0), amax(xo0), 1.0)
histObs0theta90, bin_edgesObs0theta90 = np.histogram(xo0, density=True, weights=s090t5, bins = freqbinObs0)
histObs0theta45, bin_edgesObs0theta45 = np.histogram(xo0, density=True, weights=s045t5, bins = freqbinObs0)
histObs0theta0, bin_edgesObs0theta0 = np.histogram(xo0, density=True, weights=s00t5, bins = freqbinObs0)

#Histo in rest frame with v=100km/s
freqbin = arange(amin(xe), amax(xe), 1.0)
hist, bin_edges = np.histogram(xe, bins = freqbin)


# Observed Histo with v=100km/s
freqbinObs1 = arange(amin(xo), amax(xo), 1.0)
histObs1theta90, bin_edgesObs1 = np.histogram(xo, density=True, weights=s190t5, bins = freqbinObs1)
histObs1theta45, bin_edgesObs1 = np.histogram(xo, density=True, weights=s145t5, bins = freqbinObs1)
histObs1theta0, bin_edgesObs1 = np.histogram(xo, density=True, weights=s10t5, bins = freqbinObs1)

# Observed Histo with v=200km/s

freqbinObs2 = arange(amin(xo2), amax(xo2), 1.0)
histObs2theta90, bin_edgesObs2 = np.histogram(xo2, density=True, weights=s290t5, bins = freqbinObs2)
histObs2theta45, bin_edgesObs2 = np.histogram(xo2, density=True, weights=s245t5, bins = freqbinObs2)
histObs2theta0, bin_edgesObs2 = np.histogram(xo2, density=True, weights=s20t5, bins = freqbinObs2)


# Observed Hosto with v=300km/s
freqbinObs3 = arange(amin(xo3), amax(xo3), 1.0)
histObs3theta90, bin_edgesObs3 = np.histogram(xo3, density=True, weights=s390t5, bins = freqbinObs3)
histObs3theta45, bin_edgesObs3 = np.histogram(xo3, density=True, weights=s345t5, bins = freqbinObs3)
histObs3theta0, bin_edgesObs3 = np.histogram(xo3, density=True, weights=s30t5, bins = freqbinObs3)


#--------------------t6---------------------------
#Observed Histo with v=0km/s
freqbinObs60 = arange(amin(xo60), amax(xo60), 1.0)
histObs60theta90, bin_edgesObs60 = np.histogram(xo60, density=True, weights=s090t60, bins = freqbinObs60)
histObs60theta45, bin_edgesObs60 = np.histogram(xo60, density=True, weights=s045t60, bins = freqbinObs60)
histObs60theta0, bin_edgesObs60 = np.histogram(xo60, density=True, weights=s00t60, bins = freqbinObs60)



#Histo in rest frame with v=100km/s
freqbin61 = arange(amin(xe61), amax(xe61), 1.0)
hist61, bin_edges61 = np.histogram(xe61,bins = freqbin61)

# Observed Histo with v=100km/s
freqbinObs61 = arange(amin(xo61), amax(xo61), 1.0)
histObs61theta90, bin_edgesObs61 = np.histogram(xo61, density=True, weights=s190t61, bins = freqbinObs61)
histObs61theta45, bin_edgesObs61 = np.histogram(xo61, density=True, weights=s145t61, bins = freqbinObs61)
histObs61theta0, bin_edgesObs61 = np.histogram(xo61, density=True, weights=s10t61, bins = freqbinObs61)

# Observed Histo with v=200km/s

freqbinObs62 = arange(amin(xo62), amax(xo62), 1.0)
histObs62theta90, bin_edgesObs62 = np.histogram(xo62, density=True, weights=s290t62, bins = freqbinObs62)
histObs62theta45, bin_edgesObs62 = np.histogram(xo62, density=True, weights=s245t62, bins = freqbinObs62)
histObs62theta0, bin_edgesObs62 = np.histogram(xo62, density=True, weights=s20t62, bins = freqbinObs62)

# Observed Hosto with v=300km/s
freqbinObs63 = arange(amin(xo63), amax(xo63), 1.0)
histObs63theta90, bin_edgesObs63 = np.histogram(xo63, density=True, weights=s390t63, bins = freqbinObs63)
histObs63theta45, bin_edgesObs63 = np.histogram(xo63, density=True, weights=s345t63, bins = freqbinObs63)
histObs63theta0, bin_edgesObs63 = np.histogram(xo63, density=True, weights=s30t63, bins = freqbinObs63)

#--------------------t7---------------------------
#Observed Histo with v=0km/s
freqbinObs70 = arange(amin(xo70), amax(xo70), 1.0)
histObs70theta90, bin_edgesObs70 = np.histogram(xo70, density=True, weights=s090t70, bins = freqbinObs70)
histObs70theta45, bin_edgesObs70 = np.histogram(xo70, density=True, weights=s045t70, bins = freqbinObs70)
histObs70theta0, bin_edgesObs70 = np.histogram(xo70, density=True, weights=s00t70, bins = freqbinObs70)

#Histo in rest frame with v=100km/s
freqbin71 = arange(amin(xe71), amax(xe71), 1.0)
hist71, bin_edges71 = np.histogram(xe71,bins = freqbin71)

# Observed Histo with v=100km/s
freqbinObs71 = arange(amin(xo71), amax(xo71), 1.0)
histObs71theta90, bin_edgesObs71 = np.histogram(xo71, density=True, weights=s190t71, bins = freqbinObs71)
histObs71theta45, bin_edgesObs71 = np.histogram(xo71, density=True, weights=s145t71, bins = freqbinObs71)
histObs71theta0, bin_edgesObs71 = np.histogram(xo71, density=True, weights=s10t71, bins = freqbinObs71)

# Observed Histo with v=200km/s

freqbinObs72 = arange(amin(xo72), amax(xo72), 1.0)
histObs72theta90, bin_edgesObs72 = np.histogram(xo72, density=True, weights=s290t72, bins = freqbinObs72)
histObs72theta45, bin_edgesObs72 = np.histogram(xo72, density=True, weights=s245t72, bins = freqbinObs72)
histObs72theta0, bin_edgesObs72 = np.histogram(xo72, density=True, weights=s20t72, bins = freqbinObs72)


# Observed Hosto with v=300km/s
freqbinObs73 = arange(amin(xo73), amax(xo73), 1.0)
histObs73theta90, bin_edgesObs73 = np.histogram(xo73, density=True, weights=s390t73, bins = freqbinObs73)
histObs73theta45, bin_edgesObs73 = np.histogram(xo73, density=True, weights=s345t73, bins = freqbinObs73)
histObs73theta0, bin_edgesObs73 = np.histogram(xo73, density=True, weights=s30t73, bins = freqbinObs73)


#Some test plots

#plot of observed spectra
#v=100km/s, tau=10^5
plt.title(r'Ly alpha at different theta, $\tau=10^5$, $v=100kms^{-1}$')
pObstheta90, = plot(bin_edgesObs1[1:],histObs1theta90)
pObstheta45, = plot(bin_edgesObs1[1:],histObs1theta45)
pObstheta0, = plot(bin_edgesObs1[1:],histObs1theta0)

plt.show()

#v=100km/s, tau=10^7
plt.title(r'Ly alpha at differents theta, $\tau=10^7$, $v=100kms^{-1}$')
p71Obstheta90, = plot(bin_edgesObs71[1:],histObs71theta90)
p71Obstheta45, = plot(bin_edgesObs71[1:],histObs71theta45)
p71Obstheta0, = plot(bin_edgesObs71[1:],histObs71theta0)

plt.show()

#v=100km/s, tau=10^7 
plt.title(r'Ly alpha for differents $\tau$, $\theta=0$, $v=100kms^{-1}$')
p71Obstheta0, = plot(bin_edgesObs71[1:],histObs71theta0)
p61Obstheta0, = plot(bin_edgesObs61[1:],histObs61theta0)
p1Obstheta0, = plot(bin_edgesObs1[1:],histObs1theta0)

plt.show()

# %%
#Narrow band filter.

#Steidel et al. (2010) Filters
#width of filters in Angstroms

#-------------------------------------

SSA22 = 80 # z=3.09
HS1549 = 23.4 #z= 2.842
HS1700 = 27.3 #z= 2.299

#--------------------------------------

#Center of the band filters (make a function that detects the x position corresponding to the flux maxima)!!


#Narrow band filters plots---------------------------------------

#SSA22
axvline(x=4980,linewidth=2,color='k',linestyle="--")
axvline(x=5020,linewidth=2,color='k')
axvline(x=4940,linewidth=2,color='k')

#HS1549
#plt.axvline(x=4026.7,linewidth=2,color='r')
#plt.axvline(x=4003.3,linewidth=2,color='r')

#HS1700
#plt.axvline(x=4028.65,linewidth=2,color='g')
#plt.axvline(x=4001.35,linewidth=2,color='g')


#Spectra plots --------------------------------------------------

#------------t5
pObs0, = plot(bin_edgesObs0theta0[1:],histObs0theta0, '-r') 
pObs1, = plot(bin_edgesObs1[1:],histObs1theta0, '-b')  
pObs2, = plot(bin_edgesObs2[1:],histObs2theta0, '-g')
pObs3, = plot(bin_edgesObs3[1:],histObs3theta0, '-k')


#Labels---------------------------------------------------------
ylim([0.0,0.035])
title (r'NB, $\tau = 10^5$, Homogenoeus models', fontsize=15)
ylabel("Flux (Arbitrary Units)", fontsize=18)
xlabel(r"$\lambda(\AA)$", fontsize=18)
legend([pObs0, pObs1, pObs2, pObs3],[r'$0 kms^{-1}$', r'$100 kms^{-1}$',r'$200 kms^{-1}$',r'$300 kms^{-1}$'])
savefig('NB5tDifVHOM.png')
plt.show()

#------------t6------------------------------------------------------------------------------------------
#pObs60, = plot(bin_edgesObs60[1:],histObs60theta0, '-r') 
pObs60, = plot(bin_edgesObs60[1:],histObs60theta0, '-r')  
pObs61, = plot(bin_edgesObs61[1:],histObs61theta0, '-b')  
pObs62, = plot(bin_edgesObs62[1:],histObs62theta0, '-g')
pObs63, = plot(bin_edgesObs63[1:],histObs63theta0, '-k')

#SSA22
axvline(x=4980,linewidth=2,color='k',linestyle="--")
axvline(x=5020,linewidth=2,color='k')
axvline(x=4940,linewidth=2,color='k')

#Labels---------------------------------------------------------
ylim([0.0,0.025])
title (r'NB, $\tau = 10^6$, Homogenoeus models', fontsize=15)
ylabel("Flux (Arbitrary Units)", fontsize=18)
xlabel(r"$\lambda(\AA)$", fontsize=18)
legend([pObs60, pObs61, pObs62, pObs63],[r'$0 kms^{-1}$', r'$100 kms^{-1}$',r'$200 kms^{-1}$',r'$300 kms^{-1}$'])
savefig('NB6tDifVHOM.png')
plt.show()

#------------t7------------------------------------------------------------------------------------------
pObs70, = plot(bin_edgesObs70[1:],histObs70theta0, '-r') 
pObs71, = plot(bin_edgesObs71[1:],histObs71theta0, '-b')  
pObs72, = plot(bin_edgesObs72[1:],histObs72theta0, '-g')
pObs73, = plot(bin_edgesObs73[1:],histObs73theta0, '-k')

#SSA22
axvline(x=4980,linewidth=2,color='k',linestyle="--")
axvline(x=5020,linewidth=2,color='k')
axvline(x=4940,linewidth=2,color='k')

#Labels---------------------------------------------------------
ylim([0.0,0.01])
title (r'NB, $\tau = 10^7$, Homogenoeus models', fontsize=15)
ylabel("Flux (Arbitrary Units)", fontsize=18)
xlabel(r"$\lambda(\AA)$", fontsize=18)
legend([pObs70, pObs71, pObs72, pObs73],[r'$0 kms^{-1}$', r'$100 kms^{-1}$',r'$200 kms^{-1}$',r'$300 kms^{-1}$'])
savefig('NB7tDifVHOM.png')
plt.show()

#------------t7---------------------Observer------------------------------------------------
pObs71theta90, = plot(bin_edgesObs71[1:],histObs71theta90, '-r') 
pObs71theta45, = plot(bin_edgesObs71[1:],histObs71theta45, '-b')  
pObs71theta0, = plot(bin_edgesObs71[1:],histObs71theta0, '-g')

#SSA22
axvline(x=4980,linewidth=2,color='k',linestyle="--")
axvline(x=5020,linewidth=2,color='k')
axvline(x=4940,linewidth=2,color='k')

#Labels---------------------------------------------------------
ylim([0.0,0.01])
title (r'NB, $\tau = 10^7$, Homogenoeus models', fontsize=15)
ylabel("Flux (Arbitrary Units)", fontsize=18)
xlabel(r"$\lambda(\AA)$", fontsize=18)
legend([pObs71theta90, pObs71theta45, pObs71theta0],[r'$\theta=90$',r'$\theta=45$',r'$\theta=0$'])
savefig('NB7tDifVHOMObserverv100.png')
plt.show()

# %%
#Numer of photons (Flux) inside the narrow band filter
#this is  test for HS1700

j0 = 0
j1 = 0
j2 = 0
j3 = 0 

j60 = 0
j61 = 0
j62 = 0
j63 = 0

j70 = 0
j71 = 0
j72 = 0
j73 = 0

#t5----------------------------------------------------------------------------
# For v=0km/s

for i in range(len(xo0)):
    if xo0[i] <=5020 and xo0[i] >=4040:
        j0 += 1

print 'Number of phtons inside SSA22 filter, v=0km/s , tau=10^5 = ',j0

# For V=100km/s

for i in range(len(xo)):
    if xo[i] <=5020 and xo[i] >=4040:
        j1 += 1

print 'Number of phtons inside SSA22 filter, v=100km/s, tau=10^5  = ',j1

# For V=200km/s

for i in range(len(xo2)):
    if xo2[i] <=5020 and xo2[i] >=4040:
        j2 += 1

print 'Number of phtons inside SSA22filter, v=200km/s, tau=10^5  = ', j2

# For V=300km/s

for i in range(len(xo3)):
    if xo3[i] <=5020 and xo3[i] >=4040:
        j3 += 1

print 'Number of phtons inside SSA22filter, v=300km/s, tau=10^5 = ', j3

#t6--------------------------------------------------------------------
# For v=0km/s

for i in range(len(xo60)):
    if xo60[i] <=5020 and xo60[i] >=4040:
        j60 += 1

print 'Number of phtons inside SSA22 filter, v=0km/s , tau=10^6 = ',j60

# For V=100km/s

for i in range(len(xo61)):
    if xo61[i] <=5020 and xo61[i] >=4040:
        j61 += 1

print 'Number of phtons inside SSA22 filter, v=100km/s, tau=10^6  = ',j61

# For V=200km/s

for i in range(len(xo62)):
    if xo62[i] <=5020 and xo62[i] >=4040:
        j62 += 1

print 'Number of phtons inside SSA22filter, v=200km/s, tau=10^6  = ', j62

# For V=300km/s

for i in range(len(xo63)):
    if xo63[i] <=5020 and xo63[i] >=4040:
        j63 += 1

print 'Number of phtons inside SSA22filter, v=300km/s, tau=10^6  = ', j63

#t7--------------------------------------------------------------------
# For v=0km/s

for i in range(len(xo70)):
    if xo70[i] <=5020 and xo70[i] >=4040:
        j70 += 1

#print 'Number of phtons inside SSA22 filter, v=0km/s, tau=10^7  = ',j70

# For V=100km/s

for i in range(len(xo71)):
    if xo71[i] <=5020 and xo71[i] >=4040:
        j71 += 1

print 'Number of phtons inside SSA22 filter, v=100km/s, tau=10^7  = ',j71

# For V=200km/s

for i in range(len(xo72)):
    if xo72[i] <=5020 and xo72[i] >=4040:
        j72 += 1

print 'Number of phtons inside SSA22filter, v=200km/s, tau=10^7  = ', j72

# For V=300km/s

for i in range(len(xo73)):
    if xo73[i] <=5020 and xo73[i] >=4040:
        j73 += 1

print 'Number of phtons inside SSA22filter, v=300km/s, tau=10^7 = ', j73
# Out:
# Number of phtons inside SSA22 filter, v=0km/s , tau=10^5 =  99965
# Number of phtons inside SSA22 filter, v=100km/s, tau=10^5  =
#  99221
# Number of phtons inside SSA22filter, v=200km/s, tau=10^5  =
#  90630
# Number of phtons inside SSA22filter, v=300km/s, tau=10^5 =
#  82180
# Number of phtons inside SSA22 filter, v=0km/s , tau=10^6 =
#  98658
# Number of phtons inside SSA22 filter, v=100km/s, tau=10^6  =
#  95517
# Number of phtons inside SSA22filter, v=200km/s, tau=10^6  =
#  90630
# Number of phtons inside SSA22filter, v=300km/s, tau=10^6  =
#  82180
# Number of phtons inside SSA22 filter, v=100km/s, tau=10^7  =
#  75058
# Number of phtons inside SSA22filter, v=200km/s, tau=10^7  =
#  73938
# Number of phtons inside SSA22filter, v=300km/s, tau=10^7 =
#  71953
