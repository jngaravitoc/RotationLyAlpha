# %%
# %pylab inline
from subprocess import call
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# #Width analysis (0)
# #Homogeneous

# %% [markdown]
# #Plot for $\tau = 10^5$

# %%
for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating0Sphere5tHOM.ascii %d 40 0 >> data0.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating100Sphere5tHOM.ascii %d 40 0 >> data100.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating200Sphere5tHOM.ascii %d 40 0 >> data200.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating300Sphere5tHOM.ascii %d 40 0 >> data300.dat"%(i) 
    retcode = call(command,shell=True)

# %% [markdown]
# # $\tau=10^6$

# %%
for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating0Sphere6tHOM.ascii %d 40 0 >> data06t.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating100Sphere6tHOM.ascii %d 40 0 >> data1006t.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating200Sphere6tHOM.ascii %d 40 0 >> data2006t.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating300Sphere6tHOM.ascii %d 40 0 >> data3006t.dat"%(i) 
    retcode = call(command,shell=True)

# %% [markdown]
# # $\tau=10^7$

# %%
for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating0Sphere7tHOM.ascii %d 40 0 >> data07t.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating100Sphere7tHOM.ascii %d 40 0 >> data1007t.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating200Sphere7tHOM.ascii %d 40 0 >> data2007t.dat"%(i) 
    retcode = call(command,shell=True)

for i in range (1, 10):
    command = "python New_widths_and_Maxima.py Rotating300Sphere7tHOM.ascii %d 40 0 >> data3007t.dat"%(i) 
    retcode = call(command,shell=True)

# %%
widths0 = np.loadtxt("data0.dat")
widths100 = np.loadtxt("data100.dat")
widths200 = np.loadtxt("data200.dat")
widths300 = np.loadtxt("data300.dat")

widths06t = np.loadtxt("data06t.dat")
widths1006t = np.loadtxt("data1006t.dat")
widths2006t = np.loadtxt("data2006t.dat")
widths3006t = np.loadtxt("data3006t.dat")

widths07t = np.loadtxt("data07t.dat")
widths1007t = np.loadtxt("data1007t.dat")
widths2007t = np.loadtxt("data2007t.dat")
widths3007t = np.loadtxt("data3007t.dat")

theta = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
figure(figsize=(9.5, 9))
ylabel("$\mathrm{Width}\ (\AA)$", fontsize='25')
xlabel(r"$cos(\theta)$", fontsize='25')
plot(theta, widths0, c ='r', linewidth=2.5)
plot(theta, widths100, c='b', linewidth=2.5)
plot(theta, widths200, c= 'g', linewidth=2.5)
plot(theta, widths300, c = 'k', linewidth=2.5)

# %%
figure(figsize=(9.5, 9))
ylabel("$\mathrm{Width}\ (\AA)$", fontsize='25')
xlabel(r"$cos(\theta)$", fontsize='25')
plot(theta, widths06t, c ='r', linewidth=2.5)
plot(theta, widths1006t, c='b', linewidth=2.5)
plot(theta, widths2006t, c= 'g', linewidth=2.5)
plot(theta, widths3006t, c = 'k', linewidth=2.5)

# %%
figure(figsize=(9.5, 9))
ylabel("$\mathrm{Width}\ (\AA)$", fontsize='25')
xlabel(r"$cos(\theta)$", fontsize='25')
plot(theta, widths07t, c ='r', linewidth=2.5)
#plot(theta, widths1007t, c='b', linewidth=2.5)
plot(theta, widths2007t, c= 'g', linewidth=2.5)
plot(theta, widths3007t, c = 'k', linewidth=2.5)
