# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# #Homogeneous

# %%
# !wc -l ../data/Central/Rotating0Sphere5t.ascii #check this
# !wc -l ../data/Central/Rotating100Sphere5t.ascii
# !wc -l ../data/Central/Rotating200Sphere5t.ascii
# !wc -l ../data/Central/Rotating300Sphere5t.ascii

# !wc -l ../data/Central/Rotating0Sphere6t.ascii
# !wc -l ../data/Central/Rotating100Sphere6t.ascii
# !wc -l ../data/Central/Rotating200Sphere6t.ascii
# !wc -l ../data/Central/Rotating300Sphere6t.ascii

# !wc -l ../data/Central/Rotating0Sphere7t.ascii
# !wc -l ../data/Central/Rotating100Sphere7t.ascii
# !wc -l ../data/Central/Rotating200Sphere7t.ascii   
# !wc -l ../data/Central/Rotating300Sphere7t.ascii
# Out:
# 15024 ../data/Central/Rotating0Sphere5t.ascii
# 100096 ../data/Central/Rotating100Sphere5t.ascii
# 100096 ../data/Central/Rotating200Sphere5t.ascii
# 100096 ../data/Central/Rotating300Sphere5t.ascii
# 100160 ../data/Central/Rotating0Sphere6t.ascii
# 100160 ../data/Central/Rotating100Sphere6t.ascii
# 100160 ../data/Central/Rotating200Sphere6t.ascii
# 100160 ../data/Central/Rotating300Sphere6t.ascii
# 100800 ../data/Central/Rotating0Sphere7t.ascii
# 100080 ../data/Central/Rotating100Sphere7t.ascii
# 100080 ../data/Central/Rotating200Sphere7t.ascii
# 100080 ../data/Central/Rotating300Sphere7t.ascii

# %% [markdown]
# # HOMOGENEOUS MODELS

# %%
# !python Finding_histograms_with_viewing_angle.py Rotating0Sphere5tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_05t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating100Sphere5tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_1005t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating200Sphere5tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_2005t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating300Sphere5tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_3005t.dat

# !python Finding_histograms_with_viewing_angle.py Rotating0Sphere6tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_06t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating100Sphere6tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_1006t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating200Sphere6tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_2006t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating300Sphere6tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_3006t.dat

# !python Finding_histograms_with_viewing_angle.py Rotating0Sphere7tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_07t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating100Sphere7tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_1007t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating200Sphere7tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_2007t.dat
# !python Finding_histograms_with_viewing_angle.py Rotating300Sphere7tHOM.ascii 1 40 0 0 > ../data/Homogeneous_Histograms/spec1_3007t.dat

# %% [markdown]
# #Central Models

# %%
# !python Finding_histograms_with_viewing_angle.py Rotating0Sphere5t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_05tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating100Sphere5t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_1005tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating200Sphere5t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_2005tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating300Sphere5t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_3005tc.dat

# !python Finding_histograms_with_viewing_angle.py Rotating0Sphere6t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_06tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating100Sphere6t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_1006tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating200Sphere6t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_2006tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating300Sphere6t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_3006tc.dat

# !python Finding_histograms_with_viewing_angle.py Rotating0Sphere7t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_07tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating100Sphere7t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_1007tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating200Sphere7t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_2007tc.dat
# !python Finding_histograms_with_viewing_angle.py Rotating300Sphere7t.ascii 1 40 0 1 > ../data/Central_Histograms/spec1_3007tc.dat

# %%
t5v0 = np.loadtxt("../data/Homogeneous_Histograms/spec1_05t.dat")
t5v1 = np.loadtxt("../data/Homogeneous_Histograms/spec1_1005t.dat")
t5v2 = np.loadtxt("../data/Homogeneous_Histograms/spec1_2005t.dat")
t5v3 = np.loadtxt("../data/Homogeneous_Histograms/spec1_3005t.dat")

t6v0 = np.loadtxt("../data/Homogeneous_Histograms/spec1_06t.dat")
t6v1 = np.loadtxt("../data/Homogeneous_Histograms/spec1_1006t.dat")
t6v2 = np.loadtxt("../data/Homogeneous_Histograms/spec1_2006t.dat")
t6v3 = np.loadtxt("../data/Homogeneous_Histograms/spec1_3006t.dat")

t7v0 = np.loadtxt("../data/Homogeneous_Histograms/spec1_07t.dat")
t7v1 = np.loadtxt("../data/Homogeneous_Histograms/spec1_1007t.dat")
t7v2 = np.loadtxt("../data/Homogeneous_Histograms/spec1_2007t.dat")
t7v3 = np.loadtxt("../data/Homogeneous_Histograms/spec1_3007t.dat")

t5v0c = np.loadtxt("../data/Central_Histograms/spec1_05tc.dat")
t5v1c = np.loadtxt("../data/Central_Histograms/spec1_1005tc.dat")
t5v2c = np.loadtxt("../data/Central_Histograms/spec1_2005tc.dat")
t5v3c = np.loadtxt("../data/Central_Histograms/spec1_3005tc.dat")

t6v0c = np.loadtxt("../data/Central_Histograms/spec1_06tc.dat")
t6v1c = np.loadtxt("../data/Central_Histograms/spec1_1006tc.dat")
t6v2c = np.loadtxt("../data/Central_Histograms/spec1_2006tc.dat")
t6v3c = np.loadtxt("../data/Central_Histograms/spec1_3006tc.dat")

t7v0c = np.loadtxt("../data/Central_Histograms/spec1_07tc.dat")
t7v1c = np.loadtxt("../data/Central_Histograms/spec1_1007tc.dat")
t7v2c = np.loadtxt("../data/Central_Histograms/spec1_2007tc.dat")
t7v3c = np.loadtxt("../data/Central_Histograms/spec1_3007tc.dat")

# %%
#Homogeneous model

x70h = t7v0[:,1]*-12.85/100.0
y70h = t7v0[:,0]
x71h = t7v1[:,1]*-12.85/100.0
y71h = t7v1[:,0]
x72h = t7v2[:,1]*-12.85/100.0
y72h = t7v2[:,0]
x73h = t7v3[:,1]*-12.85/100.0
y73h = t7v3[:,0]

x60h = t6v0[:,1]*-12.85/100.0
y60h = t6v0[:,0]
x61h = t6v1[:,1]*-12.85/100.0
y61h = t6v1[:,0]
x62h = t6v2[:,1]*-12.85/100.0
y62h = t6v2[:,0]
x63h = t6v3[:,1]*-12.85/100.0
y63h = t6v3[:,0]

x50h = t5v0[:,1]*-12.85/100.0
y50h = t5v0[:,0]
x51h = t5v1[:,1]*-12.85/100.0
y51h = t5v1[:,0]
x52h = t5v2[:,1]*-12.85/100.0
y52h = t5v2[:,0]
x53h = t5v3[:,1]*-12.85/100.0
y53h = t5v3[:,0]

# %%
#Central model

x70 = t7v0c[:,1]*-12.85/100.0
y70 = t7v0c[:,0]
x71 = t7v1c[:,1]*-12.85/100.0
y71 = t7v1c[:,0]
x72 = t7v2c[:,1]*-12.85/100.0
y72 = t7v2c[:,0]
x73 = t7v3c[:,1]*-12.85/100.0
y73 = t7v3c[:,0]

x60 = t6v0c[:,1]*-12.85/100.0
y60 = t6v0c[:,0]
x61 = t6v1c[:,1]*-12.85/100.0
y61 = t6v1c[:,0]
x62 = t6v2c[:,1]*-12.85/100.0
y62 = t6v2c[:,0]
x63 = t6v3c[:,1]*-12.85/100.0
y63 = t6v3c[:,0]

x50 = t5v0c[:,1]*-12.85/100.0
y50 = t5v0c[:,0]
x51 = t5v1c[:,1]*-12.85/100.0
y51 = t5v1c[:,0]
x52 = t5v2c[:,1]*-12.85/100.0
y52 = t5v2c[:,0]
x53 = t5v3c[:,1]*-12.85/100.0
y53 = t5v3c[:,0]

# %%
def enlarge_labels(ax):
    ticklabels_x = ax.get_xticklabels()
    ticklabels_y = ax.get_yticklabels()
    for label_x in ticklabels_x:
        label_x.set_fontsize(25)
        label_x.set_family('serif')
    for label_y in ticklabels_y:
        label_y.set_fontsize(25)
        label_y.set_family('serif')

# %%
fig = figure(num=None, figsize=(20, 16))
fig.subplots_adjust(hspace=0.00, wspace=0.00,
                    top=0.98, right=0.95, bottom=0.05)

#==============================================================================================================
# ----------------------------------------Panel ---------------------------------------------------------------
#==============================================================================================================

#======================================== 1 ===================================================================

ax = fig.add_subplot(341)
ax.plot(x50h, y50h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x50, y50, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
#ax.set_xlim([-5.50, 5.50])
ax.set_ylim([0, 0.155])
#ax.set_yticks([0, 0.04, 0.08, 0.12])
#ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

#======================================== 2 ===================================================================

ax = fig.add_subplot(3,4,2)
ax.plot(x51h, y51h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x51, y51, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.155])
ax.yaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xlim([-5.50, 5.50])
#ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

#======================================== 3 ===================================================================

ax = fig.add_subplot(3,4,3)
ax.plot(x52h, y52h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x52, y52, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.155])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xlim([-6.00, 6.60])
#ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
enlarge_labels(ax)

#======================================== 4 ===================================================================

ax = fig.add_subplot(3,4,4)
ax.plot(x53h, y53h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x53, y53, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.155])
#ax.set_xlim([-6.00, 6.60])
#ax.set_xticks([-4.00, -2.00, 0, 2.00, 4.00])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

#======================================== 5 ===================================================================

ax = fig.add_subplot(345)
ax.plot(x60h, y60h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x60, y60, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xlim([-5.50, 5.50])
ax.set_ylim([0, 0.085])
#ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
#ax.set_yticks([0, 0.02, 0.04, 0.06, 0.08])
enlarge_labels(ax)

#======================================== 6 ===================================================================

ax = fig.add_subplot(346)
ax.plot(x61h, y61h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x61, y61, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.085])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
#ax.set_xlim([-5.50, 5.50])
enlarge_labels(ax)

#======================================== 7 ===================================================================

ax = fig.add_subplot(347)
ax.plot(x62h, y62h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x62, y62, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.085])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
#ax.set_xlim([-6.00, 6.60])
enlarge_labels(ax)

#======================================== 8 ===================================================================

ax = fig.add_subplot(348)
ax.plot(x63h, y63h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x63, y63, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xticks([-5.00, -2.00, 0, 2.00, 5.00])
ax.set_ylim([0, 0.085])
#ax.set_xlim([-6.00, 6.60])

#======================================== 9 ===================================================================

ax = fig.add_subplot(349)
ax.plot(x70, y70, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x70h, y70h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
#ax.set_xlim([-5.50, 5.50])
ax.set_ylim([0, 0.043])
#ax.set_yticks([0, 0.01, 0.02, 0.03, 0.04])
#ax.set_xticks([-4, -2, 0, 2, 4])
#ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

#======================================== 10 =================================================================

ax = fig.add_subplot(3,4,10)
ax.plot(x71, y71, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x71h, y71h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.set_ylim([0, 0.043])
ax.yaxis.set_major_formatter(plt.NullFormatter())
#ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xticks([-4, -2, 0, 2, 4])
#ax.set_xlim([-5.50, 5.50])
enlarge_labels(ax)

#======================================== 11 ===================================================================

ax = fig.add_subplot(3,4,11)
ax.plot(x72, y72, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x72h, y72h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.set_ylim([0, 0.043])
ax.yaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xticks([-4, -2, 0, 2, 4])
#ax.set_xlim([-6.00, 6.00])
enlarge_labels(ax)

#======================================== 12 ===================================================================

ax = fig.add_subplot(3,4,12)
ax.plot(x73, y73, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x73h, y73h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.set_ylim([0, 0.043])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.set_xticks([-6, -4, -2, 0, 2, 4, 6])
#ax.set_xlim([-6.00, 6.60])
enlarge_labels(ax)
# Velocity axes --------------------------- 

"""
ax.text(-347, 0.466, '514')
ax.text(-327, 0.466, '257')
ax.text(-302, 0.466, '0')
ax.text(-290, 0.466, '-257')
ax.text(-270, 0.466, '-514')

ax.text(-247, 0.466, '514')
ax.text(-227, 0.466, '257')
ax.text(-202, 0.466, '0')
ax.text(-190, 0.466, '-257')
ax.text(-170, 0.466, '-514')

ax.text(-147, 0.466, '514')
ax.text(-127, 0.466, '257')
ax.text(-102, 0.466, '0')
ax.text(-90, 0.466, '-257')
ax.text(-70, 0.466, '-514')

ax.text(-47, 0.466, '514')
ax.text(-27, 0.466, '257')
ax.text(-2, 0.466, '0')
ax.text(11, 0.466, '-257')
ax.text(30, 0.466, '-514')
"""


# --------------------------------Labels-------------------------------------------
#==================================================================================
ax.text(-33.00, -0.007, '$\mathrm{Velocity\ (100km\ s^{-1}}$)', fontsize=30)
#ax.text(-152, -0.02, '$x$', fontsize=35)
ax.text(-62, 0.08, '$\mathrm{Intensity(Arbitrary\ Units)}$', fontsize=30, rotation= 'vertical')
#==================================================================================

# --------------------------------Legends ---------------------- 
#===========================================================================================


#================================ 1 ============================================

ax.text(-55.5, 0.125, '$\mathrm{V_{max} = 0\ km\ s^{-1}}$', fontsize=20)
ax.text(-55.5, 0.122, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)
ax.text(-55.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
#================================ 2 ============================================

ax.text(-39.5, 0.125, '$\mathrm{V_{max} = 100\ km\ s^{-1}}$', fontsize=20)
ax.text(-39.5, 0.122, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)
ax.text(-39.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
#================================ 3 ============================================

ax.text(-23.5, 0.125, '$\mathrm{V_{max} = 200\ km\ s^{-1}}$', fontsize=20)
ax.text(-23.5, 0.122, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)
ax.text(-23.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
#================================ 4 ============================================

ax.text(-7.5, 0.125, '$\mathrm{V_{max} = 300\ km\ s^{-1}}$', fontsize=20)
ax.text(-7.5, 0.122, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)
ax.text(-7.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
#================================ 5 ============================================

ax.text(-55.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-55.5, 0.082, '$\mathrm{V_{max} = 0\ km\ s^{-1}}$', fontsize=20)
ax.text(-55.5, 0.079, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)
#================================ 6 ============================================

ax.text(-39.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-39.5, 0.082, '$\mathrm{V_{max} = 100\ km\ s^{-1}}$', fontsize=20)
ax.text(-39.5, 0.079, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)
#================================ 7 ============================================

ax.text(-23.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-23.5, 0.082, '$\mathrm{V_{max} = 200\ km\ s^{-1}}$', fontsize=20)
ax.text(-23.5, 0.079, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)
#================================ 8 ============================================

ax.text(-7.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-7.5, 0.082, '$\mathrm{V_{max} = 300\ km\ s^{-1}}$', fontsize=20)
ax.text(-7.5, 0.079, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)
#================================ 9 ============================================

ax.text(-55.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-55.5, 0.037, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)
ax.text(-55.5, 0.04, '$\mathrm{V_{max} = 0\ km\ s^{-1}}$', fontsize=20)
#================================ 10 ===========================================

ax.text(-39.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-39.5, 0.04, '$\mathrm{V_{max} = 100\ km\ s^{-1}}$', fontsize=20)
ax.text(-39.5, 0.037, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)
#================================ 11 ===========================================

ax.text(-23.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-23.5, 0.04, '$\mathrm{V_{max} = 200\ km\ s^{-1}}$', fontsize=20)
ax.text(-23.5, 0.037, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)
#================================ 12 ===========================================

ax.text(-7.5, 0.037, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)
ax.text(-7.5, 0.04, '$\mathrm{V_{max} = 300\ km\ s^{-1}}$', fontsize=20)
ax.text(-7.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
#==============================================================================
#==============================================================================



#plt.savefig('../paper/f1.eps', format='eps', bbox_inches='tight', transparent=True, pad_inches=0.04)
