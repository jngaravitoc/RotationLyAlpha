# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Funcion que carga los datos

# %%
def loading_data(filename, distribution):
    if distribution == 0:
        data = loadtxt("../data/Central/" + filename, comments=("#", "nan"))
    elif distribution == 1:
        data = loadtxt("../data/Homogeneous/" + filename)
    kz = data[:,5]
    x = data[:,6]
    nscatt = data[:,8]
      
    return kz, x

# %% [markdown]
# # Funcion que hace los histogramas

# %%
def histo(name, distribution, velocity):
    kz, x = loading_data(name, distribution)
    X = amin(x) + 0.15*abs(amin(x))
    figure(figsize=(10.5, 9))
    histo = hist2d(x, abs(kz), bins=(120 , 120))
    xlabel("$x$", fontsize=25)
    plt.tick_params(axis='both', which='major', labelsize=18)
    ylabel(r"$\mathrm{|k_{z}|}$", fontsize=25)
    text(X, 0.9, velocity + "km/s", fontsize=25, color = 'White')
    colorbar()
    savefig(name+".eps")

# %% [markdown]
# # Central:
# ## Optical Depth: $\tau = 10^5, 10^6, 10^7$
# ## Velocites : $0, 100, 200, 300\ Km/s$

# %%
histo("Rotating0Sphere5t.ascii", 0, "0")
histo("Rotating100Sphere5t.ascii", 0, "100")
histo("Rotating200Sphere5t.ascii", 0, "200")
histo("Rotating300Sphere5t.ascii", 0, "300")

# %%
histo("Rotating0Sphere6t.ascii", 0, "0")
histo("Rotating100Sphere6t.ascii", 0, "100")
histo("Rotating200Sphere6t.ascii", 0, "200")
histo("Rotating300Sphere6t.ascii", 0, "300")

# %%
histo("Rotating0Sphere7t.ascii", 0, "0")
histo("Rotating100Sphere7t.ascii", 0, "100")
histo("Rotating200Sphere7t.ascii", 0, "200")
histo("Rotating300Sphere7t.ascii", 0, "300")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-918fcfa7d438> in <module>()
# ----> 1 histo("Rotating0Sphere7t.ascii", 0, "0")
#       2 histo("Rotating100Sphere7t.ascii", 0, "100")
#       3 histo("Rotating200Sphere7t.ascii", 0, "200")
#       4 histo("Rotating300Sphere7t.ascii", 0, "300")
#
# <ipython-input-48-8971b15244af> in histo(name, distribution, velocity)
#       1 def histo(name, distribution, velocity):
# ----> 2     kz, x = loading_data(name, distribution)
#       3     X = amin(x) + 0.15*abs(amin(x))
#       4     figure(figsize=(10.5, 9))
#       5     histo = hist2d(x, abs(kz), bins=(120 , 120))
#
# <ipython-input-63-249a76ca3e32> in loading_data(filename, distribution)
#       1 def loading_data(filename, distribution):
#       2     if distribution == 0:
# ----> 3         data = loadtxt("../data/Central/" + filename, comments=("#", "nan"))
# ...

# %% [markdown]
# # Homogeneous:
# ## Optical Depth: $\tau=10^5,10^6,10^7$
# ## Velocites : $0,100,200,300 Km/s$

# %%
histo("Rotating0Sphere6tHOM.ascii", 1, "0")
histo("Rotating100Sphere6tHOM.ascii", 1, "100")
histo("Rotating200Sphere6tHOM.ascii", 1, "200")
histo("Rotating300Sphere6tHOM.ascii", 1, "300")

# %%
histo("Rotating0Sphere5tHOM.ascii", 1, "0")
histo("Rotating100Sphere5tHOM.ascii", 1, "100")
histo("Rotating200Sphere5tHOM.ascii", 1, "200")
histo("Rotating300Sphere5tHOM.ascii", 1, "300")
