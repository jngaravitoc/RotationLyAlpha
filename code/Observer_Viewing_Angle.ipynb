# %%
# %pylab inline
import matplotlib.pyplot as plt
from math import*
import numpy as np
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data = np.loadtxt('../data/Homogeneous/Rotating100Sphere5tHOM.ascii')

kx = data[:, 3]
ky = data[:, 4]
kz = data[:, 5]

# %%
theta = pi/2.0
R = np.array([0, sin(theta), cos(theta)])
k = np.sqrt(kx**2 + ky**2 + kz**2)
N = len(kx)
print R
# Out:
# [  0.00000000e+00   1.00000000e+00   6.12323400e-17]

# %%
print amin(k), amax(k), type(k), len(k)
# Out:
# 0.999999918136 1.00000008086 <type 'numpy.ndarray'> 99968

# %%
miu = abs(kx[:]*R[0] +  ky[:]*R[1] +  kz[:]*R[2])

# %%
len(miu), sum(miu), amin(miu), amax(miu)
# Out:
# (99968, 49833.655149833394, 5.6045009999503864e-06, 0.99996799999999997)

# %%
print len(kx), amin(kx), amax(kx)
cos(pi/10.0)
# Out:
# 99968 -0.9999736 0.9999138
# 0.9510565162951535

# %%
def delta_n(cutoff):

    deltaN = []
    for i in range(len(miu)):
        if miu[i] >= cutoff:
            deltaN.append(miu[i])
    print len(deltaN)

# %%
delta_N = len(deltaN)

# %%
F = (2*delta_N)/(N*sin(theta)*(pi/10.0 ))
print F
# Out:
# 0.320258566265

# %%
scatter(kx, ky)
scatter()
