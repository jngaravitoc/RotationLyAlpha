# %%
# %pylab inline
import numpy as np
font = {'size':25, 'family':'serif'}
matplotlib.rc('font', **font)
import scipy.optimize as optimization
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Uploading the data

# %%
t7v0HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating0Sphere7tHOM.ascii")
t7v1HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating100Sphere7tHOM.ascii")
t7v2HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating200Sphere7tHOM.ascii")
t7v3HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating300Sphere7tHOM.ascii")

t6v0HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating0Sphere6tHOM.ascii")
t6v1HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating100Sphere6tHOM.ascii")
t6v2HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating200Sphere6tHOM.ascii")
t6v3HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating300Sphere6tHOM.ascii")

t5v0HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating0Sphere5tHOM.ascii")
t5v1HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating100Sphere5tHOM.ascii")
t5v2HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating200Sphere5tHOM.ascii")
t5v3HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating300Sphere5tHOM.ascii")

t7v0 = np.loadtxt("../data/Central_Histograms/HistogramRotating0Sphere7t.ascii")
t7v1 = np.loadtxt("../data/Central_Histograms/HistogramRotating100Sphere7t.ascii")
t7v2 = np.loadtxt("../data/Central_Histograms/HistogramRotating200Sphere7t.ascii")
t7v3 = np.loadtxt("../data/Central_Histograms/HistogramRotating300Sphere7t.ascii")

t6v0 = np.loadtxt("../data/Central_Histograms/HistogramRotating0Sphere6t.ascii")
t6v1 = np.loadtxt("../data/Central_Histograms/HistogramRotating100Sphere6t.ascii")
t6v2 = np.loadtxt("../data/Central_Histograms/HistogramRotating200Sphere6t.ascii")
t6v3 = np.loadtxt("../data/Central_Histograms/HistogramRotating300Sphere6t.ascii")

t5v0 = np.loadtxt("../data/Central_Histograms/HistogramRotating0Sphere5t.ascii")
t5v1 = np.loadtxt("../data/Central_Histograms/HistogramRotating100Sphere5t.ascii")
t5v2 = np.loadtxt("../data/Central_Histograms/HistogramRotating200Sphere5t.ascii")
t5v3 = np.loadtxt("../data/Central_Histograms/HistogramRotating300Sphere5t.ascii")

# %%
# central model

x70 = t7v0[:,0]*-12.85/100.0
y70 = t7v0[:,1]
x71 = t7v1[:,0]*-12.85/100.0
y71 = t7v1[:,1]
x72 = t7v2[:,0]*-12.85/100.0
y72 = t7v2[:,1]
x73 = t7v3[:,0]*-12.85/100.0
y73 = t7v3[:,1]

x60 = t6v0[:,0]*-12.85/100.0
y60 = t6v0[:,1]
x61 = t6v1[:,0]*-12.85/100.0
y61 = t6v1[:,1]
x62 = t6v2[:,0]*-12.85/100.0
y62 = t6v2[:,1]
x63 = t6v3[:,0]*-12.85/100.0
y63 = t6v3[:,1]

x50 = t5v0[:,0]*-12.85/100.0
y50 = t5v0[:,1]
x51 = t5v1[:,0]*-12.85/100.0
y51 = t5v1[:,1]
x52 = t5v2[:,0]*-12.85/100.0
y52 = t5v2[:,1]
x53 = t5v3[:,0]*-12.85/100.0
y53 = t5v3[:,1]

#Homogeneous model

x70h = t7v0HOM[:,0]*-12.85/100.0
y70h = t7v0HOM[:,1]
x71h = t7v1HOM[:,0]*-12.85/100.0
y71h = t7v1HOM[:,1]
x72h = t7v2HOM[:,0]*-12.85/100.0
y72h = t7v2HOM[:,1]
x73h = t7v3HOM[:,0]*-12.85/100.0
y73h = t7v3HOM[:,1]

x60h = t6v0HOM[:,0]*-12.85/100.0
y60h = t6v0HOM[:,1]
x61h = t6v1HOM[:,0]*-12.85/100.0
y61h = t6v1HOM[:,1]
x62h = t6v2HOM[:,0]*-12.85/100.0
y62h = t6v2HOM[:,1]
x63h = t6v3HOM[:,0]*-12.85/100.0
y63h = t6v3HOM[:,1]

x50h = t5v0HOM[:,0]*-12.85/100.0
y50h = t5v0HOM[:,1]
x51h = t5v1HOM[:,0]*-12.85/100.0
y51h = t5v1HOM[:,1]
x52h = t5v2HOM[:,0]*-12.85/100.0
y52h = t5v2HOM[:,1]
x53h = t5v3HOM[:,0]*-12.85/100.0
y53h = t5v3HOM[:,1]

# %% [markdown]
# # Plotting the data corresponding to the homogeneous model

# %%
def enlarge_labels(ax):
    ticklabels_x = ax.get_xticklabels()
    ticklabels_y = ax.get_yticklabels()
    for label_x in ticklabels_x:
        label_x.set_fontsize(25)
        label_x.set_family('serif')
    for label_y in ticklabels_y:
        label_y.set_fontsize(25)
        label_y.set_family('serif')

# %%
fig = figure(num=None, figsize=(20, 16))
fig.subplots_adjust(hspace=0.00, wspace=0.00,
                    top=0.98, right=0.95, bottom=0.05)


ax = fig.add_subplot(341)
ax.plot(x50h, y50h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x50, y50, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_xlim([-5.50, 5.50])
ax.set_ylim([0, 0.155])
ax.set_yticks([0, 0.04, 0.08, 0.12])
ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

ax = fig.add_subplot(3,4,2)
ax.plot(x51h, y51h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x51, y51, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.155])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_xlim([-5.50, 5.50])
ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

ax = fig.add_subplot(3,4,3)
ax.plot(x52h, y52h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x52, y52, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.155])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xlim([-6.00, 6.60])
ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
enlarge_labels(ax)

ax = fig.add_subplot(3,4,4)
ax.plot(x53h, y53h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x53, y53, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.155])
ax.set_xlim([-6.00, 6.60])
ax.set_xticks([-4.00, -2.00, 0, 2.00, 4.00])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

ax = fig.add_subplot(345)
ax.plot(x60h, y60h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x60, y60, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xlim([-5.50, 5.50])
ax.set_ylim([0, 0.085])
ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
ax.set_yticks([0, 0.02, 0.04, 0.06, 0.08])
enlarge_labels(ax)

ax = fig.add_subplot(346)
ax.plot(x61h, y61h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x61, y61, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.085])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
ax.set_xlim([-5.50, 5.50])
enlarge_labels(ax)

ax = fig.add_subplot(347)
ax.plot(x62h, y62h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x62, y62, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.set_ylim([0, 0.085])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xticks([-4.50, -2.00, 0, 2.00, 4.50])
ax.set_xlim([-6.00, 6.60])
enlarge_labels(ax)

ax = fig.add_subplot(348)
ax.plot(x63h, y63h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.plot(x63, y63, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xticks([-5.00, -2.00, 0, 2.00, 5.00])
ax.set_ylim([0, 0.085])
ax.set_xlim([-6.00, 6.60])

ax = fig.add_subplot(349)
ax.plot(x70, y70, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x70h, y70h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.set_xlim([-5.50, 5.50])
ax.set_ylim([0, 0.043])
ax.set_yticks([0, 0.01, 0.02, 0.03, 0.04])
ax.set_xticks([-4, -2, 0, 2, 4])
#ax.xaxis.set_major_formatter(plt.NullFormatter())
enlarge_labels(ax)

ax = fig.add_subplot(3,4,10)
ax.plot(x71, y71, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x71h, y71h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.set_ylim([0, 0.043])
ax.yaxis.set_major_formatter(plt.NullFormatter())
#ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xticks([-4, -2, 0, 2, 4])
ax.set_xlim([-5.50, 5.50])

ax = fig.add_subplot(3,4,11)
ax.plot(x72, y72, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x72h, y72h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.set_ylim([0, 0.043])
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_xticks([-4, -2, 0, 2, 4])
ax.set_xlim([-6.00, 6.00])

ax = fig.add_subplot(3,4,12)
ax.plot(x73, y73, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax.plot(x73h, y73h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax.set_ylim([0, 0.043])
ax.yaxis.set_major_formatter(plt.NullFormatter())
#ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xticks([-6, -4, -2, 0, 2, 4, 6])
ax.set_xlim([-6.00, 6.60])

# Velocity axes --------------------------- 

"""
ax.text(-347, 0.466, '514')
ax.text(-327, 0.466, '257')
ax.text(-302, 0.466, '0')
ax.text(-290, 0.466, '-257')
ax.text(-270, 0.466, '-514')

ax.text(-247, 0.466, '514')
ax.text(-227, 0.466, '257')
ax.text(-202, 0.466, '0')
ax.text(-190, 0.466, '-257')
ax.text(-170, 0.466, '-514')

ax.text(-147, 0.466, '514')
ax.text(-127, 0.466, '257')
ax.text(-102, 0.466, '0')
ax.text(-90, 0.466, '-257')
ax.text(-70, 0.466, '-514')

ax.text(-47, 0.466, '514')
ax.text(-27, 0.466, '257')
ax.text(-2, 0.466, '0')
ax.text(11, 0.466, '-257')
ax.text(30, 0.466, '-514')
"""
ax.text(-26.00, -0.007, 'Velocity ($\mathrm{100km\ s^{-1}}$)', fontsize=30)
#ax.text(-152, -0.02, '$x$', fontsize=35)
ax.text(-48.85, 0.0706, '$\mathrm{Intensity(Arbitrary\ Units)}$', fontsize=30, rotation= 'vertical')

# Legends ----------------------

ax.text(-33.50+2.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-33.50+2.5, 0.037, '$\mathrm{V_{max} = 100\ km\ s^{-1}}$', fontsize=20)
ax.text(-33.50+2.5, 0.04, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)

ax.text(-20.50+2.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-20.50+2.5, 0.037, '$\mathrm{V_{max} = 200\ km\ s^{-1}}$', fontsize=20)
ax.text(-20.50+2.5, 0.04, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)

ax.text(-8.0+2.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-8.00+2.5, 0.04, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)
ax.text(-8.0+2.5, 0.037, '$\mathrm{V_{max} = 300\ km\ s^{-1}}$', fontsize=20)

ax.text(-45.0+1.5, 0.034, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-45.0+1.5, 0.04, r'$\mathrm{\tau_{H} = 10^{7}}$', fontsize=20)
ax.text(-45.00+1.5, 0.037, '$\mathrm{V_{max} = 0\ km\ s^{-1}}$', fontsize=20)

ax.text(-33.50+2.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-33.50+2.5, 0.079, '$\mathrm{V_{max} = 100\ km\ s^{-1}}$', fontsize=20)
ax.text(-33.50+2.5, 0.082, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)

ax.text(-20.50+2.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-20.50+2.5, 0.079, '$\mathrm{V_{max} = 200\ km\ s^{-1}}$', fontsize=20)
ax.text(-20.50+2.5, 0.082, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)

ax.text(-8.00+2.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-8.00+2.5, 0.079, '$\mathrm{V_{max} = 300\ km\ s^{-1}}$', fontsize=20)
ax.text(-8.00+2.5, 0.082, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)

ax.text(-45.0+1.5, 0.076, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-45.0+1.5, 0.079, '$\mathrm{V_{max} = 0\ km\ s^{-1}}$', fontsize=20)
ax.text(-45.0+1.5, 0.082, r'$\mathrm{\tau_{H} = 10^{6}}$', fontsize=20)

ax.text(-33.5+2.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-33.50+2.5, 0.122, '$\mathrm{V_{max} = 100\ km\ s^{-1}}$', fontsize=20)
ax.text(-33.50+2.5, 0.125, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)

ax.text(-20.5+2.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-20.50+2.5, 0.122, '$\mathrm{V_{max} = 200\ km\ s^{-1}}$', fontsize=20)
ax.text(-20.50+2.5, 0.125, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)

ax.text(-8.00+2.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-8.00+2.5, 0.122, '$\mathrm{V_{max} = 300\ km\ s^{-1}}$', fontsize=20)
ax.text(-8.00+2.5, 0.125, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)

ax.text(-45.0+1.5, 0.119, r'$\mathrm{\theta = \pi/2.0}$', fontsize=20)
ax.text(-45.0+1.5, 0.122, '$\mathrm{V_{max} = 0\ km\ s^{-1}}$', fontsize=20)
ax.text(-45.0+1.5, 0.125, r'$\mathrm{\tau_{H} = 10^{5}}$', fontsize=20)




plt.savefig('../paper/f1.eps', format='eps', bbox_inches='tight', transparent=True, pad_inches=0.04)

# %%
## Plot data Homogeneous Model 
#V = (- 12.8451673301 * x)

figure(num=None, figsize=(10.5, 9))
ax1 = subplot(1, 1, 1)
ax1.plot(x70, y70, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-.', c = 'k')
#plt.plot(V, y, label=r'$\mathrm{50 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5)
ax1.plot(x71,y71, label='$\mathrm{100 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = ':', c = 'k')
ax1.plot(x72,y72, label='$\mathrm{200 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax1.plot(x73,y73, label='$\mathrm{300 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax1.legend(loc='upper left', fontsize = 22)
ax1.set_xlabel (r'$x$', fontsize=35)
ax1.set_ylabel ('$\mathrm{Intensity}$ $\mathrm{(Arbitrary Units)}$', fontsize=35)

ax1.tick_params(axis='both', which='major', labelsize=35)
new1_tick_locations = np.array([0, 0.01, 0.02, 0.03 ,0.038])
ax1.set_yticks(new1_tick_locations)
ax1.set_yticklabels([0.0, 0.01, 0.02, 0.03, 0.040])

new_tick_locations = np.array([0, .166, .3333, .5, .666, .833, 1])
ax2 = ax1.twiny()
ax2.set_xticks(new_tick_locations)
ax2.tick_params(labelsize=35)
ax2.set_xticklabels(['-768','-512','-256', '0', '256', '512', '768'])
plt.text(0.72, 0.034, r"$\mathrm{\tau_{H}=10^7}$", fontsize=35)
plt.text(0.72, 0.037, r"$\mathrm{Central}$", fontsize = 35)
plt.text(0.27, 0.044, '$\mathrm{Velocity}$ $\mathrm{(km}$ $\mathrm{s^{-1})}$', fontsize=35)
savefig('../paper/f1_1.eps', bbox_inches='tight', format='eps', transparent=True)

plt.show()
#print  (1/6.0)*5
#print 12.8*60, 12.8*40, 12.8*20

# %% [markdown]
# # Plotting the data corresponding to the central model

# %%
figure(num=None, figsize=(10.5, 9))

ax1 = subplot(1, 1, 1)
ax1.plot(x70h, y70h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-.', c = 'k')
ax1.plot(x71h,y71h, label='$\mathrm{100 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = ':', c = 'k')
ax1.plot(x72h,y72h, label='$\mathrm{200 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax1.plot(x73h,y73h, label='$\mathrm{300 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax1.legend(loc='upper left', fontsize = 22)
ax1.set_xlabel (r'$x$', fontsize=35)
ax1.set_ylabel ('$\mathrm{Intensity}$ $\mathrm{(Arbitrary Units)}$', fontsize=35)
#plt.title(r"$\mathrm{Central}$ , $\mathrm{\tau_{H}=10^7}$", fontsize=35)
ax1.tick_params(axis='both', which='major', labelsize=35)
new1_tick_locations = np.array([0, 0.01, 0.02, 0.03 ,0.038])
ax1.set_yticks(new1_tick_locations)
ax1.set_yticklabels([0.0, 0.01, 0.02, 0.03, 0.040])

new_tick_locations = np.array([0, .166, .3333, .5, .666, .833, 1])

ax2 = ax1.twiny()
ax2.set_xticks(new_tick_locations)
ax2.tick_params(labelsize=35)
ax2.set_xticklabels(['-768','-512','-256', '0', '256', '512', '768'])
plt.text(0.65, 0.034, r"$\mathrm{\tau_{H}=10^7}$", fontsize=35)
plt.text(0.65, 0.037, r"$\mathrm{Homogeneous}$", fontsize = 35)
plt.text(0.27, 0.044, '$\mathrm{Velocity}$ $\mathrm{(km}$ $\mathrm{s^{-1})}$', fontsize=35)

savefig('../paper/f1_2.eps', bbox_inches='tight', format='eps')

plt.show()

# %% [markdown]
# # Measuring FWHM

# %%
def FWHMHomogeneous(x, y, name, mode):
    h = amax(y)
    half = h/2.0
    Y = []
    X = []
    A = []
    if(mode == 7):
        m = 15
    elif(mode==6):
        m = 8
    elif(mode==5):
        m = 4.0
    for i in range(len(x)):
        if(np.abs(x[i])>m):
            X.append(x[i])
            Y.append(y[i])
    for i in range(len(X)):
        a = np.abs(Y[i]-half)
        A.append(a)
    z = amin(A)
    xx = A.index(z)
    FWHM = np.abs(2*X[xx])
    f = open('../data/HomogeneousWidhts'+name+'.dat', 'w')
    f.write(str(FWHM))
    f.close
    #print FWHM
    
def FWHMcentral(x, y, name, mode):
    h = amax(y)
    half = h/2.0
    #print half
    Y = []
    X = []
    A = []
    if(mode == 7):
        m = 15
    elif(mode==6):
        m = 10
    elif(mode==5):
        m = 4
    for i in range(len(x)):
        if(np.abs(x[i])>m):
            X.append(x[i])
            Y.append(y[i])
    for i in range(len(X)):
        a = np.abs(Y[i]-half)
        A.append(a)
    z = amin(A)
    xx = A.index(z)
    FWHM = np.abs(2*X[xx])
    f = open('../data/CentralWidhts'+name+'.dat', 'w')
    f.write(str(FWHM))
    f.close
    #print FWHM
    
    
    
FWHMHomogeneous(x70h, y70h, "t7v0hom", 7)
FWHMHomogeneous(x71h, y71h, "t7v100hom", 7)
FWHMHomogeneous(x72h, y72h, "t7v200hom", 7)
FWHMHomogeneous(x73h, y73h, "t7v300hom", 7)
FWHMHomogeneous(x60h, y60h, "t6v0hom", 6)
FWHMHomogeneous(x61h, y61h, "t6v100hom", 6)
FWHMHomogeneous(x62h, y62h, "t6v200hom", 6)
FWHMHomogeneous(x63h, y63h, "t6v300hom", 6)
FWHMHomogeneous(x50h, y50h, "t5v0hom", 5)
FWHMHomogeneous(x51h, y51h, "t5v100hom", 5)
FWHMHomogeneous(x52h, y52h, "t5v200hom", 5)
FWHMHomogeneous(x53h, y53h, "t5v300hom", 5)

FWHMcentral(x70, y70, "t7v0", 7)
FWHMcentral(x71, y71, "t7v100", 7)
FWHMcentral(x72, y72, "t7v200", 7)
FWHMcentral(x73, y73, "t7v300", 7)
FWHMcentral(x60, y60, "t6v0", 6)
FWHMcentral(x61, y61, "t6v100", 6)
FWHMcentral(x62, y62, "t6v200", 6)
FWHMcentral(x63, y63, "t6v300", 6)
FWHMcentral(x50, y50, "t5v0", 5)
FWHMcentral(x51, y51, "t5v100", 5)
FWHMcentral(x52, y52, "t5v200", 5)
FWHMcentral(x53, y53, "t5v300", 5)

#X.index(35.5)
#print X
#list.index?

# %% [markdown]
# # Reading data to make FWHM plot

# %%
w70h = np.loadtxt("../data/HomogeneousWidhtst7v0hom.dat")
w71h = np.loadtxt("../data/HomogeneousWidhtst7v100hom.dat")
w72h = np.loadtxt("../data/HomogeneousWidhtst7v200hom.dat")
w73h = np.loadtxt("../data/HomogeneousWidhtst7v300hom.dat")
w60h = np.loadtxt("../data/HomogeneousWidhtst6v0hom.dat")
w61h = np.loadtxt("../data/HomogeneousWidhtst6v100hom.dat")
w62h = np.loadtxt("../data/HomogeneousWidhtst6v200hom.dat")
w63h = np.loadtxt("../data/HomogeneousWidhtst6v300hom.dat")
w50h = np.loadtxt("../data/HomogeneousWidhtst5v0hom.dat")
w51h = np.loadtxt("../data/HomogeneousWidhtst5v100hom.dat")
w52h = np.loadtxt("../data/HomogeneousWidhtst5v200hom.dat")
w53h = np.loadtxt("../data/HomogeneousWidhtst5v300hom.dat")

w70 = np.loadtxt("../data/CentralWidhtst7v0.dat")
w71 = np.loadtxt("../data/CentralWidhtst7v100.dat")
w72 = np.loadtxt("../data/CentralWidhtst7v200.dat")
w73 = np.loadtxt("../data/CentralWidhtst7v300.dat")
w60 = np.loadtxt("../data/CentralWidhtst6v0.dat")
w61 = np.loadtxt("../data/CentralWidhtst6v100.dat")
w62 = np.loadtxt("../data/CentralWidhtst6v200.dat")
w63 = np.loadtxt("../data/CentralWidhtst6v300.dat")
w50 = np.loadtxt("../data/CentralWidhtst5v0.dat")
w51 = np.loadtxt("../data/CentralWidhtst5v100.dat")
w52 = np.loadtxt("../data/CentralWidhtst5v200.dat")
w53 = np.loadtxt("../data/CentralWidhtst5v300.dat")

w7h = np.array([w70h, w71h, w72h, w73h])
w7 = np.array([w70, w71, w72, w73])

w6h = np.array([w60h, w61h, w62h, w63h])
w6 = np.array([w60, w61, w62, w63])

w5h = np.array([w50h, w51h, w52h, w53h])
w5 = np.array([w50, w51, w52, w53])

# %%
def linearfit(x, a, m):
    return a + m*x
## Data for Fitting

x1 = w70h*12.85
x2 = w60h*12.85
x3 = w50h*12.85
x4 = w70*12.85
x5 = w60*12.85
x6 = w50*12.85

xdatah = np.array([0.0/x1, 100.0/x1, 200.0/x1, 300.0/x1, 100.0/x2, 200.0/x2, 300.0/x2, 100.0/x3, 200.0/x3, 300.0/x3])
ydatah = np.array([(w70h*12.85)/(w70h*12.85), (w71h*12.85)/(w70h*12.85),(w72h*12.85)/(w70h*12.85), (w73h*12.85)/(w70h*12.85), (w61h*12.85)/(w60h*12.85),(w62h*12.85)/(w60h*12.85), (w63h*12.85)/(w60h*12.85), (w51h*12.85)/(w50h*12.85),(w52h*12.85)/(w50h*12.85), (w53h*12.85)/(w50h*12.85)])

xdata = np.array([0.0/x4, 100.0/x4, 200.0/x4, 300.0/x4, 100.0/x5, 200.0/x5, 300.0/x5, 100.0/x6, 200.0/x6, 300.0/x6])
ydata = np.array([(w70*12.85)/(w70*12.85), (w71*12.85)/(w70*12.85),(w72*12.85)/(w70*12.85), (w73*12.85)/(w70*12.85), (w61*12.85)/(w60*12.85),(w62*12.85)/(w60*12.85), (w63*12.85)/(w60*12.85), (w51*12.85)/(w50*12.85),(w52*12.85)/(w50*12.85), (w53*12.85)/(w50*12.85)])

x0  = np.array([0.0, 0.0])
ah, b =  optimization.curve_fit(linearfit, xdatah, ydatah, x0)
a, b =  optimization.curve_fit(linearfit, xdata, ydata, x0)
print a[0], a[1], ah[0], ah[1]
# Out:
# 1.03795187109 0.25672361726 1.00895829943 0.504540679932

# %%
fig = figure(num=None, figsize=(19,7))
fig.subplots_adjust(hspace=0.00, wspace=0.17,
                    top=0.98, right=0.95, bottom=0.05)
#plt.tick_params(axis='both', which='major', labelsize=25)

v = [0, 100, 200, 300]


ax = fig.add_subplot(121)

ax.plot(v, w7*12.85, linewidth = 2.5, c = 'k')
ax.plot(v, w6*12.85, linewidth = 2.5, c = 'k')
ax.plot(v, w5*12.85, linewidth = 2.5, c = 'k')

ax.plot(v, w7h*12.85, linewidth = 2.5, c = 'k', linestyle='--')
ax.plot(v, w6h*12.85, linewidth = 2.5, c = 'k', linestyle='--')
ax.plot(v, w5h*12.85, linewidth = 2.5, c = 'k', linestyle='--')

ax = fig.add_subplot(122)

ax = fig.add_subplot(122)
p1, = ax.plot(v/(w70h*12.85), (w7h*12.85)/(w70h*12.85),  linewidth = 1.5, marker = '^', ms=10, c= 'k', linestyle = '--')
p2, = ax.plot(v/(w60h*12.85), (w6h*12.85)/(w60h*12.85),  linewidth = 1.5, marker = 's', ms=10, c= 'k', linestyle = '--')
p3, = ax.plot(v/(w50h*12.85), (w5h*12.85)/(w50h*12.85),  linewidth = 1.5, marker = 'o', ms=10, c= 'k', linestyle = '--')

p4, = ax.plot(v/(w50*12.85), (w5*12.85)/(w50*12.85), linewidth = 1.5, marker = 'o', ms=10, c= 'k')
p5, = ax.plot(v/(w60*12.85), (w6*12.85)/(w60*12.85), linewidth = 1.5, marker = 's', ms=10, c= 'k')
p6, = ax.plot(v/(w70*12.85), (w7*12.85)/(w70*12.85), linewidth = 1.5, marker = '^', ms=10, c= 'k')
# Fitting
xdata2 = np.linspace(0, 2.5, 100)
p7, = ax.plot(xdata2, ah[0] + ah[1]*xdata2, linewidth=2.5, c='r', linestyle='--')
p8, = ax.plot(xdata2, a[0] + a[1]*xdata2, linewidth=2.5, c='r', linestyle='-')
#ax.set_xlim([0, 2.7])
ax.legend([p1, p2, p3, p7, p8], [r'$\tau_H=10^{7}$',r'$\tau_H=10^{6}$', r'$\tau_H=10^{5}$', 'Homogeneous', 'Central'], loc ='upper left', ncol=1, fontsize=20)

# Labels -------------------------------------------------------------------------------------------

ax.text(0.8, 0.85, r'$\mathrm{V_{max}/FWHM_o}$', fontsize=35)
ax.text(-1.7, 0.85, r'$\mathrm{V_{max}(km\ s^{-1})}$', fontsize=35)
ax.text (-0.4, 2.0, r'$\mathrm{FWHM/FWHM_o} $', fontsize=35, rotation='vertical')
ax.text (-3.35, 2.0, r'$\mathrm{FWHM(km\ s^{-1})}$', fontsize=35, rotation='vertical')

#ax.text(0.8, 0.85, r'$\mathrm{\dfrac{FWHM}{FWHM_0}}$', fontsize=35)

#savefig('../paper/f2.eps', format='eps', transparent=True, bbox_inches='tight')

# %%
# Data measured by my eye# 
t7 = np.array([12.13, 15, 21.24, 27.73])                 
t6 = np.array([5.99, 9.397, 13.99, 15.1756])
t5 = np.array([3.21, 6.311, 7.462, 9.00])

t7hom = np.array([13.51, 15.63308, 21.4569, 23.6824])                 
#t6hom = np.array([5.42, 9.68307, 12.074, 14.0267])
t6hom = np.array([8.23, 10.69, 12.074, 14.0267])
#t5hom = np.array([3.92, 6.425, 7.929, 9.889])
t5hom = np.array([5.051, 8.18, 10.96, 16.1531])

# %% [markdown]
# # Errors of Last Sqaure fitting

# %% [markdown]
# Reference: Taylor page 185

# %%
def error(x, y, mode):
    X2 = sum(x**2)
    X = sum(x)    #X2 = (sum(xdata[i]))**2
    N = float(len(x))
    Del = N*X2 - X**2
    if mode == 0:
        sigma = sum((y - a[0] -a[1]*x)**2)
    elif mode == 1:
        sigma = sum((y - ah[0] -ah[1]*x)**2)
    sigma_y = sqrt((1/(N-2))*sigma)
    SIGMA = sigma_y*sqrt(N/float(Del))
    return  Del, sigma_y, SIGMA
l = error(xdata, ydata, 0)
lh = error(xdatah, ydatah, 1)

print l, lh
# Out:
# (34.282005375617814, 0.07676842457562856, 0.041461930456495558) (39.480695863154807, 0.1233572817581845, 0.062082956636524723)
