# %%
# %pylab inline
from scipy.optimize import curve_fit
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Uploading the data

# %%
t7v0HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating0Sphere7tHOM.ascii")
t7v1HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating100Sphere7tHOM.ascii")
t7v2HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating200Sphere7tHOM.ascii")
t7v3HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating300Sphere7tHOM.ascii")

t6v0HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating0Sphere6tHOM.ascii")
t6v1HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating100Sphere6tHOM.ascii")
t6v2HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating200Sphere6tHOM.ascii")
t6v3HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating300Sphere6tHOM.ascii")

t5v0HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating0Sphere5tHOM.ascii")
t5v1HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating100Sphere5tHOM.ascii")
t5v2HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating200Sphere5tHOM.ascii")
t5v3HOM = np.loadtxt("../data/Homogeneous_Histograms/HistogramRotating300Sphere5tHOM.ascii")

t7v0 = np.loadtxt("../data/Central_Histograms/HistogramRotating0Sphere7t.ascii")
t7v1 = np.loadtxt("../data/Central_Histograms/HistogramRotating100Sphere7t.ascii")
t7v2 = np.loadtxt("../data/Central_Histograms/HistogramRotating200Sphere7t.ascii")
t7v3 = np.loadtxt("../data/Central_Histograms/HistogramRotating300Sphere7t.ascii")

t6v0 = np.loadtxt("../data/Central_Histograms/HistogramRotating0Sphere6t.ascii")
t6v1 = np.loadtxt("../data/Central_Histograms/HistogramRotating100Sphere6t.ascii")
t6v2 = np.loadtxt("../data/Central_Histograms/HistogramRotating200Sphere6t.ascii")
t6v3 = np.loadtxt("../data/Central_Histograms/HistogramRotating300Sphere6t.ascii")

t5v0 = np.loadtxt("../data/Central_Histograms/HistogramRotating0Sphere5t.ascii")
t5v1 = np.loadtxt("../data/Central_Histograms/HistogramRotating100Sphere5t.ascii")
t5v2 = np.loadtxt("../data/Central_Histograms/HistogramRotating200Sphere5t.ascii")
t5v3 = np.loadtxt("../data/Central_Histograms/HistogramRotating300Sphere5t.ascii")

# %%
x70 = t7v0[:,0]
y70 = t7v0[:,1]
x71 = t7v1[:,0]
y71 = t7v1[:,1]
x72 = t7v2[:,0]
y72 = t7v2[:,1]
x73 = t7v3[:,0]
y73 = t7v3[:,1]

x60 = t6v0[:,0]
y60 = t6v0[:,1]
x61 = t6v1[:,0]
y61 = t6v1[:,1]
x62 = t6v2[:,0]
y62 = t6v2[:,1]
x63 = t6v3[:,0]
y63 = t6v3[:,1]

x50 = t5v0[:,0]
y50 = t5v0[:,1]
x51 = t5v1[:,0]
y51 = t5v1[:,1]
x52 = t5v2[:,0]
y52 = t5v2[:,1]
x53 = t5v3[:,0]
y53 = t5v3[:,1]

# %%
x70h = t7v0HOM[:,0]
y70h = t7v0HOM[:,1]
x71h = t7v1HOM[:,0]
y71h = t7v1HOM[:,1]
x72h = t7v2HOM[:,0]
y72h = t7v2HOM[:,1]
x73h = t7v3HOM[:,0]
y73h = t7v3HOM[:,1]

x60h = t6v0HOM[:,0]
y60h = t6v0HOM[:,1]
x61h = t6v1HOM[:,0]
y61h = t6v1HOM[:,1]
x62h = t6v2HOM[:,0]
y62h = t6v2HOM[:,1]
x63h = t6v3HOM[:,0]
y63h = t6v3HOM[:,1]

x50h = t5v0HOM[:,0]
y50h = t5v0HOM[:,1]
x51h = t5v1HOM[:,0]
y51h = t5v1HOM[:,1]
x52h = t5v2HOM[:,0]
y52h = t5v2HOM[:,1]
x53h = t5v3HOM[:,0]
y53h = t5v3HOM[:,1]

# %% [markdown]
# # Plotting the data corresponding to the homogeneous model

# %%
## Plot data Homogeneous Model 
#V = (- 12.8451673301 * x)

figure(num=None, figsize=(10.5, 9))
ax1 = subplot(1, 1, 1)
ax1.plot(x70, y70, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-.', c = 'k')
#plt.plot(V, y, label=r'$\mathrm{50 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5)
ax1.plot(x71,y71, label='$\mathrm{100 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = ':', c = 'k')
ax1.plot(x72,y72, label='$\mathrm{200 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax1.plot(x73,y73, label='$\mathrm{300 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax1.legend(loc='upper left', fontsize = 22)
ax1.set_xlabel (r'$x$', fontsize=35)
ax1.set_ylabel ('$\mathrm{Intensity}$ $\mathrm{(Arbitrary Units)}$', fontsize=35)

ax1.tick_params(axis='both', which='major', labelsize=35)
new1_tick_locations = np.array([0, 0.01, 0.02, 0.03 ,0.038])
ax1.set_yticks(new1_tick_locations)
ax1.set_yticklabels([0.0, 0.01, 0.02, 0.03, 0.040])

new_tick_locations = np.array([0, .166, .3333, .5, .666, .833, 1])
ax2 = ax1.twiny()
ax2.set_xticks(new_tick_locations)
ax2.tick_params(labelsize=35)
ax2.set_xticklabels(['-768','-512','-256', '0', '256', '512', '768'])
plt.text(0.72, 0.034, r"$\mathrm{\tau_{H}=10^7}$", fontsize=35)
plt.text(0.72, 0.037, r"$\mathrm{Central}$", fontsize = 35)
plt.text(0.27, 0.044, '$\mathrm{Velocity}$ $\mathrm{(km}$ $\mathrm{s^{-1})}$', fontsize=35)
savefig('f1_1.eps', bbox_inches='tight')

plt.show()
#print  (1/6.0)*5
#print 12.8*60, 12.8*40, 12.8*20

# %% [markdown]
# # Plotting the data corresponding to the central model

# %%
figure(num=None, figsize=(10.5, 9))

ax1 = subplot(1, 1, 1)
ax1.plot(x70h, y70h, label=r'$\mathrm{0 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-.', c = 'k')
ax1.plot(x71h,y71h, label='$\mathrm{100 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = ':', c = 'k')
ax1.plot(x72h,y72h, label='$\mathrm{200 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '--', c = 'k')
ax1.plot(x73h,y73h, label='$\mathrm{300 km}$ $\mathrm{s^{-1}}$', linewidth = 2.5, ls = '-', c = 'k')
ax1.legend(loc='upper left', fontsize = 22)
ax1.set_xlabel (r'$x$', fontsize=35)
ax1.set_ylabel ('$\mathrm{Intensity}$ $\mathrm{(Arbitrary Units)}$', fontsize=35)
#plt.title(r"$\mathrm{Central}$ , $\mathrm{\tau_{H}=10^7}$", fontsize=35)
ax1.tick_params(axis='both', which='major', labelsize=35)
new1_tick_locations = np.array([0, 0.01, 0.02, 0.03 ,0.038])
ax1.set_yticks(new1_tick_locations)
ax1.set_yticklabels([0.0, 0.01, 0.02, 0.03, 0.040])

new_tick_locations = np.array([0, .166, .3333, .5, .666, .833, 1])

ax2 = ax1.twiny()
ax2.set_xticks(new_tick_locations)
ax2.tick_params(labelsize=35)
ax2.set_xticklabels(['-768','-512','-256', '0', '256', '512', '768'])
plt.text(0.65, 0.034, r"$\mathrm{\tau_{H}=10^7}$", fontsize=35)
plt.text(0.65, 0.037, r"$\mathrm{Homogeneous}$", fontsize = 35)
plt.text(0.27, 0.044, '$\mathrm{Velocity}$ $\mathrm{(km}$ $\mathrm{s^{-1})}$', fontsize=35)

savefig('f1_2.eps', bbox_inches='tight')

plt.show()

# %% [markdown]
# # Measuring FWHM

# %%
def FWHM(x, y, err):
    h = amax(y)
    half = h/2.0
    print 'the half maximum is','    ',half
#print x[35]

    FWHM=[]
    for i in range(len(x)):
        if np.abs(y[i] - half) <= err:
            width = FWHM.append(x[i])
            #print i,  FWHM, y[i]  
    #print 'all the wights correspondig to the half maximum are', '   ' , FWHM
    order = np.sort(np.abs(FWHM))
    print 'ordered widhts'
    print order
    avg = (order[-1] + order[-2] + order[-3])/3.0
    print 'Average of widhts'
    print avg
    print '-----------------------'
    return avg

# %% [markdown]
# # Homogeneous

# %%
w70h = FWHM(x70h, y70h, 0.004)
w71h = FWHM(x71h, y71h, 0.0015)
w72h = FWHM(x72h, y72h, 0.001)
w73h = FWHM(x73h, y73h, 0.0005)

w7h = np.array([w70h, w71h, w72h, w73h])

print '################################################################'

w60h = FWHM(x60h, y60h, 0.004)
w61h = FWHM(x61h, y61h, 0.005)
w62h = FWHM(x62h, y62h, 0.001)
w63h = FWHM(x63h, y63h, 0.0005)

w6h = np.array([8.245, w61h, w62h, w63h])
print '################################################################'

w50h = FWHM(x50h, y50h, 0.006)
w51h = FWHM(x51h, y51h, 0.005)
w52h = FWHM(x52h, y52h, 0.001)
w53h = FWHM(x53h, y53h, 0.001)
w5h = np.array([5.34, w51h, w52h, w53h])

print '-------------------'
print 'w7=',   w7
print 'w6=',   w6
print 'w5=',   w5
print '-------------------'
# Out:
# the half maximum is      0.018656
# ordered widhts
# [  3.40385   3.90385   4.09615   4.40385   4.59615  15.90385  16.40385
#   16.90385  17.09615  17.40385  17.59615  17.90385  18.09615  18.59615]
# Average of widhts
# 18.1987166667
# -----------------------
# the half maximum is      0.0165505
# ordered widhts
# [  3.34402   3.65598   3.84402   4.15598  17.84402  18.34402  18.65598]
# Average of widhts
# 18.28134
# -----------------------
# the half maximum is      0.013409
# ordered widhts
# [ 19.89782  20.39782  20.60218  20.89782  21.10218  21.60218]
# Average of widhts
# 21.2007266667
# -----------------------
# the half maximum is      0.01072
# ordered widhts
# [ 22.92186  23.42186  23.57814  23.92186  24.42186]
# Average of widhts
# 23.9739533333
# -----------------------
# ################################################################
# the half maximum is      0.042704
# ordered widhts
# [ 3.43519  8.06481  8.43519]
# Average of widhts
# 6.64506333333
# ...

# %%
figure(num=None, figsize=(9.5, 9))
plt.plot(x60h, y60h)
plt.plot(x61h, y61h)
plt.plot(x62h, y62h)
plt.plot(x63h, y63h)

plt.xlim([-50, 50])
plt.ylim([0, 0.09])
# Out:
# (0, 0.09)

# %%
figure(num=None, figsize=(9.5, 9))
plt.plot(x50h, y50h)
plt.plot(x51h, y51h)
plt.plot(x52h, y52h)
plt.plot(x53h, y53h)
plt.xlim([-50, 50])
plt.ylim([0, 0.13])
# Out:
# (0, 0.13)

# %%
figure(num=None, figsize=(9.5, 9))
plt.plot(x50h, y50h)
plt.plot(x51h, y51h)
plt.plot(x52h, y52h)
plt.plot(x53h, y53h)
plt.xlim([-50, 50])
plt.ylim([0, 0.13])
# Out:
# (0, 0.13)

# %% [markdown]
# # Central

# %%
w70 = FWHM(x70, y70, 0.004)
w71 = FWHM(x71, y71, 0.004)
w72 = FWHM(x72, y72, 0.001)
w73 = FWHM(x73, y73, 0.0005)

w7 = np.array([w70, w71, w72, w73])

print '################################################################'

w60 = FWHM(x60, y60, 0.009)
w61 = FWHM(x61, y61, 0.005)
w62 = FWHM(x62, y62, 0.001)
w63 = FWHM(x63, y63, 0.002)

w6 = np.array([w60, w61, w62, w63])
print '################################################################'

w50 = FWHM(x50, y50, 0.019)
w51 = FWHM(x51, y51, 0.015)
w52 = FWHM(x52, y52, 0.003)
w53 = FWHM(x53, y53, 0.001)
w5 = np.array([w50, w51, w52, w53])

print '-------------------'
print 'w7=',   w7
print 'w6=',   w6
print 'w5=',   w5
print '-------------------'
# Out:
# the half maximum is      0.0199405
# ordered widhts
# [  7.6387   8.1387   8.3613   8.6387   8.8613   9.1387   9.3613   9.6387
#    9.8613  20.1387  20.6387  20.8613  21.1387  21.3613  21.6387  21.8613]
# Average of widhts
# 21.6204333333
# -----------------------
# the half maximum is      0.01714
# ordered widhts
# [  6.83504   7.16496   7.33504   7.66496   7.83504   8.16496   8.33504
#    8.66496   8.83504   9.16496   9.66496  20.83504  21.16496  21.33504
#   21.66496  21.83504  22.16496  22.33504  22.66496  23.16496]
# Average of widhts
# 22.7216533333
# -----------------------
# the half maximum is      0.013205
# ordered widhts
# [  4.56851   4.93149   5.06851   5.43149   5.56851   6.43149  23.06851
#   23.56851  24.06851  24.43149]
# Average of widhts
# 24.0228366667
# -----------------------
# the half maximum is      0.010286
# ordered widhts
# [ 26.09952  26.40048  26.59952  26.90048]
# Average of widhts
# 26.6334933333
# -----------------------
# ...

# %%
figure(num=None, figsize=(9.5, 9))
plt.plot(x70, y70)
plt.plot(x71, y71)
plt.plot(x72, y72)
plt.plot(x73, y73)
plt.xlim([-50, 50])
plt.ylim([0, 0.05])
# Out:
# (0, 0.05)

# %%
# Width Analysis in Velocitis units

t7 = np.array([12.13, 15, 21.24, 27.73])                 # 90 theta
t6 = np.array([5.99, 9.397, 13.99, 15.1756])
t5 = np.array([3.21, 6.311, 7.462, 9.00])

t7hom = np.array([13.51, 15.63308, 21.4569, 23.6824])                 # 90 theta 
#t6hom = np.array([5.42, 9.68307, 12.074, 14.0267])
t6hom = np.array([8.23, 10.69, 12.074, 14.0267])
#t5hom = np.array([3.92, 6.425, 7.929, 9.889])
t5hom = np.array([5.051, 8.18, 10.96, 16.1531])

#New widths in V terms

Wt7 = w7*12.85
Wt6 = w6*12.85
Wt5 = w5*12.85

Wt7hom = w7h*12.85
Wt6hom = w6h*12.85
Wt5hom = w5h*12.85

v = (0, 100, 200, 300)

figure(num=None, figsize=(9.5,9))

p1, = plot(v,Wt7, linewidth = 2.5, marker = '^', ms=10, c= 'k')
p2, = plot(v,Wt6, linewidth = 2.5, marker = 's', ms=10, c= 'k')
p3, = plot(v,Wt5, linewidth = 2.5, marker = 'o', ms=10, c= 'k')

p1hom, = plot(v,Wt7hom, linewidth = 2.5, marker = '^', ms=10, c= 'k', linestyle = '--')
p2hom, = plot(v,Wt6hom, linewidth = 2.5, marker = 's', ms=10, c= 'k', linestyle = '--')
p3hom, = plot(v,Wt5hom, linewidth = 2.5, marker = 'o', ms=10, c= 'k', linestyle = '--')


#plt.text(0.4, 100.8, '$\mathrm{-- Central}$', fontsize=34)
legend([p1, p2, p3], [r'$\tau=10^{7}$',r'$\tau=10^{6}$', r'$\tau=10^{5}$'], loc ='upper center', ncol=3, fontsize=20)
xlabel (r'$\mathrm{V_{max}}$ ($\mathrm{km}$ $\mathrm{s^{-1}}$)', fontsize=35)
ylabel ( r'$\mathrm{W_{1/2}} \mathrm{(kms^{-1})}$', fontsize=35)
#plt.title ('Central', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.xlim([-20, 320])
plt.ylim([0, 400])
savefig("NewWidthVvsVmax.png")
#plt.show()

# %%
def gauss(x, *p):
    A, mu, sigma = p
    return A*np.exp(-(x-mu)**2/(2.*sigma**2))

# p0 is the initial guess for the fitting coefficients (A, mu and sigma above)
p0 = [1., 1., 1.]

coeff, var_matrix = curve_fit(gauss, x51h, y51h, p0=p0)

# Get the fitted curve
hist_fit = gauss(x51h, *coeff)

# %%
plt.plot(x51h, y51h, label='Test data')
plt.plot(x51h, hist_fit, label='Fitted data')

# %%
print 'Fitted mean = ', coeff[2]
# Out:
# Fitted mean =  5.4910662442

# %%
savefig?
