# %%
# %pylab inline
font = {'size':20, 'family':'serif'}
matplotlib.rc('font', **font)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
data05 = np.loadtxt("../data/Homogeneous/RotatingV0Sphere5tHOM_in.ascii")
data05out = np.loadtxt("../data/Homogeneous/RotatingV0Sphere5tHOM_out.ascii")

data06 = np.loadtxt("../data/Homogeneous/RotatingV0Sphere6tHOM_in.ascii")
data06out = np.loadtxt("../data/Homogeneous/RotatingV0Sphere6tHOM_out.ascii")

data07 = np.loadtxt("../data/Homogeneous/RotatingV0Sphere7tHOM_in.ascii")
data07out = np.loadtxt("../data/Homogeneous/RotatingV0Sphere7tHOM_out.ascii")

# %%
data1 = np.loadtxt("../data/Homogeneous/RotatingV100Sphere5tHOM_in.ascii")
data1out = np.loadtxt("../data/Homogeneous/RotatingV100Sphere5tHOM_out.ascii")
data2 = np.loadtxt("../data/Homogeneous/RotatingV200Sphere5tHOM_in.ascii")
data2out = np.loadtxt("../data/Homogeneous/RotatingV200Sphere5tHOM_out.ascii")
data3 = np.loadtxt("../data/Homogeneous/RotatingV300Sphere5tHOM_in.ascii")
data3out = np.loadtxt("../data/Homogeneous/RotatingV300Sphere5tHOM_out.ascii")
data4 = np.loadtxt("../data/Homogeneous/RotatingV100Sphere6tHOM_in.ascii")
data4out = np.loadtxt("../data/Homogeneous/RotatingV100Sphere6tHOM_out.ascii")
data5 = np.loadtxt("../data/Homogeneous/RotatingV200Sphere6tHOM_in.ascii")
data5out = np.loadtxt("../data/Homogeneous/RotatingV200Sphere6tHOM_out.ascii")
data6 = np.loadtxt("../data/Homogeneous/RotatingV300Sphere6tHOM_in.ascii")
data6out = np.loadtxt("../data/Homogeneous/RotatingV300Sphere6tHOM_out.ascii")
data7 = np.loadtxt("../data/Homogeneous/RotatingV100Sphere7tHOM_in.ascii")
data7out = np.loadtxt("../data/Homogeneous/RotatingV100Sphere7tHOM_out.ascii")
data8 = np.loadtxt("../data/Homogeneous/RotatingV200Sphere7tHOM_in.ascii")
data8out = np.loadtxt("../data/Homogeneous/RotatingV200Sphere7tHOM_out.ascii")
data9 = np.loadtxt("../data/Homogeneous/RotatingV300Sphere7tHOM_in.ascii")
data9out = np.loadtxt("../data/Homogeneous/RotatingV300Sphere7tHOM_out.ascii")

# %%
x_in_05 = data0[:,6]
x_out_05 = data0out[:,6]

x_in_06 = data0[:,6]
x_out_06 = data0out[:,6]

x_in_07 = data0[:,6]
x_out_07 = data0out[:,6]

x_in_1 = data1[:,6]
x_out_1 = data1out[:,6]

x_in_2 = data2[:,6]
x_out_2 = data2out[:,6]

x_in_3 = data3[:,6]
x_out_3 = data3out[:,6]

x_in_4 = data4[:,6]
x_out_4 = data4out[:,6]
x_in_5 = data5[:,6]
x_out_5 = data5out[:,6]

x_in_6 = data6[:,6]
x_out_6 = data6out[:,6]

x_in_7 = data7[:,6]
x_out_7 = data7out[:,6]

x_in_8 = data8[:,6]
x_out_8 = data8out[:,6]

x_in_9 = data9[:,6]
x_out_9 = data9out[:,6]

# %%
figure(num=None, figsize=(9.5,9.0))

histin_05, binsin_05 = np.histogram(x_in_05, bins=50, normed=True)
histout_05, binsout_05 = np.histogram(x_out_05, bins=50, normed=True)

histin_06, binsin_06 = np.histogram(x_in_06, bins=50, normed=True)
histout_06, binsout_06 = np.histogram(x_out_06, bins=50, normed=True)


histin_07, binsin_07 = np.histogram(x_in_07, bins=50, normed=True)
histout_07, binsout_07 = np.histogram(x_out_07, bins=50, normed=True)


histin_1, binsin_1 = np.histogram(x_in_1, bins=50, normed=True)
histout_1, binsout_1 = np.histogram(x_out_1, bins=50, normed=True)

histin_2, binsin_2 = np.histogram(x_in_2, bins=50, normed=True)
histout_2, binsout_2 = np.histogram(x_out_2, bins=50, normed=True)

histin_3, binsin_3 = np.histogram(x_in_3, bins=50, normed=True)
histout_3, binsout_3 = np.histogram(x_out_3, bins=50, normed=True)

histin_4, binsin_4 = np.histogram(x_in_4, bins=50, normed=True)
histout_4, binsout_4 = np.histogram(x_out_4, bins=50, normed=True)

histin_5, binsin_5 = np.histogram(x_in_5, bins=50, normed=True)
histout_5, binsout_5 = np.histogram(x_out_5, bins=50, normed=True)

histin_6, binsin_6 = np.histogram(x_in_6, bins=50, normed=True)
histout_6, binsout_6 = np.histogram(x_out_6, bins=50, normed=True)

histin_7, binsin_7 = np.histogram(x_in_7, bins=50, normed=True)
histout_7, binsout_7 = np.histogram(x_out_7, bins=50, normed=True)

histin_8, binsin_8 = np.histogram(x_in_8, bins=50, normed=True)
histout_8, binsout_8 = np.histogram(x_out_8, bins=50, normed=True)

histin_9, binsin_9 = np.histogram(x_in_9, bins=50, normed=True)
histout_9, binsout_9 = np.histogram(x_out_9, bins=50, normed=True)

# %%
fig = figure(num=None, figsize=(20, 16))
fig.subplots_adjust(hspace=0.00, wspace=0.00,
                    top=0.98, right=0.95, bottom=0.05)

ax = fig.add_subplot(341)
ax.plot(binsin_05[:-1], histin_05,  label = (r"$x_{in}$"))
ax.plot(binsout_05[:-1], histout_05,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-18, 18])
ax.legend()

ax = fig.add_subplot(342)
ax.plot(binsin_1[:-1], histin_1,  label = (r"$x_{in}$"))
ax.plot(binsout_1[:-1], histout_1,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-43, 43])
ax.legend()

ax = fig.add_subplot(343)
ax.plot(binsin_2[:-1], histin_2,  label = (r"$x_{in}$"))
ax.plot(binsout_2[:-1], histout_2,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-43, 43])
ax.legend()

ax = fig.add_subplot(344)
ax.plot(binsin_3[:-1], histin_3,  label = (r"$x_{in}$"))
ax.plot(binsout_3[:-1], histout_3,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-53, 53])
ax.legend()

ax = fig.add_subplot(345)
ax.plot(binsin_06[:-1], histin_06,  label = (r"$x_{in}$"))
ax.plot(binsout_06[:-1], histout_06,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_xlim([-18, 18])
ax.set_ylim([0, 0.16])
ax.legend()

ax = fig.add_subplot(346)
ax.plot(binsin_4[:-1], histin_4,  label = (r"$x_{in}$"))
ax.plot(binsout_4[:-1], histout_4,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-43, 43])
ax.legend()

ax = fig.add_subplot(347)
ax.plot(binsin_5[:-1], histin_5,  label = (r"$x_{in}$"))
ax.plot(binsout_5[:-1], histout_5,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-43, 43])
ax.legend()

ax = fig.add_subplot(348)
ax.plot(binsin_6[:-1], histin_6,  label = (r"$x_{in}$"))
ax.plot(binsout_6[:-1], histout_6,  label = (r"$x_{out}$"))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-53, 53])
ax.legend()

ax = fig.add_subplot(349)
ax.plot(binsin_07[:-1], histin_07,  label = (r"$x_{in}$"))
ax.plot(binsout_07[:-1], histout_07,  label = (r"$x_{out}$"))
#ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-18, 18])
ax.legend()


ax = fig.add_subplot(3,4,10)
ax.plot(binsin_7[:-1], histin_7,  label = (r"$x_{in}$"))
ax.plot(binsout_7[:-1], histout_7,  label = (r"$x_{out}$"))
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-43, 43])
ax.legend()

ax = fig.add_subplot(3,4,11)
ax.plot(binsin_8[:-1], histin_8,  label = (r"$x_{in}$"))
ax.plot(binsout_8[:-1], histout_8,  label = (r"$x_{out}$"))
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_xlabel("$x$", fontsize=30)
ax.set_ylim([0, 0.16])
ax.set_xlim([-43, 43])
ax.legend()

ax = fig.add_subplot(3,4,12)
ax.plot(binsin_9[:-1], histin_9,  label = (r"$x_{in}$"))
ax.plot(binsout_9[:-1], histout_9,  label = (r"$x_{out}$"))
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_ylim([0, 0.16])
ax.set_xlim([-53, 53])
ax.legend()

ax.text(-364.00, 0.14, r"$\tau=10^7$", fontsize=30)
ax.text(-364.00, 0.3, r"$\tau=10^6$", fontsize=30)
ax.text(-364.00, 0.45, r"$\tau=10^5$", fontsize=30)

ax.text(-360.00, 0.49,  r"$v=10 km\ s^{-1}$", fontsize=30)
ax.text(-270.00, 0.49,  r"$v=100 km\ s^{-1}$", fontsize=30)
ax.text(-154.00, 0.49,  r"$v=200 km\ s^{-1}$", fontsize=30)
ax.text(-34.00, 0.49, r"$v=300 km\ s^{-1}$", fontsize=30)



plt.savefig("intrinsic_spectrum.png")
