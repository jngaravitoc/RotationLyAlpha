# %%
from numpy import *
from pylab import *
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

data_path = "/home/Nicolas-Garavito/"
data_dir="Dropbox/LyAlpha/plots/Model5/"
filename="Rotating50Sphere5t.ascii"

datoslyman = np.loadtxt(data_path+data_dir+filename, comments = '#')

frec = datoslyman[:,6]
NScatt = datoslyman[:,8]


p1, = plot(frec, NScatt, 'o')
#print NScatt

# %%
H, xedges, yedges = np.histogram2d(frec, NScatt, bins=(1, 150000))
H.shape, xedges.shape, yedges.shape
# Out:
# ((1, 150000), (2,), (150001,))

# %%
extent = [yedges[0], yedges[-1], xedges[-1], xedges[0]]
plt.imshow(H, extent=extent, interpolation='nearest')
plt.colorbar()
plt.show()
