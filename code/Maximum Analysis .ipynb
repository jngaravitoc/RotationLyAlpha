# %%
from numpy import *
from pylab import *
import numpy as np
import math
import matplotlib.pyplot as plt

data_path = "/home/Nicolas-Garavito/"
data_dir="Dropbox/PaperLymanRotation/code/"
filenamex="Maxima50t5x.ascii"
filenamey="Maxima50t5y.ascii"

maximX = np.loadtxt(data_path+data_dir+filenamex)
maximY = np.loadtxt(data_path+data_dir+filenamey)

#x = maximX[:,1]
#y = maximY[:,1]


print maximX

p1, = plot(maximX,maximY)
# Out:
# [-15.33708 -14.33708 -13.33708 -12.33708 -11.33708 -10.33708  -9.33708
#   -8.33708  -7.33708  -6.33708  -5.33708  -4.33708  -3.33708  -2.33708
#   -1.33708  -0.33708   0.66292   1.66292   2.66292   3.66292   4.66292
#    5.66292   6.66292   7.66292   8.66292   9.66292  10.66292  11.66292]

# %%
z = matplotlib.mlab.slopes(maximX, maximY)
p2, = plot(maximX,z)
print z
# Out:
# [ -1.20000000e-05  -4.00000000e-06  -6.50000000e-06  -4.90000000e-05
#   -1.61500000e-04  -7.79500000e-04  -2.85200000e-03  -8.80400000e-03
#   -2.25760000e-02  -4.68395000e-02  -8.18990000e-02  -1.08553500e-01
#   -9.91970000e-02  -6.59470000e-02  -3.87505000e-02  -2.72825000e-02
#   -2.99225000e-02  -4.64075000e-02  -7.76975000e-02  -1.05955500e-01
#   -1.02280000e-01  -7.04395000e-02  -3.74755000e-02  -1.66000000e-02
#   -6.47350000e-03  -2.13100000e-03  -6.54500000e-04   2.45000000e-05]
